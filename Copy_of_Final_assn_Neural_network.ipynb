# %% [markdown]
# <a href="https://colab.research.google.com/github/lilyzhizhou/ML-Final-Project/blob/main/Copy_of_Final_assn_Neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Necessary Libraries

# %%
# importing PyTorch library as 't' for convenience
import torch as t

# importing other necessary libraries
import numpy as np
from torch.nn.functional import sigmoid, relu, tanh
from torch.optim import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.impute import SimpleImputer

# !pip install category_encoders
from category_encoders import OneHotEncoder, TargetEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
# importing PyTorch modules for building neural networks
from torch.nn import Tanh, Linear, Sequential, Sigmoid, Dropout
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.11.4)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.1)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (23.2)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.3

# %%
# Set random seed for NumPy
np.random.seed(42)

# Set random seed for PyTorch
t.manual_seed(42)
t.backends.cudnn.deterministic = True
t.backends.cudnn.benchmark = False

# %% [markdown]
# Load data

# %%
# Read CSV file into Pandas df
import pandas as pd

df = pd.read_csv('datapd.csv')
df.head()
# Out:
#    Unnamed: 0  predm  Age_at_Exam   BMI  Total_Cholesterol  Depression  HTN  \
# 0           2      1           63  30.9                NaN           0    1
# 1        2386      1           66  23.6               3.54           1    1
# 2        7781      0           68  34.3               5.55           1    1
# 3        7644      1           73  28.5               3.78           1    1
# 4        2290      0           53  33.4               5.38           0    1
#
#    OA  COPD  corstrd_bin  htnmed_bin  Sex        Patient_ID
# 0   0     1            0           1    1  1001000000000054
# 1   1     0            0           1    1  1001000000004538
# 2   1     0            0           1    0  1001000000007331
# 3   0     1            1           1    0  1001000000007333
# 4   1     0            1           1    0  1001000000009032

# %% [markdown]
# Checking Data Types

# %%
# checking the data types
df.dtypes
# Out:
# Unnamed: 0             int64
# predm                  int64
# Age_at_Exam            int64
# BMI                  float64
# Total_Cholesterol    float64
# Depression             int64
# HTN                    int64
# OA                     int64
# COPD                   int64
# corstrd_bin            int64
# htnmed_bin             int64
# Sex                    int64
# Patient_ID             int64
# dtype: object

# %%
#remove "Patient_ID" column
df=df.drop('Patient_ID', axis=1)

# %% [markdown]
# Define numerical and categorical columns

# %%
# create list of numerical, categorical, multinomial features
target_column = 'predm'
categorical_columns = ['Depression', 'HTN',
                       'OA', 'COPD', 'Sex',
                       'corstrd_bin','htnmed_bin']
#multinomial_columns = [] there are none
numerical_columns = ['Age_at_Exam','BMI','Total_Cholesterol']

# %% [markdown]
# Convert numeric categorical categories into descriptive categories

# %%
# Convert numeric categorical variables into descriptive categories
df_descr = df.copy()

df_descr['predm'].replace({0 : 'No', 1 : 'Yes'}, inplace=True)
df_descr['Depression'].replace({0 : 'No', 1 : 'Yes'}, inplace=True)
df_descr['HTN'].replace({0 : 'No', 1 : 'Yes'}, inplace=True)
df_descr['OA'].replace({0 : 'No', 1 : 'Yes'}, inplace=True)
df_descr['COPD'].replace({0 : 'No', 1 : 'Yes'}, inplace=True)
df_descr['corstrd_bin'].replace({0 : 'No', 1 : 'Yes'}, inplace=True)
df_descr['htnmed_bin'].replace({0 : 'No', 1 : 'Yes'}, inplace=True)

df_descr.head()
# Out:
#    Unnamed: 0 predm  Age_at_Exam   BMI  Total_Cholesterol Depression  HTN  \
# 0           2   Yes           63  30.9                NaN         No  Yes
# 1        2386   Yes           66  23.6               3.54        Yes  Yes
# 2        7781    No           68  34.3               5.55        Yes  Yes
# 3        7644   Yes           73  28.5               3.78        Yes  Yes
# 4        2290    No           53  33.4               5.38         No  Yes
#
#     OA COPD corstrd_bin htnmed_bin  Sex
# 0   No  Yes          No        Yes    1
# 1  Yes   No          No        Yes    1
# 2  Yes   No          No        Yes    0
# 3   No  Yes         Yes        Yes    0
# 4  Yes   No         Yes        Yes    0

# %% [markdown]
# Check distribution of outcome variable

# %%
# Checking for Pre-Diabetes imbalance

# Compute the count of each class in the 'target' column
counts = df_descr['predm'].value_counts()

# Define colors for the pie chart sections
colors = ['#a3416c', '#ebc898']

# Construct a pie chart with plotly
# 'names' are the class labels, and 'values' are the counts for each class
fig = px.pie(
    names=counts.index,
    values=counts.values,
    hole=0.5,  # creates a donut-styled pie chart
    title='Distribution of predm',
    color_discrete_sequence=colors
)

# Update the layout of the pie chart for better presentation and clarity
fig.update_layout(
    margin=dict(t=50, b=0, l=0, r=0),
    legend=dict(
        orientation="v",
        yanchor="top",
        y=0.5,
        xanchor="left",
        x=1.05,
        title='target'
    ),
    title=dict(
        text='Distribution of Classes in predm',
        x=0.45,
        xanchor='center',
        y=0.95,
        yanchor='top',
        font=dict(size=16)
    ),
    width=500,
    height=350
)

# Display the pie chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a6a59a5c-18bb-45aa-99c6-57399f7eeb92" class="plotly-graph-div" style="height:350px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6a59a5c-18bb-45aa-99c6-57399f7eeb92")) {                    Plotly.newPlot(                        "a6a59a5c-18bb-45aa-99c6-57399f7eeb92",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["No","Yes"],"legendgroup":"","name":"","showlegend":true,"values":[3798,2616],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"mark ...

# %% [markdown]
# Check Distributions of variables

# %%
# checking the difference in distribution of numerical features in two classes

# Create a grid of subplots with 1 rows and 3 columns
fig, axs = plt.subplots(ncols=3, nrows=2, figsize=(15, 10))

# Loop over each feature in numerical and multinomial lists
for i, column in enumerate(numerical_columns):
    # Calculate the position for the subplot; x is the row index and y is the column index
    x = i // 3
    y = i % 3

    # Plot a histogram of the feature split by the 'target' class
    # kde=True adds a Kernel Density Estimate plot to smooth the histogram, providing a clearer view of the data distribution
    sns.histplot(df_descr, x=column, hue= target_column, kde=True, palette='rocket', ax=axs[x][y])

# Display all the subplots
plt.show()

# %% [markdown]
# Proportion of positive cases

# %%
df['predm'].mean()
# Out:
# 0.4078578110383536

# %% [markdown]
# Data Preparation

# %%
# Splitting the original dataset into training, validation, and test sets

# Taking 75% of the data for training
train_df = df.sample(frac = 0.75, random_state=42)

# Removing the training data from the original dataset to get the combined validation and test data
test_df = df.drop(train_df.index)

# Splitting the combined validation and test data into two equal parts for validation and testing, respectively
valid_df = test_df.sample(frac = 0.5, random_state=42)
test_df = test_df.drop(valid_df.index)

# %%
#Impute Missing Values
imputer = SimpleImputer(strategy='median')
train_df = pd.DataFrame(imputer.fit_transform(train_df), columns=train_df.columns)
test_df = pd.DataFrame(imputer.transform(test_df), columns=test_df.columns)
valid_df = pd.DataFrame(imputer.transform(valid_df), columns=valid_df.columns)

# %%
#double check if there are not missing values anymore
print(valid_df.isna().sum())
print(train_df.isna().sum())
# Out:
# Unnamed: 0           0
# predm                0
# Age_at_Exam          0
# BMI                  0
# Total_Cholesterol    0
# Depression           0
# HTN                  0
# OA                   0
# COPD                 0
# corstrd_bin          0
# htnmed_bin           0
# Sex                  0
# dtype: int64
# Unnamed: 0           0
# predm                0
# Age_at_Exam          0
# BMI                  0
# Total_Cholesterol    0
# Depression           0
# HTN                  0
# OA                   0
# COPD                 0
# corstrd_bin          0
# htnmed_bin           0
# Sex                  0
# dtype: int64

# %%
# Data Preparation

# Extract the 'predm' column as the target variable for training and testing
Y_train = train_df['predm'].to_numpy()
Y_test = test_df['predm'].to_numpy()
Y_valid = valid_df['predm'].to_numpy()

# Extract the features (excluding 'predm') for training and testing
X_train = train_df.drop('predm', axis=1).to_numpy()
X_test = test_df.drop('predm', axis=1).to_numpy()
X_valid = valid_df.drop('predm', axis=1).to_numpy()

# Standardize the features to have zero mean and unit variance
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
X_valid = sc.transform(X_valid)

# %% [markdown]
# Initializing Neural Network Parameters in PyTorch

# %%
# Define the number of neurons in the first and second hidden layers
hidden_units_layer_1 = 10
hidden_units_layer_2 = 10

# FIRST LAYER: Define weights and biases for the first layer
W1 = t.randn((11, hidden_units_layer_1), requires_grad=True)
B1 = t.zeros((1, hidden_units_layer_1), requires_grad=True)

# SECOND LAYER: Define weights and biases for the second layer
W2 = t.randn((hidden_units_layer_1, hidden_units_layer_2), requires_grad=True)
B2 = t.zeros((1, hidden_units_layer_2), requires_grad=True)

# THIRD LAYER: Define weights and biases for the output layer
W3 = t.randn((hidden_units_layer_2, 1), requires_grad=True)
B3 = t.zeros((1, 1), requires_grad=True)

# %% [markdown]
# Implementing the Forward Pass of a Neural Network in PyTorch

# %%
# Define the forward pass of the neural network
def forward(input):
    # First hidden layer with tanh activation
    out = tanh(input @ W1 + B1)

    # Second hidden layer with tanh activation
    out = tanh(out @ W2 + B2)

    # Output layer with sigmoid activation (since it's a binary classification problem)
    out = sigmoid(out @ W3 + B3)
    return out

# %% [markdown]
# Preparing Data and Training Utilities for Neural Network Training in PyTorch

# %%
#Explicitly convert the data types of your NumPy array elements to a compatible numeric type
#X_train = X_train.astype(np.float32)
#Y_train = Y_train.astype(np.float32)

# Convert the training data to PyTorch tensors
X = t.Tensor(X_train).type(t.float32)
Y = t.Tensor(Y_train).type(t.float32)

# Create a dataset from tensors to be used with DataLoader
train_dataset = TensorDataset(X, Y)

# Define training hyperparameters
epochs = 2000
learning_rate = 0.001
batch_size = 25

# DataLoader provides batches of data for training
train_data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Define the optimizer (Adam) and include all weights and biases
optimizer = Adam([W1, B1, W2, B2, W3, B3], lr=learning_rate)

# Define the loss function (Binary Cross-Entropy Loss)
loss_fn = t.nn.BCELoss()

# %% [markdown]
# Training Loop for a Neural Network in PyTorch

# %%
train_loss_list = [] #initializes an empty list to store the average loss of each epoch

# Train the model for a specified number of epochs
for epoch in range(epochs):
    # Reduce the learning rate every 500 epochs
    if epoch % 500 == 0:
        learning_rate *= .9

    per_epoch_loss_list = []

    # Iterate over all batches of data
    for batch_idx, (X, Y) in enumerate(train_data_loader):
        # Forward pass: Compute predictions
        probs = forward(X) #calls the forward function to compute predictions based on the batch of input data x

        # Compute the loss
        loss = loss_fn(probs.view(-1), Y)

        # Backward pass: Compute gradient and update weights
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Record the loss for this batch
        per_epoch_loss_list.append(loss.item())

    # Record the average loss for this epoch
    train_loss_list.append(sum(per_epoch_loss_list) / len(per_epoch_loss_list))

# %% [markdown]
# Visualizing Training Loss over Epochs with Maptlotlib in Python

# %%
# Plot the training loss over epochs
plt.plot([i for i in range(len(train_loss_list))], train_loss_list)
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# Evaluating Model Performance on Validation Data

# %%
# Evaluate Model Performance on Validation Data

# Disable gradient calculations for evaluation using t.no_grad()
with t.no_grad():
    # Prepare the validation data
    X_valid_tensor = t.Tensor(X_valid).type(t.float32)  # Convert validation features to a PyTorch tensor
    Y_valid_tensor = t.Tensor(Y_valid).type(t.float32)  # Convert validation labels to a PyTorch tensor

    # Calculate predictions on the validation data
    probs = forward(X_valid_tensor)  # Pass validation data through the trained model
    loss = loss_fn(probs.view(-1), Y_valid_tensor)  # Compute the loss between predictions and actual labels

    # Print the validation loss
    print(loss.item())

    # Now, evaluate the model on the training data
    X_train_tensor = t.Tensor(X_train).type(t.float32)  # Convert training features to a PyTorch tensor
    Y_train_tensor = t.Tensor(Y_train).type(t.float32)  # Convert training labels to a PyTorch tensor

    # Calculate predictions on the training data
    probs = forward(X_train_tensor)  # Pass training data through the trained model
    loss = loss_fn(probs.view(-1), Y_train_tensor)  # Compute the loss between predictions and actual labels

    # Print the training loss
    print(loss.item())
# Out:
# 0.6744502186775208
# 0.4926304519176483

# %% [markdown]
# Regularized Training of a Neural Network in Pytorch

# %%
import torch as t
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt

# Regularization
# Deep neural networks are prone to overfitting if there is not much data available during training.

# Define hyperparameters
number_of_input_features = 11
number_of_hidden_units = 10
epochs = 200
learning_rate = 0.001
batch_size = 25
landa = 0.01  # Regularization term (lambda)

# Prepare the data
X_train_tensor = t.Tensor(X_train).type(t.float32)
Y_train_tensor = t.Tensor(Y_train).type(t.float32)

X_valid_tensor = t.Tensor(X_test).type(t.float32)
Y_valid_tensor = t.Tensor(Y_test).type(t.float32)

train_dataset = TensorDataset(X_train_tensor, Y_train_tensor)
train_data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Define the neural network model with regularization
model = nn.Sequential(
    nn.Linear(number_of_input_features, number_of_hidden_units),  # Linear layer for matrix multiplication and bias addition
    nn.Tanh(),  # Tanh activation function
    nn.Linear(number_of_hidden_units, 1),  # Another linear layer
    nn.Sigmoid()  # Sigmoid activation for probability output
)

# Define the optimizer
optimizer = Adam(model.parameters(), lr=learning_rate)

# Define the loss function with Binary Cross-Entropy Loss
loss_fn = nn.BCELoss()

# Lists to store training accuracy, validation accuracy, and training loss over epochs
train_accuracy_list = []
validation_accuracy_list = []
train_loss_list = []
train_recall_list = []
valid_recall_list = []

for epoch in range(epochs):
    if epoch % 500 == 0:
        learning_rate *= 0.9  # Learning rate scheduling

    per_epoch_loss_list = []

    for batch_idx, (X, Y) in enumerate(train_data_loader):
        # Forward pass: Compute predictions
        probs = model(X)

        # Adding regularization term for all parameters in the model
        l2_term = sum([(w ** 2).sum() for w in model.parameters()])

        # New loss is the old loss + regularization term
        loss = loss_fn(probs.view(-1), Y) + landa * l2_term

        per_epoch_loss_list.append(loss.item())

        # Backward pass: Compute gradient and update weights
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Evaluate the model on training and validation data
    with t.no_grad():
        # Set the model in eval mode; some layers use this for certain calculations during training
        model.eval()

        # Calculate accuracy on train data
        probs = model(X_train_tensor)
        prediction = (probs >= 0.5).type(t.LongTensor).view(-1)
        train_accuracy = (prediction == Y_train_tensor).type(t.float32).mean().item()

        TP_train = t.sum((prediction == 1) & (Y_train_tensor == 1)).item()
        FN_train = t.sum((prediction == 0) & (Y_train_tensor == 1)).item()
        recall_train = TP_train / (TP_train + FN_train)

        # Calculate accuracy on validation data
        probs = model(X_valid_tensor)
        prediction = (probs >= 0.5).type(t.LongTensor).view(-1)
        validation_accuracy = (prediction == Y_valid_tensor).type(t.float32).mean().item()

        TP_valid = t.sum((prediction == 1) & (Y_valid_tensor == 1)).item()
        FN_valid = t.sum((prediction == 0) & (Y_valid_tensor == 1)).item()
        recall_valid = TP_valid / (TP_valid + FN_valid)

        # Print accuracy for the current epoch
        print(f'Epoch {epoch}/{epochs} ---> Train Accuracy: {train_accuracy}, Validation Accuracy: {validation_accuracy}')
        print(f'epoch {epoch}/{epochs} ---> train_recall : {recall_train} , valid_recall : {recall_valid}')

        model.train()
        train_recall_list.append(recall_train)
        valid_recall_list.append(recall_valid)

        # Set the model back to train mode
        model.train()

        # Append accuracy values to lists
        train_accuracy_list.append(train_accuracy)
        validation_accuracy_list.append(validation_accuracy)

    # Calculate and append the average loss for the epoch
    train_loss_list.append(sum(per_epoch_loss_list) / len(per_epoch_loss_list))
# Out:
# Epoch 0/200 ---> Train Accuracy: 0.6771309971809387, Validation Accuracy: 0.6645885109901428
# epoch 0/200 ---> train_recall : 0.5781650435674013 , valid_recall : 0.6054216867469879
# Epoch 1/200 ---> Train Accuracy: 0.7020789980888367, Validation Accuracy: 0.7044887542724609
# epoch 1/200 ---> train_recall : 0.5166581240389544 , valid_recall : 0.5783132530120482
# Epoch 2/200 ---> Train Accuracy: 0.7043659090995789, Validation Accuracy: 0.6970074772834778
# epoch 2/200 ---> train_recall : 0.5325474115838031 , valid_recall : 0.5753012048192772
# Epoch 3/200 ---> Train Accuracy: 0.7043659090995789, Validation Accuracy: 0.6970074772834778
# epoch 3/200 ---> train_recall : 0.521783700666325 , valid_recall : 0.5692771084337349
# Epoch 4/200 ---> Train Accuracy: 0.7027027010917664, Validation Accuracy: 0.6957606077194214
# epoch 4/200 ---> train_recall : 0.5356227575602255 , valid_recall : 0.5753012048192772
# Epoch 5/200 ---> Train Accuracy: 0.7037422060966492, Validation Accuracy: 0.6982543468475342
# epoch 5/200 ---> train_recall : 0.5228088159917991 , valid_recall : 0.572289156626506
# Epoch 6/200 ---> Train Accuracy: 0.7039501070976257, Validation Accuracy: 0.6995012760162354
# epoch 6/200 ---> train_recall : 0.5274218349564326 , valid_recall : 0.5753012048192772
# Epoch 7/200 ---> Train Accuracy: 0.7045738101005554, Validation Accuracy: 0.7007481455802917
# epoch 7/200 ---> train_recall : 0.5202460276781138 , valid_recall : 0.5753012048192772
# Epoch 8/200 ---> Train Accuracy: 0.7072765231132507, Validation Accuracy: 0.7057356834411621
# epoch 8/200 ---> train_recall : 0.5238339313172732 , valid_recall : 0.5753012048192772
# Epoch 9/200 ---> Train Accuracy: 0.7045738101005554, Validation Accuracy: 0.7007481455802917
# epoch 9/200 ---> train_recall : 0.5279343926191696 , valid_recall : 0.5783132530120482
# Epoch 10/200 ---> Train Accuracy: 0.7043659090995789, Validation Accuracy: 0.7007481455802917
# epoch 10/200 ---> train_recall : 0.5335725269092773 , valid_recall : 0.5813253012048193
# Epoch 11/200 ---> Train Accuracy: 0.7024948000907898, Validation Accuracy: 0.6982543468475342
# epoch 11/200 ---> train_recall : 0.5366478728856996 , valid_recall : 0.5753012048192772
# Epoch 12/200 ---> Train Accuracy: 0.7051975131034851, Validation Accuracy: 0.6995012760162354
# epoch 12/200 ---> train_recall : 0.5202460276781138 , valid_recall : 0.5692771084337349
# Epoch 13/200 ---> Train Accuracy: 0.7022868990898132, Validation Accuracy: 0.694513738155365
# epoch 13/200 ---> train_recall : 0.5207585853408508 , valid_recall : 0.5632530120481928
# Epoch 14/200 ---> Train Accuracy: 0.7054054141044617, Validation Accuracy: 0.7019950151443481
# epoch 14/200 ---> train_recall : 0.5187083546899026 , valid_recall : 0.5753012048192772
# Epoch 15/200 ---> Train Accuracy: 0.7056133151054382, Validation Accuracy: 0.7094762921333313
# epoch 15/200 ---> train_recall : 0.5192209123526397 , valid_recall : 0.5783132530120482
# Epoch 16/200 ---> Train Accuracy: 0.7058212161064148, Validation Accuracy: 0.6995012760162354
# epoch 16/200 ---> train_recall : 0.5274218349564326 , valid_recall : 0.5753012048192772
# Epoch 17/200 ---> Train Accuracy: 0.7064449191093445, Validation Accuracy: 0.6995012760162354
# epoch 17/200 ---> train_recall : 0.5284469502819067 , valid_recall : 0.
200 ---> train_recall : 0.5171706817016914 , valid_recall : 0.5753012048192772
# Epoch 197/200 ---> Train Accuracy: 0.7058212161064148, Validation Accuracy: 0.7069825530052185
# epoch 197/200 ---> train_recall : 0.5166581240389544 , valid_recall : 0.572289156626506
# Epoch 198/200 ---> Train Accuracy: 0.7029106020927429, Validation Accuracy: 0.6995012760162354
# epoch 198/200 ---> train_recall : 0.5279343926191696 , valid_recall : 0.572289156626506
# Epoch 199/200 ---> Train Accuracy: 0.703326404094696, Validation Accuracy: 0.6995012760162354
# epoch 199/200 ---> train_recall : 0.522296258329062 , valid_recall : 0.5662650602409639

# %%
# Plot training and validation accuracy over epochs
plt.plot([i for i in range(len(train_accuracy_list))], train_accuracy_list, label="Train")
plt.plot([i for i in range(len(validation_accuracy_list))], validation_accuracy_list, label="Validation")
plt.legend(loc="upper left")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
# Plot training and validation recall over epochs
plt.plot([i for i in range(len(train_recall_list))], train_recall_list, label="Train")
plt.plot([i for i in range(len(valid_recall_list))], valid_recall_list, label="Validation")
plt.legend(loc="upper left")
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.show()

# %% [markdown]
# Neural Network with Dropout with Validation set

# %%
from sklearn.metrics import roc_auc_score, confusion_matrix, precision_score
number_of_input_features = 11  # Number of input features in the dataset

#from grid search:
#Hyperparameters: {'learning_rate': 0.001, 'batch_size': 25, 'number_of_hidden_units': 10, 'dropout_probability': 0.5}
#Validation Accuracy: 0.7331671118736267

# Reduced number of hidden units to 5 and just using 1 hidden layer
number_of_hidden_units = 10  # Number of hidden units in the neural network
epochs = 200  # Number of training epochs
learning_rate = 0.001  # Learning rate for the optimizer
batch_size = 25  # Number of samples in each training batch
dropout_probablity = 0.5  # Probability of dropping out a neuron in dropout layer

# Convert training and validation data to PyTorch tensors
X_train_tensor = t.Tensor(X_train).type(t.float32)
Y_train_tensor = t.Tensor(Y_train).type(t.float32)
X_valid_tensor = t.Tensor(X_valid).type(t.float32)
Y_valid_tensor = t.Tensor(Y_valid).type(t.float32)

# Create a training dataset and data loader
train_dataset = TensorDataset(X_train_tensor, Y_train_tensor)
train_data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Define the neural network model
model = Sequential(
    Linear(number_of_input_features, number_of_hidden_units),  # Linear layer for matrix multiplication and bias addition
    Tanh(),  # Add Tanh activation function
    Dropout(dropout_probablity),  # Dropout layer to prevent overfitting
    Linear(number_of_hidden_units, 1),  # Another linear layer
    Sigmoid()  # Sigmoid activation for probability output
)

# Define the optimizer
optimizer = Adam(model.parameters(), lr=learning_rate)

# Define the loss function as Binary Cross-Entropy Loss
loss_fn = t.nn.BCELoss()

train_accuracy_list = []  # List to store training accuracy
valid_accuracy_list = []  # List to store validation accuracy
train_recall_list = []
valid_recall_list = []

for epoch in range(epochs):
    if epoch % 500 == 0:
        learning_rate *= 0.9  # Learning rate scheduling

    per_epoch_loss_list = []  # List to store losses for each epoch

    for batch_idx, (X, Y) in enumerate(train_data_loader):
        # Forward pass: Compute predictions
        probs = model(X)

        # Calculate the loss
        loss = loss_fn(probs.view(-1), Y)
        per_epoch_loss_list.append(loss.item())

        # Backward pass: Compute gradients and update weights
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Evaluate the model on training and validation data
    with t.no_grad():
        # Set the model in eval mode; some layers use this for certain calculations during training
        model.eval()

        # Calculate accuracy on train data
        probs = model(X_train_tensor)
        prediction = (probs >= 0.5).type(t.LongTensor).view(-1)
        train_accuracy = (prediction == Y_train_tensor).type(t.float32).mean().item()

        TP_train = t.sum((prediction == 1) & (Y_train_tensor == 1)).item()
        FN_train = t.sum((prediction == 0) & (Y_train_tensor == 1)).item()
        recall_train = TP_train / (TP_train + FN_train)

        # Calculate accuracy on validation data
        probs = model(X_valid_tensor)
        prediction = (probs >= 0.5).type(t.LongTensor).view(-1)
        valid_accuracy = (prediction == Y_valid_tensor).type(t.float32).mean().item()

        TP_valid = t.sum((prediction == 1) & (Y_valid_tensor == 1)).item()
        FN_valid = t.sum((prediction == 0) & (Y_valid_tensor == 1)).item()
        recall_valid = TP_valid / (TP_valid + FN_valid)

        conf_matrix_test = confusion_matrix(Y_valid_tensor, prediction)
        TN_valid = conf_matrix_test[0, 0]
        FP_valid = conf_matrix_test[0, 1]
        TP_valid = conf_matrix_test[1, 1]
        FN_valid = conf_matrix_test[1, 0]

        # Calculate AUC
        auc_valid = roc_auc_score(Y_valid_tensor.numpy(), probs.numpy())

        # Calculate precision
        precision_valid = precision_score(Y_valid_tensor.numpy(), prediction.numpy())

        print(f'epoch {epoch}/{epochs} ---> train_accuracy: {train_accuracy}, valid_accuracy: {valid_accuracy}')
        print(f'epoch {epoch}/{epochs} ---> train_recall : {recall_train} , valid_recall : {recall_valid}')
        print(f'epoch {epoch}/{epochs} ---> TN_valid: {TN_valid}, FP_valid: {FP_valid}, TP_valid: {TP_valid}, FN_valid: {FN_valid}')
        print(f'epoch {epoch}/{epochs} ---> AUC_valid: {auc_valid}')
        print(f'epoch {epoch}/{epochs} ---> Precision_valid: {precision_valid}')

        model.train()
        train_recall_list.append(recall_train)
        valid_recall_list.append(recall_valid)

        # Set the model back to train mode
        model.train()

        # Append accuracy values to lists
        train_accuracy_list.append(train_accuracy)
        valid_accuracy_list.append(valid_accuracy)
# Out:
# epoch 0/200 ---> train_accuracy: 0.6846153736114502, valid_accuracy: 0.6708229184150696
# epoch 0/200 ---> train_recall : 0.48539210661199383 , valid_recall : 0.4864864864864865
# epoch 0/200 ---> TN_valid: 376, FP_valid: 93, TP_valid: 162, FN_valid: 171
# epoch 0/200 ---> AUC_valid: 0.6970744731938762
# epoch 0/200 ---> Precision_valid: 0.6352941176470588
# epoch 1/200 ---> train_accuracy: 0.6958419680595398, valid_accuracy: 0.6745635867118835
# epoch 1/200 ---> train_recall : 0.5064069707842133 , valid_recall : 0.4954954954954955
# epoch 1/200 ---> TN_valid: 376, FP_valid: 93, TP_valid: 165, FN_valid: 168
# epoch 1/200 ---> AUC_valid: 0.70932339589056
# epoch 1/200 ---> Precision_valid: 0.6395348837209303
# epoch 2/200 ---> train_accuracy: 0.7012473940849304, valid_accuracy: 0.6758104562759399
# epoch 2/200 ---> train_recall : 0.5074320861096874 , valid_recall : 0.4954954954954955
# epoch 2/200 ---> TN_valid: 377, FP_valid: 92, TP_valid: 165, FN_valid: 168
# epoch 2/200 ---> AUC_valid: 0.7128898621435934
# epoch 2/200 ---> Precision_valid: 0.642023346303502
# epoch 3/200 ---> train_accuracy: 0.7041580080986023, valid_accuracy: 0.6783042550086975
# epoch 3/200 ---> train_recall : 0.5176832393644285 , valid_recall : 0.5105105105105106
# epoch 3/200 ---> TN_valid: 374, FP_valid: 95, TP_valid: 170, FN_valid: 163
# epoch 3/200 ---> AUC_valid: 0.7149516253993866
# epoch 3/200 ---> Precision_valid: 0.6415094339622641
# epoch 4/200 ---> train_accuracy: 0.7062370181083679, valid_accuracy: 0.6795511245727539
# epoch 4/200 ---> train_recall : 0.5125576627370579 , valid_recall : 0.5075075075075075
# epoch 4/200 ---> TN_valid: 376, FP_valid: 93, TP_valid: 169, FN_valid: 164
# epoch 4/200 ---> AUC_valid: 0.7164947463454927
# epoch 4/200 ---> Precision_valid: 0.6450381679389313
# epoch 5/200 ---> train_accuracy: 0.7062370181083679, valid_accuracy: 0.6795511245727539
# epoch 5/200 ---> train_recall : 0.5176832393644285 , valid_recall : 0.5105105105105106
# epoch 5/200 ---> TN_valid: 375, FP_valid: 94, TP_valid: 170, FN_valid: 163
# epoch 5/200 ---> AUC_valid: 0.7161553877971787
# epoch 5/200 ---> Precision_valid: 0.6439393939393939
# epoch 6/200 ---> train_accuracy: 0.7049896121025085, valid_accuracy: 0.6783042550086975
# epoch 6/200 ---> train_recall : 0.5238339313172732 , valid_recall : 0.5165165165165165
# epoch 6/200 ---> TN_valid: 372, FP_valid: 97, TP_valid: 172, FN_valid: 161
# epoch 6/200 ---> AUC_valid: 0.7165907912176568
# epoch 6/200 ---> Precision_valid: 0.6394052044609665
# epoch 7/200 ---> train_accuracy: 0.7043659090995789, valid_accuracy: 0.6708229184150696
# epoch 7/200 ---> train_recall : 0.5279343926191696 , valid_recall : 0.5105105105105106
# epoch 7/200 ---> TN_valid: 368, FP_valid: 101, TP_valid: 170, FN_valid: 163
# epoch 7/200 ---> AUC_valid: 0.7168597168597168
# epoch 7/200 ---> Precision_valid: 0.6273062730627307
# epoch 8/200 ---> train_accuracy: 0.7062370181083679, valid_accuracy: 0.6720698475837708
# epoch 8/200 ---> train_recall : 0.5228088159917991 , valid_recall : 0.5075075075075075
# epoch 8/200 ---> TN_valid: 370, FP_valid: 99, TP_valid: 169, FN_valid: 164
# epoch 8/200 ---> AUC_valid: 0.7174808070330458
# epoch 8/200 ---> Precision_valid: 0.6305970149253731
# epoch 9/200 ---> train_accuracy: 0.7070686221122742, valid_accuracy: 0.6733167171478271
# epoch 9/200 ---> train_recall : 0.5228088159917991 , valid_recall : 0.5075075075075075
# epoch 9/200 ---> TN_valid: 371, FP_valid: 98, TP_valid: 169, FN_valid: 164
# epoch 9/200 ---> AUC_valid: 0.7177561356665835
# epoch 9/200 ---> Precision_valid: 0.6329588014981273
# epoch 10/200 ---> train_accuracy: 0.7054054141044617, valid_accuracy: 0.6733167171478271
# epoch 10/200 ---> train_recall : 0.5212711430035879 , valid_recall : 0.5075075075075075
# epoch 10/200 ---> TN_valid: 371, FP_valid: 98, TP_valid: 169, FN_valid: 164
# epoch 10/200 ---> AUC_valid: 0.7176088668625982
# epoch 10/200 ---> Precision_valid: 0.6329588014981273
# epoch 11/200 ---> train_accuracy: 0.706652820110321, valid_accuracy: 0.6708229184150696
# epoch 11/200 ---> train_recall : 0.5284469502819067 , valid_recall : 0.5105105105105106
# epoch 11/200 ---> TN_valid: 368, FP_valid: 101, TP_valid: 170, FN_valid: 163
# epoch 11/200 ---> AUC_valid: 0.7173527472034934
# epoch 11/200 ---> Precision_valid: 0.6273062730627307
# epoch 12/200 ---> train_accuracy: 0.7039501070976257, valid_accuracy: 0.6708229184150696
# epoch 12/200 ---> train_recall : 0.5284469502819067 , valid_recall : 0.5165165165165165
# epoch 12/200 ---> TN_valid: 366, FP_valid: 103, TP_valid: 172, FN_valid: 161
# epoch 12/200 ---> AUC_valid: 0.7170197916466574
# epoch 12/200 ---> Precision_valid: 0.6254545454545455
# epoch 13/200 ---> train_accuracy: 0.7027027010917664, valid_accuracy: 0.6720698475837708
# epoch 13/200 ---> train_recall : 0.5299846232701179 , valid_recall : 0.5165165165165165
# epoch 13/200 ---> TN_valid: 367, FP_valid: 102, TP_valid: 172, FN_valid: 161
# epoch 13/200 ---> AUC_valid: 0.7172246873739411
# epoch 13/200 ---> Precision_valid: 0.6277372262773723
# epoch 14/200 ---> train_accuracy: 0.7049896121025085, valid_accuracy: 0.6720698475837708
# epoch 14/200 ---> train_recall : 0.5258841619682214 , valid_recall : 0.5135135135135135
# epoch 14/200 ---> TN_valid: 368, FP_valid: 101, TP_valid: 171, FN_valid: 162
# epoch 14/200 ---> AUC_valid: 0.717679299768852
# epoch 14/200 ---> Precision_valid: 0.6286764705882353
# epoch 15/200 ---> train_accuracy: 0.7054054141044617, valid_accuracy: 0.6720698475837708
# epoch 15/200 ---> train_recall : 0.5284469502819067 , valid_recall : 0.5135135135135135
# epoch 15/200 ---> TN_valid: 368, FP_valid: 101, TP_valid: 171, FN_valid: 162
# epoch 15/200 ---> AUC_valid: 0.7174487920756578
# epoch 15/200 ---> Precision_valid: 0.6286764705882353
# epoch 16/200 ---> train_accuracy: 0.7060291171073914, valid_accuracy: 0.6770573854446411
# epoch 16/200 ---> train_recall : 0.5284469502819067 , valid_recall : 0.5195195195195195
# epoch 16/200 ---> TN_valid: 370, FP_valid: 99, TP_valid: 173, FN_valid: 160
# epoch 16/200 ---> AUC_valid: 0.7179738373768224
# epoch 16/200 ---> Precision_valid: 0.6360294117647058
# epoch 17/200 ---> train_accuracy: 0.7083160281181335, valid_accuracy: 0.6770573854446411
# epoch 17/200 ---> train_recall : 0.5269092772936955 , valid_recall : 0.5135135135135135
# epoch 17/200 ---> TN_valid: 372, FP_valid: 97, TP_valid: 171, FN_valid: 162
# epoch 17/200 ---> AUC_valid: 0.7183067929336584
# epoch 17/200 ---> Precision_valid: 0.6380597014925373
# epoch 18/200 ---> train_accuracy: 0.704781711101532, valid_accuracy: 0.6708229184150696
# epoch 18/200 ---> train_recall : 0.5299846232701179 , valid_recall : 0.5135135135135135
# epoch 18/200 ---> TN_valid: 367, FP_valid: 102, TP_valid: 171, FN_valid: 162
# epoch 18/200 ---> AUC_valid: 0.7173719561779264
# epoch 18/200 ---> Precision_valid: 0.6263736263736264
# epoch 19/200 ---> train_accuracy: 0.7056133151054382, valid_accuracy: 0.6708229184150696
# epoch 19/200 ---> train_recall : 0.5274218349564326 , valid_recall : 0.5135135135135135
# epoch 19/200 ---> TN_valid: 367, FP_valid: 102, TP_valid: 171, FN_valid: 162
# epoch 19/200 ---> AUC_valid: 0.7178329715643148
# epoch 19/200 ---> Precision_valid: 0.6263736263736264
# epoch 20/200 ---> train_accuracy: 0.7045738101005554, valid_accuracy: 0.6720698475837708
# epoch 20/200 ---> train_recall : 0.5284469502819067 , valid_recall : 0.5165165165165165
# epoch 20/200 ---> TN_valid: 367, FP_valid: 102, TP_valid: 172, FN_valid: 161
# epoch 20/200 ---> AUC_valid: 0.7177369266921505
# epoch 20/200 ---> Precision_valid: 0.6277372262773723
# epoch 21/200 ---> train_accuracy: 0.704781711101532, valid_accuracy: 0.6695760488510132
# epoch 21/200 ---> train_recall : 0.5345976422347514 , valid_recall : 0.5195195195195195
# epoch 21/200 ---> TN_valid: 364, FP_valid: 105, TP_valid: 173, FN_valid: 160
# epoch 21/200 ---> AUC_valid: 0.7175576429307772
# epoch 21/200 ---> Precision_valid: 0.6223021582733813
# epoch 22/200 ---> train_accuracy: 0.7072765231132507, valid_accuracy: 0.6708229184150696
# epoch 22/200 ---> train_recall : 0.5299846232701179 , valid_recall : 0.5135135135135135
# epoch 22/200 ---> TN_valid: 367, FP_valid: 102, TP_valid: 171, FN_valid: 162
# epoch 22/200 ---> AUC_valid: 0.7176728967773744
# epoch 22/200 ---> Precision_valid: 0.6263736263736264
# epoch 23/200 ---> train_accuracy: 0.7072765231132507, valid_accuracy: 0.6745635867118835
# epoch 23/200 ---> train_recall : 0.531522296258329 , valid_recall : 0.5225225225225225
# epoch 23/200 ---> TN_valid: 367, FP_valid: 102, TP_valid: 174, FN_valid: 159
# epoch 23/200 ---> AUC_valid: 0.717679299768852
# epoch 23/200 ---> Precision_valid: 0.6304347826086957
# epoch 24/200 ---> train_accuracy: 0.7064449191093445, valid_accuracy: 0.6733167171478271
# epoch 24/200 ---> train_recall : 0.5299846232701179 , valid_recall : 0.5165165165165165
# epoch 24/200 ---> TN_valid: 368, FP_valid: 101, TP_valid: 172, FN_valid: 161
# epoch 24/200 ---> AUC_valid: 0.7179994493427329
# epoch 24/200 ---> Precision_valid: 0.63003663003663
# epoch 25/200 ---> train_accuracy: 0.7072765231132507, valid_accuracy: 0.6733167171478271
# epoch 25/200 ---> train_recall : 0.5294720656073808 , valid_recall : 0.5105105105105106
# epoch 25/200 ---> TN_valid: 370, FP_valid: 99, TP_valid: 170, FN_valid: 163
# epoch 25/200 ---> AUC_valid: 0.7182939869507032
# epoch 25/200 ---> Precision_valid: 0.6319702602230484
# epoch 26/200 ---> train_accuracy: 0.7049896121025085, valid_accuracy: 0.6733167171478271
# epoch 26/200 ---> train_recall : 0.5304971809328549 , valid_recall : 0.5165165165165165
# epoch 26/200 ---> TN_valid: 368, FP_valid: 101, TP_valid: 172, FN_valid: 161
# epoch 26/200 ---> AUC_valid: 0.7185565096012858
# epoch 26/200 ---> Precision_valid: 0.63003663003663
# epoch 27/200 ---> train_accuracy: 0.7076923251152039, valid_accuracy: 0.6770573854446411
# epoch 27/200 ---> train_recall : 0.5325474115838031 , valid_recall : 0.5225225225225225
# epoch 27/200 ---> TN_valid: 369, FP_valid: 100, TP_valid: 174, FN_valid: 159
# epoch 27/200 ---> AUC_valid: 0.718466867720599
# epoch 27/200 ---> Precision_valid: 0.635036496350365
# epoch 28/200 ---> train_accuracy: 0.7064449191093445, valid_accuracy: 0.6745635867118835
# epoch 28/200 ---> train_recall : 0.5335725269092773 , valid_recall : 0.5195195195195195
# epoch 28/200 ---> TN_valid: 368, FP_valid: 101, TP_valid: 173, FN_valid: 160
# epoch 28/200 ---> AUC_valid: 0.7184924796865094
# epoch 28/200 ---> Precision_valid: 0.6313868613138686
# epoch 29/200 ---> train_accuracy: 0.7074844241142273, valid_accuracy: 0.6758104562759399
# epoch 29/200 ---> train_recall : 0.5289595079446437 , valid_recall : 0.5135135135135135
# epoch 29/200 ---> TN_valid: 371, FP_valid: 98, TP_valid: 171, FN_valid: 162
# epoch 29/200 ---> AUC_valid: 0.7191647937916597
# epoch 29/200 ---> Precision_valid: 0.6356877323420075
# epoch 30/200 ---> train_accuracy: 0.7076923251152039, valid_accuracy: 0.6770573854446411
# epoch 30/200 ---> train_recall : 0.5304971809328549 , valid_recall : 0.5195195195195195
# epoch 30/200 ---> TN_valid: 370, FP_valid: 99, TP_valid: 173, FN_valid: 160
# epoch 30/200 ---> AUC_valid: 0.719087957893928
# epoch 30/200 ---> Precision_valid: 0.6360294117647058
# epoch 31/200 ---> train_accuracy: 0.7091476321220398, valid_accuracy: 0.6770573854446411
# epoch 31/200 ---> train_recall : 0.5279343926191696 , valid_recall : 0.5105105105105106
# epoch 31/200 ---> TN_valid: 373, FP_valid: 96, TP_valid: 170, FN_valid: 163
# epoch 31/200 ---> AUC_valid: 0.7193504805445103
# epoch 31/200 ---> Precision_valid: 0.6390977443609023
# epoch 32/200 ---> train_accuracy: 0.7068607211112976, valid_accuracy: 0.6795511245727539
# epoch 32/200 ---> train_recall : 0.5325474115838031 , valid_recall : 0.5195195195195195
# epoch 32/200 ---> TN_valid: 372, FP_valid: 97, TP_valid: 173, FN_valid: 160
# epoch 32/200 ---> AUC_valid: 0.7192288237064357
# epoch 32/200 ---> Precision_valid: 0.6407407407407407
# epoch 33/200 ---> train_accuracy: 0.706652820110321, valid_accuracy: 0.6807979941368103
# epoch 33/200 ---> train_recall : 0.5294720656073808 , valid_recall : 0.5195195195195195
# epoch 33/200 ---> TN_valid: 373, FP_valid: 96, TP_valid: 173, FN_valid: 160
# epoch 33/200 ---> AUC_valid: 0.719625809178048
# epoch 33/200 ---> Precision_valid: 0.6431226765799256
# epoch 34/200 ---> train_accuracy: 0.7056133151054382, valid_accuracy: 0.6745635867118835
# epoch 34/200 ---> train_recall : 0.5345976422347514 , valid_recall : 0.5225225225225225
# epoch 34/200 ---> TN_valid: 367, FP_valid: 102, TP_valid: 174, FN_valid: 159
# epoch 34/200 ---> AUC_valid: 0.7196001972121375
# epoch 34/200 ---> Precision_valid: 0.6304347826086957
# epoch 35/200 ---> train_accuracy: 0.708108127117157, valid_accuracy: 0.6758104562759399
# epoch 35/200 ---> train_recall : 0.5335725269092773 , valid_recall : 0.5195195195195195
# epoch 35/200 ---> TN_valid: 369, FP_valid: 100, TP_valid: 173, FN_valid: 160
# epoch 35/200 ---> AUC_valid: 0.7196130031950927
# epoch 35/200 ---> Precision_valid: 0.6336996336996337
# epoch 36/200 ---> train_accuracy: 0.7101871371269226, valid_accuracy: 0.6795511245727539
# epoch 36/200 ---> train_recall : 0.5269092772936955 , valid_recall : 0.5105105105105106
# epoch 36/200 ---> TN_valid: 375, FP_valid: 94, TP_valid: 170, FN_valid: 163
# epoch 36/200 ---> AUC_valid: 0.7199779737093172
# epoch 36/200 ---> Precision_valid: 0.6439393939393939
# epoch 37/200 ---> train_accuracy: 0.708108127117157, valid_accuracy: 0.6758104562759399
# epoch 37/200 ---> train_recall : 0.531522296258329 , valid_recall : 0.5165165165165165
# epoch 37/200 ---> TN_valid: 370, FP_valid: 99, TP_valid: 172, FN_valid: 161
# epoch 37/200 ---> AUC_valid: 0.7198691228541975
# epoch 37/200 ---> Precision_valid: 0.6346863468634686
# epoch 38/200 ---> train_accuracy: 0.706652820110321, valid_accuracy: 0.6783042550086975
# epoch 38/200 ---> train_recall : 0.531009738595592 , valid_recall : 0.5195195195195195
# epoch 38/200 ---> TN_valid: 371, FP_valid: 98, TP_valid: 173, FN_valid: 160
# epoch 38/200 ---> AUC_valid: 0.7196834361013467
# epoch 38/200 ---> Precision_valid: 0.6383763837638377
# epoch 39/200 ---> train_accuracy: 0.7101871371269226, valid_accuracy: 0.6845386624336243
# epoch 39/200 ---> train_recall : 0.5212711430035879 , valid_recall : 0.5075075075075075
# epoch 39/200 ---> TN_valid: 380, FP_valid: 89, TP_valid: 169, FN_valid: 164
# epoch 39/200 ---> AUC_valid: 0.7202853173002426
# epoch 39/200 ---> Precision_valid: 0.6550387596899225
# epoch 40/200 ---> train_accuracy: 0.709979236125946, valid_accuracy: 0.6820448637008667
# epoch 40/200 ---> train_recall : 0.5269092772936955 , valid_recall : 0.5135135135135135
# epoch 40/200 ---> TN_valid: 376, FP_valid: 93, TP_valid: 171, FN_valid: 162
# epoch 40/200 ---> AUC_valid: 0.7205222279849145
# epoch 40/200 ---> Precision_valid: 0.6477272727272727
# epoch 41/200 ---> train_accuracy: 0.7076923251152039, valid_accuracy: 0.6783042550086975
# epoch 41/200 ---> train_recall : 0.5299846232701179 , valid_recall : 0.5195195195195195
# epoch 41/200 ---> TN_valid: 371, FP_valid: 98, TP_valid: 173, FN_valid: 160
# epoch 41/200 ---> AUC_valid: 0.720330138240586
# epoch 41/200 ---> Precision_valid: 0.6383763837638377
# epoch 42/200 ---> train_accuracy: 0.7076923251152039, valid_accuracy: 0.6832917928695679
# epoch 42/200 ---> train_recall : 0.5289595079446437 , valid_recall : 0.5165165165165165
# epoch 42/200 ---> TN_valid: 376, FP_valid: 93, TP_valid: 172, FN_valid: 161
# epoch 42/200 ---> AUC_valid: 0.7207975566184521
# epoch 42/200 ---> Precision_valid: 0.6490566037735849
# epoch 43/200 ---> train_accuracy: 0.7072765231132507, valid_accuracy: 0.6807979941368103
# epoch 43/200 ---> train_recall : 0.5304971809328549 , valid_recall : 0.5225225225225225
# epoch 43/200 ---> TN_valid: 372, FP_valid: 97, TP_valid: 174, FN_valid: 159
# epoch 43/200 ---> AUC_valid: 0.721386631834393
# epoch 43/200 ---> Precision_valid: 0.6420664206642066
# epoch 44/200 ---> train_accuracy: 0.7089397311210632, valid_accuracy: 0.6845386624336243
# epoch 44/200 ---> train_recall : 0.5279343926191696 , valid_recall : 0.5225225225225225
# epoch 44/200 ---> TN_valid: 375, FP_valid: 94, TP_valid: 174, FN_valid: 159
# epoch 44/200 ---> AUC_valid: 0.7213994378173482
# epoch 44/200 ---> Precision_valid: 0.6492537313432836
# epoch 45/200 ---> train_accuracy: 0.7093555331230164, valid_accuracy: 0.6857855319976807
# epoch 45/200 ---> train_recall : 0.5294720656073808 , valid_recall : 0.5225225225225225
# epoch 45/200 ---> TN_valid: 376, FP_valid: 93, TP_valid: 174, FN_valid: 159
# epoch 45/200 ---> AUC_valid: 0.7217419978614008
# epoch 45/200 ---> Precision_valid: 0.651685393258427
# epoch 46/200 ---> train_accuracy: 0.7083160281181335, valid_accuracy: 0.6832917928695679
# epoch 46/200 ---> train_recall : 0.5335725269092773 , valid_recall : 0.5285285285285285
# epoch 46/200 ---> TN_valid: 372, FP_valid: 97, TP_valid: 176, FN_valid: 157
# epoch 46/200 ---> AUC_valid: 0.7217644083315724
# epoch 46/200 ---> Precision_valid: 0.6446886446886447
# epoch 47/200 ---> train_accuracy: 0.7072765231132507, valid_accuracy: 0.6770573854446411
# epoch 47/200 ---> train_recall : 0.5351101998974884 , valid_recall : 0.5255255255255256
# epoch 47/200 ---> TN_valid: 368, FP_valid: 101, TP_valid: 175, FN_valid: 158
# epoch 47/200 ---> AUC_valid: 0.7217708113230501
# epoch 47/200 ---> Precision_valid: 0.6340579710144928
# epoch 48/200 ---> train_accuracy: 0.7054054141044617, valid_accuracy: 0.6795511245727539
# epoch 48/200 ---> train_recall : 0.531009738595592 , valid_recall : 0.5255255255255256
# epoch 48/200 ---> TN_valid: 370, FP_valid: 99, TP_valid: 175, FN_valid: 158
# epoch 48/200 ---> AUC_valid: 0.7217708113230502
# epoch 48/200 ---> Precision_valid: 0.6386861313868614
# epoch 49/200 ---> train_accuracy: 0.708108127117157, valid_accuracy: 0.6820448637008667
# epoch 49/200 ---> train_recall : 0.5284469502819067 , valid_recall : 0.5195195195195195
# epoch 49/200 ---> TN_valid: 374, FP_valid: 95, TP_valid: 173, FN_valid: 160
# epoch 49/200 ---> AUC_valid: 0.7214826767065572
# epoch 49/200 ---> Precision_valid: 0.6455223880597015
# epoch 50/200 ---> train_accuracy: 0.7085239291191101, valid_accuracy: 0.6820448637008667
# epoch 50/200 ---> train_recall : 0.5294720656073808 , valid_recall : 0.5195195195195195
# epoch 50/200 ---> TN_valid: 374, FP_valid: 95, TP_valid: 173, FN_valid: 160
# epoch 50/200 ---> AUC_valid: 0.7214122438003036
# epoch 50/200 ---> Precision_valid: 0.6455223880597015
# epoch 51/200 ---> train_accuracy: 0.7095634341239929, valid_accuracy: 0.6845386624336243
# epoch 51/200 ---> train_recall : 0.5299846232701179 , valid_recall : 0.5195195195195195
# epoch 51/200 ---> TN_valid: 376, FP_valid: 93, TP_valid: 173, FN_valid: 160
# epoch 51/200 ---> AUC_valid: 0.7217259903827068
# epoch 51/200 ---> Precision_valid: 0.650375939849624
# epoch 52/200 ---> train_accuracy: 0.7101871371269226, valid_accuracy: 0.6832917928695679
# epoch 52/200 ---> train_recall : 0.5263967196309585 , valid_recall : 0.5165165165165165
# epoch 52/200 ---> TN_valid: 376, FP_valid: 93, TP_valid: 172, FN_valid: 161
# epoch 52/200 ---> AUC_valid: 0.7224431254282
# epoch 52/200 ---> Precision_valid: 0.6490566037735849
# epoch 53/200 ---> train_accuracy: 0.7089397311210632, valid_accuracy: 0.6832917928695679
# epoch 53/200 ---> train_recall : 0.5299846232701179 , valid_recall : 0.5225225225225225
# epoch 53/200 ---> TN_valid: 374, FP_valid: 95, TP_valid: 174, FN_valid: 159
# epoch 53/200 ---> AUC_valid: 0.7220973638884086
# epoch 53/200 ---> Precision_valid: 0.6468401486988847
# epoch 54/200 ---> train_accuracy: 0.709979236125946, valid_accuracy: 0.6807979941368103
# epoch 54/200 ---> train_recall : 0.5253716043054844 , valid_recall : 0.5135135135135135
# epoch 54/200 ---> TN_valid: 375, FP_valid: 94, TP_valid: 171, FN_valid: 162
# epoch 54/200 ---> AUC_valid: 0.7223086626071701
# epoch 54/200 ---> Precision_valid: 0.6452830188679245
# epoch 55/200 ---> train_accuracy: 0.7074844241142273, valid_accuracy: 0.6795511245727539
# epoch 55/200 ---> train_recall : 0.531009738595592 , valid_recall : 0.5195195195195195
# epoch 55/200 ---> TN_valid: 372, FP_valid: 97, TP_valid: 173, FN_valid: 160
# epoch 55/200 ---> AUC_valid: 0.7224239164537671
# epoch 55/200 ---> Precision_valid: 0.6407407407407407
# epoch 56/200 ---> train_accuracy: 0.7095634341239929, valid_accuracy: 0.6795511245727539
# epoch 56/200 ---> train_recall : 0.5269092772936955 , valid_recall : 0.5165165165165165
# epoch 56/200 ---> TN_valid: 373, FP_valid: 96, TP_valid: 172, FN_valid: 161
# epoch 56/200 ---> AUC_valid: 0.7225007523514986
# epoch 56/200 ---> Precision_valid: 0.6417910447761194
# epoch 57/200 ---> train_accuracy: 0.7089397311210632, valid_accuracy: 0.6820448637008667
# epoch 57/200 ---> train_recall : 0.5238339313172732 , valid_recall : 0.5135135135135135
# epoch 57/200 ---> TN_valid: 376, FP_valid: 93, TP_valid: 171, FN_valid: 162
# epoch 57/200 ---> AUC_valid: 0.7223790955134238
# epoch 57/200 ---> Precision_valid: 0.6477272727272727
# epoch 58/200 ---> train_accuracy: 0.7097713351249695, valid_accuracy: 0.6857855319976807
# epoch 58/200 ---> train_recall : 0.5258841619682214 , valid_recall : 0.5165165165165165
# epoch 58/200 ---> TN_valid: 378, FP_valid: 91, TP_valid: 172, FN_valid: 161
# epoch 58/200 ---> AUC_valid: 0.7229041408145885
# epoch 58/200 ---> Precision_valid: 0.6539923954372624
# epoch 59/200 ---> train_accuracy: 0.7049896121025085, valid_accuracy: 0.6807979941368103
# epoch 59/200 ---> train_recall : 0.5325474115838031 , valid_recall : 0.5225225225225225
# epoch 59/200 ---> TN_valid: 372, FP_valid: 97, TP_valid: 174, FN_valid: 159
# epoch 59/200 ---> AUC_valid: 0.722359886538991
# epoch 59/200 ---> Precision_valid: 0.6420664206642066
# epoch 60/200 ---> train_accuracy: 0.708108127117157, valid_accuracy: 0.6882793307304382
# epoch 60/200 ---> train_recall : 0.5263967196309585 , valid_recall : 0.5225225225225225
# epoch 60/200 ---> TN_valid: 378, FP_valid: 91, TP_valid: 174, FN_valid: 159
# epoch 60/200 ---> AUC_valid: 0.7228016929509468
# epoch 60/200 ---> Precision_valid: 0.6566037735849056
# epoch 61/200 ---> train_accuracy: 0.7087318301200867, valid_accuracy: 0.6895262002944946
# epoch 61/200 ---> train_recall : 0.5294720656073808 , valid_recall : 0.5225225225225225
# epoch 61/200 ---> TN_valid: 379, FP_valid: 90, TP_valid: 174, FN_valid: 159
# epoch 61/200 ---> AUC_valid: 0.7231602604736933
# epoch 61/200 ---> Precision_valid: 0.6590909090909091
# epoch 62/200 ---> train_accuracy: 0.7101871371269226, valid_accuracy: 0.6920199394226074
# epoch 62/200 ---> train_recall : 0.5243464889800102 , valid_recall : 0.5135135135135135
# epoch 62/200 ---> TN_valid: 384, FP_valid: 85, TP_valid: 171, FN_valid: 162
# epoch 62/200 ---> AUC_valid: 0.723819768595888
# epoch 62/200 ---> Precision_valid: 0.66796875
# epoch 63/200 ---> train_accuracy: 0.7093555331230164, valid_accuracy: 0.690773069858551
# epoch 63/200 ---> train_recall : 0.5253716043054844 , valid_recall : 0.5165165165165165
# epoch 63/200 ---> TN_valid: 382, FP_valid: 87, TP_valid: 172, FN_valid: 161
# epoch 63/200 ---> AUC_valid: 0.7237621416725895
# epoch 63/200 ---> Precision_valid: 0.6640926640926641
# epoch 64/200 ---> train_accuracy: 0.7112265825271606, valid_accuracy: 0.694513738155365
# epoch 64/200 ---> train_recall : 0.5243464889800102 , valid_recall : 0.5195195195195195
# epoch 64/200 ---> TN_valid: 384, FP_valid: 85, TP_valid: 173, FN_valid: 160
# epoch 64/200 ---> AUC_valid: 0.7239670373998731
# epoch 64/200 ---> Precision_valid: 0.6705426356589147
# epoch 65/200 ---> train_accuracy: 0.7097713351249695, valid_accuracy: 0.690773069858551
# epoch 65/200 ---> train_recall : 0.5269092772936955 , valid_recall : 0.5195195195195195
# epoch 65/200 ---> TN_valid: 381, FP_valid: 88, TP_valid: 173, FN_valid: 160
# epoch 65/200 ---> AUC_valid: 0.7241911421015899
# epoch 65/200 ---> Precision_valid: 0.6628352490421456
# epoch 66/200 ---> train_accuracy: 0.7106029391288757, valid_accuracy: 0.6895262002944946
# epoch 66/200 ---> train_recall : 0.5263967196309585 , valid_recall : 0.5165165165165165
# epoch 66/200 ---> TN_valid: 381, FP_valid: 88, TP_valid: 172, FN_valid: 161
# epoch 66/200 ---> AUC_valid: 0.7245369036413812
# epoch 66/200 ---> Precision_valid: 0.6615384615384615
# epoch 67/200 ---> train_accuracy: 0.7093555331230164, valid_accuracy: 0.6882793307304382
# epoch 67/200 ---> train_recall : 0.5248590466427473 , valid_recall : 0.5195195195195195
# epoch 67/200 ---> TN_valid: 379, FP_valid: 90, TP_valid: 173, FN_valid: 160
# epoch 67/200 ---> AUC_valid: 0.724440858769217
# epoch 67/200 ---> Precision_valid: 0.6577946768060836
# epoch 68/200 ---> train_accuracy: 0.7087318301200867, valid_accuracy: 0.6882793307304382
# epoch 68/200 ---> train_recall : 0.5243464889800102 , valid_recall : 0.5195195195195195
# epoch 68/200 ---> TN_valid: 379, FP_valid: 90, TP_valid: 173, FN_valid: 160
# epoch 68/200 ---> AUC_valid: 0.724709784411277
# epoch 68/200 ---> Precision_valid: 0.6577946768060836
# epoch 69/200 ---> train_accuracy: 0.709979236125946, valid_accuracy: 0.6932668089866638
# epoch 69/200 ---> train_recall : 0.5248590466427473 , valid_recall : 0.5225225225225225
# epoch 69/200 ---> TN_valid: 382, FP_valid: 87, TP_valid: 174, FN_valid: 159
# epoch 69/200 ---> AUC_valid: 0.7250683519340236
# epoch 69/200 ---> Precision_valid: 0.6666666666666666
# epoch 70/200 ---> train_accuracy: 0.7091476321220398, valid_accuracy: 0.6845386624336243
# epoch 70/200 ---> train_recall : 0.531009738595592 , valid_recall : 0.5195195195195195
# epoch 70/200 ---> TN_valid: 376, FP_valid: 93, TP_valid: 173, FN_valid: 160
# epoch 70/200 ---> AUC_valid: 0.7245625156072918
# epoch 70/200 ---> Precision_valid: 0.650375939849624
# epoch 71/200 ---> train_accuracy: 0.7103950381278992, valid_accuracy: 0.6882793307304382
# epoch 71/200 ---> train_recall : 0.5253716043054844 , valid_recall : 0.5135135135135135
# epoch 71/200 ---> TN_valid: 381, FP_valid: 88, TP_valid: 171, FN_valid: 162
# epoch 71/200 ---> AUC_valid: 0.7248698591982174
# epoch 71/200 ---> Precision_valid: 0.6602316602316602
# epoch 72/200 ---> train_accuracy: 0.7110186815261841, valid_accuracy: 0.6895262002944946
# epoch 72/200 ---> train_recall : 0.5289595079446437 , valid_recall : 0.5195195195195195
# epoch 72/200 ---> TN_valid: 380, FP_valid: 89, TP_valid: 173, FN_valid: 160
# epoch 72/200 ---> AUC_valid: 0.7249787100533368
# epoch 72/200 ---> Precision_valid: 0.6603053435114504
# epoch 73/200 ---> train_accuracy: 0.7097713351249695, valid_accuracy: 0.6845386624336243
# epoch 73/200 ---> train_recall : 0.5274218349564326 , valid_recall : 0.5135135135135135
# epoch 73/200 ---> TN_valid: 378, FP_valid: 91, TP_valid: 171, FN_valid: 162
# epoch 73/200 ---> AUC_valid: 0.7250363369766355
# epoch 73/200 ---> Precision_valid: 0.6526717557251909
# epoch 74/200 ---> train_accuracy: 0.7108108401298523, valid_accuracy: 0.6845386624336243
# epoch 74/200 ---> train_recall : 0.5274218349564326 , valid_recall : 0.5135135135135135
# epoch 74/200 ---> TN_valid: 378, FP_valid: 91, TP_valid: 171, FN_valid: 162
# epoch 74/200 ---> AUC_valid: 0.7249338891129935
# epoch 74/200 ---> Precision_valid: 0.6526717557251909
# epoch 75/200 ---> train_accuracy: 0.71247398853302, valid_accuracy: 0.690773069858551
# epoch 75/200 ---> train_recall : 0.5238339313172732 , valid_recall : 0.5105105105105106
# epoch 75/200 ---> TN_valid: 384, FP_valid: 85, TP_valid: 170, FN_valid: 163
# epoch 75/200 ---> AUC_valid: 0.7256254121925765
# epoch 75/200 ---> Precision_valid: 0.6666666666666666
# epoch 76/200 ---> train_accuracy: 0.7110186815261841, valid_accuracy: 0.690773069858551
# epoch 76/200 ---> train_recall : 0.5243464889800102 , valid_recall : 0.5135135135135135
# epoch 76/200 ---> TN_valid: 383, FP_valid: 86, TP_valid: 171, FN_valid: 162
# epoch 76/200 ---> AUC_valid: 0.7261760694596515
# epoch 76/200 ---> Precision_valid: 0.6653696498054474
# epoch 77/200 ---> train_accuracy: 0.7079002261161804, valid_accuracy: 0.6845386624336243
# epoch 77/200 ---> train_recall : 0.5289595079446437 , valid_recall : 0.5225225225225225
# epoch 77/200 ---> TN_valid: 375, FP_valid: 94, TP_valid: 174, FN_valid: 159
# epoch 77/200 ---> AUC_valid: 0.7260095916812335
# epoch 77/200 ---> Precision_valid: 0.6492537313432836
# epoch 78/200 ---> train_accuracy: 0.709979236125946, valid_accuracy: 0.6895262002944946
# epoch 78/200 ---> train_recall : 0.5284469502819067 , valid_recall : 0.5255255255255256
# epoch 78/200 ---> TN_valid: 378, FP_valid: 91, TP_valid: 175, FN_valid: 158
# epoch 78/200 ---> AUC_valid: 0.7255998002266658
# epoch 78/200 ---> Precision_valid: 0.6578947368421053
# epoch 79/200 ---> train_accuracy: 0.7076923251152039, valid_accuracy: 0.6882793307304382
# epoch 79/200 ---> train_recall : 0.5299846232701179 , valid_recall : 0.5255255255255256
# epoch 79/200 ---> TN_valid: 377, FP_valid: 92, TP_valid: 175, FN_valid: 158
# epoch 79/200 ---> AUC_valid: 0.7255869942437108
# epoch 79/200 ---> Precision_valid: 0.6554307116104869
# epoch 80/200 ---> train_accuracy: 0.7110186815261841, valid_accuracy: 0.690773069858551
# epoch 80/200 ---> train_recall : 0.5228088159917991 , valid_recall : 0.5195195195195195
# epoch 80/200 ---> TN_valid: 381, FP_valid: 88, TP_valid: 173, FN_valid: 160
# epoch 80/200 ---> AUC_valid: 0.7257726809965617
# epoch 80/200 ---> Precision_valid: 0.6628352490421456
# epoch 81/200 ---> train_accuracy: 0.7101871371269226, valid_accuracy: 0.6932668089866638
# epoch 81/200 ---> train_recall : 0.5207585853408508 , valid_recall : 0.5225225225225225
# epoch 81/200 ---> TN_valid: 382, FP_valid: 87, TP_valid: 174, FN_valid: 159
# epoch 81/200 ---> AUC_valid: 0.7255869942437106
# epoch 81/200 ---> Precision_valid: 0.6666666666666666
# epoch 82/200 ---> train_accuracy: 0.709979236125946, valid_accuracy: 0.6895262002944946
# epoch 82/200 ---> train_recall : 0.5274218349564326 , valid_recall : 0.5195195195195195
# epoch 82/200 ---> TN_valid: 380, FP_valid: 89, TP_valid: 173, FN_valid: 160
# epoch 82/200 ---> AUC_valid: 0.7251900087720984
# epoch 82/200 ---> Precision_valid: 0.6603053435114504
# epoch 83/200 ---> train_accuracy: 0.709979236125946, valid_accuracy: 0.6932668089866638
# epoch 83/200 ---> train_recall : 0.5233213736545361 , valid_recall : 0.5135135135135135
# epoch 83/200 ---> TN_valid: 385, FP_valid: 84, TP_valid: 171, FN_valid: 162
# epoch 83/200 ---> AUC_valid: 0.7253180686016507
# epoch 83/200 ---> Precision_valid: 0.6705882352941176
# epoch 84/200 ---> train_accuracy: 0.7097713351249695, valid_accuracy: 0.6920199394226074
# epoch 84/200 ---> train_recall : 0.5253716043054844 , valid_recall : 0.5195195195195195
# epoch 84/200 ---> TN_valid: 382, FP_valid: 87, TP_valid: 173, FN_valid: 160
# epoch 84/200 ---> AUC_valid: 0.7253372775760836
# epoch 84/200 ---> Precision_valid: 0.6653846153846154
# epoch 85/200 ---> train_accuracy: 0.7097713351249695, valid_accuracy: 0.690773069858551
# epoch 85/200 ---> train_recall : 0.5274218349564326 , valid_recall : 0.5225225225225225
# epoch 85/200 ---> TN_valid: 380, FP_valid: 89, TP_valid: 174, FN_valid: 159
# epoch 85/200 ---> AUC_valid: 0.7257470690306512
# epoch 85/200 ---> Precision_valid: 0.6615969581749049
# epoch 86/200 ---> train_accuracy: 0.7097713351249695, valid_accuracy: 0.6920199394226074
# epoch 86/200 ---> train_recall : 0.5263967196309585 , valid_recall : 0.5195195195195195
# epoch 86/200 ---> TN_valid: 382, FP_valid: 87, TP_valid: 173, FN_valid: 160
# epoch 86/200 ---> AUC_valid: 0.7256510241584868
# epoch 86/200 ---> Precision_valid: 0.6653846153846154
# epoch 87/200 ---> train_accuracy: 0.7110186815261841, valid_accuracy: 0.6970074772834778
# epoch 87/200 ---> train_recall : 0.5248590466427473 , valid_recall : 0.5195195195195195
# epoch 87/200 ---> TN_valid: 386, FP_valid: 83, TP_valid: 173, FN_valid: 160
# epoch 87/200 ---> AUC_valid: 0.7265218309994429
# epoch 87/200 ---> Precision_valid: 0.67578125
# epoch 88/200 ---> train_accuracy: 0.7089397311210632, valid_accuracy: 0.6845386624336243
# epoch 88/200 ---> train_recall : 0.5304971809328549 , valid_recall : 0.5225225225225225
# epoch 88/200 ---> TN_valid: 375, FP_valid: 94, TP_valid: 174, FN_valid: 159
# epoch 88/200 ---> AUC_valid: 0.7258751288602034
# epoch 88/200 ---> Precision_valid: 0.6492537313432836
# epoch 89/200 ---> train_accuracy: 0.7106029391288757, valid_accuracy: 0.694513738155365
# epoch 89/200 ---> train_recall : 0.5269092772936955 , valid_recall : 0.5195195195195195
# epoch 89/200 ---> TN_valid: 384, FP_valid: 85, TP_valid: 173, FN_valid: 160
# epoch 89/200 ---> AUC_valid: 0.7267203237352491
# epoch 89/200 ---> Precision_valid: 0.6705426356589147
# epoch 90/200 ---> train_accuracy: 0.7097713351249695, valid_accuracy: 0.6895262002944946
# epoch 90/200 ---> train_recall : 0.5304971809328549 , valid_recall : 0.5255255255255256
# epoch 90/200 ---> TN_valid: 378, FP_valid: 91, TP_valid: 175, FN_valid: 158
# epoch 90/200 ---> AUC_valid: 0.726252905357383
# epoch 90/200 ---> Precision_valid: 0.6578947368421053
# epoch 91/200 ---> train_accuracy: 0.7116423845291138, valid_accuracy: 0.6957606077194214
# epoch 91/200 ---> train_recall : 0.5263967196309585 , valid_recall : 0.5165165165165165
# epoch 91/200 ---> TN_valid: 386, FP_valid: 83, TP_valid: 172, FN_valid: 161
# epoch 91/200 ---> AUC_valid: 0.7267459357011596
# epoch 91/200 ---> Precision_valid: 0.6745098039215687
# epoch 92/200 ---> train_accuracy: 0.7095634341239929, valid_accuracy: 0.6920199394226074
# epoch 92/200 ---> train_recall : 0.5279343926191696 , valid_recall : 0.
200 ---> TN_valid: 384, FP_valid: 85, TP_valid: 172, FN_valid: 161
# epoch 112/200 ---> AUC_valid: 0.7291854754541323
# epoch 112/200 ---> Precision_valid: 0.669260700389105
# epoch 113/200 ---> train_accuracy: 0.713929295539856, valid_accuracy: 0.690773069858551
# epoch 113/200 ---> train_recall : 0.531522296258329 , valid_recall : 0.5195195195195195
# epoch 113/200 ---> TN_valid: 381, FP_valid: 88, TP_valid: 173, FN_valid: 160
# epoch 113/200 ---> AUC_valid: 0.729608072891655
# epoch 113/200 ---> Precision_valid: 0.6628352490421456
# epoch 114/200 ---> train_accuracy: 0.7141371965408325, valid_accuracy: 0.6957606077194214
# epoch 114/200 ---> train_recall : 0.5243464889800102 , valid_recall : 0.5195195195195195
# epoch 114/200 ---> TN_valid: 385, FP_valid: 84, TP_valid: 173, FN_valid: 160
# epoch 114/200 ---> AUC_valid: 0.7297873566530282
# epoch 114/200 ---> Precision_valid: 0.6731517509727627
# epoch 115/200 ---> train_accuracy: 0.7118502855300903, valid_accuracy: 0.690773069858551
# epoch 115/200 ---> train_recall : 0.5258841619682214 , valid_recall : 0.5165165165165165
# epoch 115/200 ---> TN_valid: 382, FP_valid: 87, TP_valid: 172, FN_valid: 161
# epoch 115/200 ---> AUC_valid: 0.7294031771643712
# epoch 115/200 ---> Precision_valid: 0.6640926640926641
# epoch 116/200 ---> train_accuracy: 0.7137213945388794, valid_accuracy: 0.6932668089866638
# epoch 116/200 ---> train_recall : 0.5253716043054844 , valid_recall : 0.5195195195195195
# epoch 116/200 ---> TN_valid: 383, FP_valid: 86, TP_valid: 173, FN_valid: 160
# epoch 116/200 ---> AUC_valid: 0.729806565627461
# epoch 116/200 ---> Precision_valid: 0.667953667953668
# epoch 117/200 ---> train_accuracy: 0.7110186815261841, valid_accuracy: 0.6895262002944946
# epoch 117/200 ---> train_recall : 0.5294720656073808 , valid_recall : 0.5165165165165165
# epoch 117/200 ---> TN_valid: 381, FP_valid: 88, TP_valid: 172, FN_valid: 161
# epoch 117/200 ---> AUC_valid: 0.7297553416956402
# epoch 117/200 ---> Precision_valid: 0.6615384615384615
# epoch 118/200 ---> train_accuracy: 0.7118502855300903, valid_accuracy: 0.6932668089866638
# epoch 118/200 ---> train_recall : 0.5269092772936955 , valid_recall : 0.5165165165165165
# epoch 118/200 ---> TN_valid: 384, FP_valid: 85, TP_valid: 172, FN_valid: 161
# epoch 118/200 ---> AUC_valid: 0.729857789559282
# epoch 118/200 ---> Precision_valid: 0.669260700389105
# epoch 119/200 ---> train_accuracy: 0.7133055925369263, valid_accuracy: 0.6920199394226074
# epoch 119/200 ---> train_recall : 0.5228088159917991 , valid_recall : 0.5165165165165165
# epoch 119/200 ---> TN_valid: 383, FP_valid: 86, TP_valid: 172, FN_valid: 161
# epoch 119/200 ---> AUC_valid: 0.7296208788746101
# epoch 119/200 ---> Precision_valid: 0.6666666666666666
# epoch 120/200 ---> train_accuracy: 0.7116423845291138, valid_accuracy: 0.6957606077194214
# epoch 120/200 ---> train_recall : 0.5212711430035879 , valid_recall : 0.5195195195195195
# epoch 120/200 ---> TN_valid: 385, FP_valid: 84, TP_valid: 173, FN_valid: 160
# epoch 120/200 ---> AUC_valid: 0.7303636258860139
# epoch 120/200 ---> Precision_valid: 0.6731517509727627
# epoch 121/200 ---> train_accuracy: 0.71247398853302, valid_accuracy: 0.6957606077194214
# epoch 121/200 ---> train_recall : 0.5171706817016914 , valid_recall : 0.5195195195195195
# epoch 121/200 ---> TN_valid: 385, FP_valid: 84, TP_valid: 173, FN_valid: 160
# epoch 121/200 ---> AUC_valid: 0.7310295369996862
# epoch 121/200 ---> Precision_valid: 0.6731517509727627
# epoch 122/200 ---> train_accuracy: 0.7128897905349731, valid_accuracy: 0.6957606077194214
# epoch 122/200 ---> train_recall : 0.5187083546899026 , valid_recall : 0.5195195195195195
# epoch 122/200 ---> TN_valid: 385, FP_valid: 84, TP_valid: 173, FN_valid: 160
# epoch 122/200 ---> AUC_valid: 0.7308566562297907
# epoch 122/200 ---> Precision_valid: 0.6731517509727627
# epoch 123/200 ---> train_accuracy: 0.7128897905349731, valid_accuracy: 0.6957606077194214
# epoch 123/200 ---> train_recall : 0.5202460276781138 , valid_recall : 0.5195195195195195
# epoch 123/200 ---> TN_valid: 385, FP_valid: 84, TP_valid: 173, FN_valid: 160
# epoch 123/200 ---> AUC_valid: 0.7307478053746712
# epoch 123/200 ---> Precision_valid: 0.6731517509727627
# epoch 124/200 ---> train_accuracy: 0.7128897905349731, valid_accuracy: 0.6970074772834778
# epoch 124/200 ---> train_recall : 0.5228088159917991 , valid_recall : 0.5195195195195195
# epoch 124/200 ---> TN_valid: 386, FP_valid: 83, TP_valid: 173, FN_valid: 160
# epoch 124/200 ---> AUC_valid: 0.7299474314399688
# epoch 124/200 ---> Precision_valid: 0.67578125
# epoch 125/200 ---> train_accuracy: 0.7147608995437622, valid_accuracy: 0.6970074772834778
# epoch 125/200 ---> train_recall : 0.5115325474115838 , valid_recall : 0.5195195195195195
# epoch 125/200 ---> TN_valid: 386, FP_valid: 83, TP_valid: 173, FN_valid: 160
# epoch 125/200 ---> AUC_valid: 0.7306453575110292
# epoch 125/200 ---> Precision_valid: 0.67578125
# epoch 126/200 ---> train_accuracy: 0.7145529985427856, valid_accuracy: 0.6932668089866638
# epoch 126/200 ---> train_recall : 0.5120451050743209 , valid_recall : 0.5135135135135135
# epoch 126/200 ---> TN_valid: 385, FP_valid: 84, TP_valid: 171, FN_valid: 162
# epoch 126/200 ---> AUC_valid: 0.7307093874258052
# epoch 126/200 ---> Precision_valid: 0.6705882352941176
# epoch 127/200 ---> train_accuracy: 0.7149688005447388, valid_accuracy: 0.6982543468475342
# epoch 127/200 ---> train_recall : 0.5176832393644285 , valid_recall : 0.5195195195195195
# epoch 127/200 ---> TN_valid: 387, FP_valid: 82, TP_valid: 173, FN_valid: 160
# epoch 127/200 ---> AUC_valid: 0.7307606113576263
# epoch 127/200 ---> Precision_valid: 0.6784313725490196
# epoch 128/200 ---> train_accuracy: 0.7122660875320435, valid_accuracy: 0.6957606077194214
# epoch 128/200 ---> train_recall : 0.521783700666325 , valid_recall : 0.5195195195195195
# epoch 128/200 ---> TN_valid: 385, FP_valid: 84, TP_valid: 173, FN_valid: 160
# epoch 128/200 ---> AUC_valid: 0.730363625886014
# epoch 128/200 ---> Precision_valid: 0.6731517509727627
# epoch 129/200 ---> train_accuracy: 0.7145529985427856, valid_accuracy: 0.6957606077194214
# epoch 129/200 ---> train_recall : 0.5212711430035879 , valid_recall : 0.5195195195195195
# epoch 129/200 ---> TN_valid: 385, FP_valid: 84, TP_valid: 173, FN_valid: 160
# epoch 129/200 ---> AUC_valid: 0.7312472387099254
# epoch 129/200 ---> Precision_valid: 0.6731517509727627
# epoch 130/200 ---> train_accuracy: 0.7160083055496216, valid_accuracy: 0.7007481455802917
# epoch 130/200 ---> train_recall : 0.5140953357252691 , valid_recall : 0.5165165165165165
# epoch 130/200 ---> TN_valid: 390, FP_valid: 79, TP_valid: 172, FN_valid: 161
# epoch 130/200 ---> AUC_valid: 0.7322493068761726
# epoch 130/200 ---> Precision_valid: 0.6852589641434262
# epoch 131/200 ---> train_accuracy: 0.7149688005447388, valid_accuracy: 0.6982543468475342
# epoch 131/200 ---> train_recall : 0.5094823167606356 , valid_recall : 0.5105105105105106
# epoch 131/200 ---> TN_valid: 390, FP_valid: 79, TP_valid: 170, FN_valid: 163
# epoch 131/200 ---> AUC_valid: 0.7325534489713594
# epoch 131/200 ---> Precision_valid: 0.6827309236947792
# epoch 132/200 ---> train_accuracy: 0.715800404548645, valid_accuracy: 0.6970074772834778
# epoch 132/200 ---> train_recall : 0.5243464889800102 , valid_recall : 0.5195195195195195
# epoch 132/200 ---> TN_valid: 386, FP_valid: 83, TP_valid: 173, FN_valid: 160
# epoch 132/200 ---> AUC_valid: 0.7320796276020156
# epoch 132/200 ---> Precision_valid: 0.67578125
# epoch 133/200 ---> train_accuracy: 0.7130976915359497, valid_accuracy: 0.6970074772834778
# epoch 133/200 ---> train_recall : 0.5212711430035879 , valid_recall : 0.5195195195195195
# epoch 133/200 ---> TN_valid: 386, FP_valid: 83, TP_valid: 173, FN_valid: 160
# epoch 133/200 ---> AUC_valid: 0.7318875378576871
# epoch 133/200 ---> Precision_valid: 0.67578125
# epoch 134/200 ---> train_accuracy: 0.7147608995437622, valid_accuracy: 0.6982543468475342
# epoch 134/200 ---> train_recall : 0.513582778062532 , valid_recall : 0.5165165165165165
# epoch 134/200 ---> TN_valid: 388, FP_valid: 81, TP_valid: 172, FN_valid: 161
# epoch 134/200 ---> AUC_valid: 0.7315545823008509
# epoch 134/200 ---> Precision_valid: 0.6798418972332015
# epoch 135/200 ---> train_accuracy: 0.7141371965408325, valid_accuracy: 0.6970074772834778
# ...
# epoch 155/200 ---> train_recall : 0.5202460276781138 , valid_recall : 0.5165165165165165
# epoch 155/200 ---> TN_valid: 388, FP_valid: 81, TP_valid: 172, FN_valid: 161
# epoch 155/200 ---> AUC_valid: 0.7330400763236584
# epoch 155/200 ---> Precision_valid: 0.6798418972332015
# epoch 156/200 ---> train_accuracy: 0.7174636125564575, valid_accuracy: 0.6982543468475342
# epoch 156/200 ---> train_recall : 0.5181957970271656 , valid_recall : 0.5135135135135135
# epoch 156/200 ---> TN_valid: 389, FP_valid: 80, TP_valid: 171, FN_valid: 162
# epoch 156/200 ---> AUC_valid: 0.7328607925622851
# epoch 156/200 ---> Precision_valid: 0.6812749003984063
# epoch 157/200 ---> train_accuracy: 0.7155925035476685, valid_accuracy: 0.6995012760162354
# epoch 157/200 ---> train_recall : 0.5074320861096874 , valid_recall : 0.5075075075075075
# epoch 157/200 ---> TN_valid: 392, FP_valid: 77, TP_valid: 169, FN_valid: 164
# epoch 157/200 ---> AUC_valid: 0.7335779276077783
# epoch 157/200 ---> Precision_valid: 0.6869918699186992
# epoch 158/200 ---> train_accuracy: 0.7164241075515747, valid_accuracy: 0.6982543468475342
# epoch 158/200 ---> train_recall : 0.5089697590978985 , valid_recall : 0.5075075075075075
# epoch 158/200 ---> TN_valid: 391, FP_valid: 78, TP_valid: 169, FN_valid: 164
# epoch 158/200 ---> AUC_valid: 0.7330400763236583
# epoch 158/200 ---> Precision_valid: 0.6842105263157895
# epoch 159/200 ---> train_accuracy: 0.7166320085525513, valid_accuracy: 0.6995012760162354
# epoch 159/200 ---> train_recall : 0.5258841619682214 , valid_recall : 0.5135135135135135
# epoch 159/200 ---> TN_valid: 390, FP_valid: 79, TP_valid: 171, FN_valid: 162
# epoch 159/200 ---> AUC_valid: 0.7323677622185085
# epoch 159/200 ---> Precision_valid: 0.684
# epoch 160/200 ---> train_accuracy: 0.7180873155593872, valid_accuracy: 0.6970074772834778
# epoch 160/200 ---> train_recall : 0.5274218349564326 , valid_recall : 0.5165165165165165
# epoch 160/200 ---> TN_valid: 387, FP_valid: 82, TP_valid: 172, FN_valid: 161
# epoch 160/200 ---> AUC_valid: 0.7321052395679262
# epoch 160/200 ---> Precision_valid: 0.6771653543307087
# epoch 161/200 ---> train_accuracy: 0.7182952165603638, valid_accuracy: 0.7032418847084045
# epoch 161/200 ---> train_recall : 0.522296258329062 , valid_recall : 0.5165165165165165
# epoch 161/200 ---> TN_valid: 392, FP_valid: 77, TP_valid: 172, FN_valid: 161
# epoch 161/200 ---> AUC_valid: 0.7332385690594646
# epoch 161/200 ---> Precision_valid: 0.6907630522088354
# epoch 162/200 ---> train_accuracy: 0.7168399095535278, valid_accuracy: 0.7007481455802917
# epoch 162/200 ---> train_recall : 0.5258841619682214 , valid_recall : 0.5165165165165165
# epoch 162/200 ---> TN_valid: 390, FP_valid: 79, TP_valid:
200 ---> train_recall : 0.5207585853408508 , valid_recall : 0.5195195195195195
# epoch 172/200 ---> TN_valid: 389, FP_valid: 80, TP_valid: 173, FN_valid: 160
# epoch 172/200 ---> AUC_valid: 0.734019734019734
# epoch 172/200 ---> Precision_valid: 0.6837944664031621
# epoch 173/200 ---> train_accuracy: 0.7189189195632935, valid_accuracy: 0.6995012760162354
# epoch 173/200 ---> train_recall : 0.5274218349564326 , valid_recall : 0.5195195195195195
# epoch 173/200 ---> TN_valid: 388, FP_valid: 81, TP_valid: 173, FN_valid: 160
# epoch 173/200 ---> AUC_valid: 0.7333858378634499
# epoch 173/200 ---> Precision_valid: 0.6811023622047244
# epoch 174/200 ---> train_accuracy: 0.7187110185623169, valid_accuracy: 0.6995012760162354
# epoch 174/200 ---> train_recall : 0.5202460276781138 , valid_recall : 0.5195195195195195
# epoch 174/200 ---> TN_valid: 388, FP_valid: 81, TP_valid: 173, FN_valid: 160
# epoch 174/200 ---> AUC_valid: 0.7333602258975394
# epoch 174/200 ---> Precision_valid: 0.6811023622047244
# epoch 175/200 ---> train_accuracy: 0.715800404548645, valid_accuracy: 0.6995012760162354
# epoch 175/200 ---> train_recall : 0.5202460276781138 , valid_recall : 0.5195195195195195
# epoch 175/200 ---> TN_valid: 388, FP_valid: 81, TP_valid: 173, FN_valid: 160
# epoch 175/200 ---> AUC_valid: 0.7334242558123155
# epoch 175/200 ---> Precision_valid: 0.6811023622047244
# epoch 176/200 ---> train_accuracy: 0.7174636125564575, valid_accuracy: 0.6995012760162354
# epoch 176/200 ---> train_recall : 0.5089697590978985 , valid_recall : 0.5075075075075075
# epoch 176/200 ---> TN_valid: 392, FP_valid: 77, TP_valid: 169, FN_valid: 164
# epoch 176/200 ---> AUC_valid: 0.7345127643635107
# epoch 176/200 ---> Precision_valid: 0.6869918699186992
# epoch 177/200 ---> train_accuracy: 0.7170478105545044, valid_accuracy: 0.7019950151443481
# epoch 177/200 ---> train_recall : 0.5099948744233727 , valid_recall : 0.5165165165165165
# epoch 177/200 ---> TN_valid: 391, FP_valid: 78, TP_valid: 172, FN_valid: 161
# epoch 177/200 ---> AUC_valid: 0.7346664361589734
# epoch 177/200 ---> Precision_valid: 0.688
# epoch 178/200 ---> train_accuracy: 0.7166320085525513, valid_accuracy: 0.7007481455802917
# epoch 178/200 ---> train_recall : 0.5105074320861097 , valid_recall : 0.5135135135135135
# epoch 178/200 ---> TN_valid: 391, FP_valid: 78, TP_valid: 171, FN_valid: 162
# epoch 178/200 ---> AUC_valid: 0.734807301971481
# epoch 178/200 ---> Precision_valid: 0.6867469879518072
# epoch 179/200 ---> train_accuracy: 0.717255711555481, valid_accuracy: 0.6995012760162354
# epoch 179/200 ---> train_recall : 0.5171706817016914 , valid_recall : 0.5165165165165165
# epoch 179/200 ---> TN_valid: 389, FP_valid: 80, TP_valid: 172, FN_valid: 161
# epoch 179/200 ---> AUC_valid: 0.7346344212015854
# epoch 179/200 ---> Precision_valid: 0.6825396825396826
# epoch 180/200 ---> train_accuracy: 0.7166320085525513, valid_accuracy: 0.6970074772834778
# epoch 180/200 ---> train_recall : 0.504356740133265 , valid_recall : 0.5075075075075075
# epoch 180/200 ---> TN_valid: 390, FP_valid: 79, TP_valid: 169, FN_valid: 164
# epoch 180/200 ---> AUC_valid: 0.7351018395794515
# epoch 180/200 ---> Precision_valid: 0.6814516129032258
# epoch 181/200 ---> train_accuracy: 0.7170478105545044, valid_accuracy: 0.6995012760162354
# epoch 181/200 ---> train_recall : 0.5207585853408508 , valid_recall : 0.5195195195195195
# epoch 181/200 ---> TN_valid: 388, FP_valid: 81, TP_valid: 173, FN_valid: 160
# epoch 181/200 ---> AUC_valid: 0.734506361372033
# epoch 181/200 ---> Precision_valid: 0.6811023622047244
# epoch 182/200 ---> train_accuracy: 0.7164241075515747, valid_accuracy: 0.6982543468475342
# epoch 182/200 ---> train_recall : 0.513070220399795 , valid_recall : 0.5105105105105106
# epoch 182/200 ---> TN_valid: 390, FP_valid: 79, TP_valid: 170, FN_valid: 163
# epoch 182/200 ---> AUC_valid: 0.7348521229118243
# epoch 182/200 ---> Precision_valid: 0.6827309236947792
# epoch 183/200 ---> train_accuracy: 0.7166320085525513, valid_accuracy: 0.6982543468475342
# epoch 183/200 ---> train_recall : 0.513070220399795 , valid_recall : 0.5105105105105106
# epoch 183/200 ---> TN_valid: 390, FP_valid: 79, TP_valid: 170, FN_valid: 163
# epoch 183/200 ---> AUC_valid: 0.7349417647925109
# epoch 183/200 ---> Precision_valid: 0.6827309236947792
# epoch 184/200 ---> train_accuracy: 0.7182952165603638, valid_accuracy: 0.7007481455802917
# epoch 184/200 ---> train_recall : 0.5176832393644285 , valid_recall : 0.5195195195195195
# epoch 184/200 ---> TN_valid: 389, FP_valid: 80, TP_valid: 173, FN_valid: 160
# epoch 184/200 ---> AUC_valid: 0.7348457199203468
# epoch 184/200 ---> Precision_valid: 0.6837944664031621
# epoch 185/200 ---> train_accuracy: 0.7178794145584106, valid_accuracy: 0.6982543468475342
# epoch 185/200 ---> train_recall : 0.5248590466427473 , valid_recall : 0.5195195195195195
# epoch 185/200 ---> TN_valid: 387, FP_valid: 82, TP_valid: 173, FN_valid: 160
# epoch 185/200 ---> AUC_valid: 0.7347432720567049
# epoch 185/200 ---> Precision_valid: 0.6784313725490196
# epoch 186/200 ---> train_accuracy: 0.7168399095535278, valid_accuracy: 0.6995012760162354
# epoch 186/200 ---> train_recall : 0.5146078933880062 , valid_recall : 0.5135135135135135
# epoch 186/200 ---> TN_valid: 390, FP_valid: 79, TP_valid: 171, FN_valid: 162
# epoch 186/200 ---> AUC_valid: 0.7341541968407639
# epoch 186/200 ---> Precision_valid: 0.684
# epoch 187/200 ---> train_accuracy: 0.7185031175613403, valid_accuracy: 0.6957606077194214
# epoch 187/200 ---> train_recall : 0.5212711430035879 , valid_recall : 0.5135135135135135
# epoch 187/200 ---> TN_valid: 387, FP_valid: 82, TP_valid: 171, FN_valid: 162
# epoch 187/200 ---> AUC_valid: 0.7335235021802187
# epoch 187/200 ---> Precision_valid: 0.6758893280632411
# epoch 188/200 ---> train_accuracy: 0.7170478105545044, valid_accuracy: 0.7007481455802917
# epoch 188/200 ---> train_recall : 0.5099948744233727 , valid_recall : 0.5135135135135135
# epoch 188/200 ---> TN_valid: 391, FP_valid: 78, TP_valid: 171, FN_valid: 162
# epoch 188/200 ---> AUC_valid: 0.7349225558180783
# epoch 188/200 ---> Precision_valid: 0.6867469879518072
# epoch 189/200 ---> train_accuracy: 0.7174636125564575, valid_accuracy: 0.7032418847084045
# epoch 189/200 ---> train_recall : 0.5099948744233727 , valid_recall : 0.5105105105105106
# epoch 189/200 ---> TN_valid: 394, FP_valid: 75, TP_valid: 170, FN_valid: 163
# epoch 189/200 ---> AUC_valid: 0.7353003323152576
# epoch 189/200 ---> Precision_valid: 0.6938775510204082
# epoch 190/200 ---> train_accuracy: 0.7170478105545044, valid_accuracy: 0.7007481455802917
# epoch 190/200 ---> train_recall : 0.5084572014351615 , valid_recall : 0.5075075075075075
# epoch 190/200 ---> TN_valid: 393, FP_valid: 76, TP_valid: 169, FN_valid: 164
# epoch 190/200 ---> AUC_valid: 0.7348008989800034
# epoch 190/200 ---> Precision_valid: 0.689795918367347
# epoch 191/200 ---> train_accuracy: 0.7178794145584106, valid_accuracy: 0.6957606077194214
# epoch 191/200 ---> train_recall : 0.5279343926191696 , valid_recall : 0.5165165165165165
# epoch 191/200 ---> TN_valid: 386, FP_valid: 83, TP_valid: 172, FN_valid: 161
# epoch 191/200 ---> AUC_valid: 0.7341157788918983
# epoch 191/200 ---> Precision_valid: 0.6745098039215687
# epoch 192/200 ---> train_accuracy: 0.7193347215652466, valid_accuracy: 0.6970074772834778
# epoch 192/200 ---> train_recall : 0.522296258329062 , valid_recall : 0.5135135135135135
# epoch 192/200 ---> TN_valid: 388, FP_valid: 81, TP_valid: 171, FN_valid: 162
# epoch 192/200 ---> AUC_valid: 0.7338980771816592
# epoch 192/200 ---> Precision_valid: 0.6785714285714286
# epoch 193/200 ---> train_accuracy: 0.7185031175613403, valid_accuracy: 0.7007481455802917
# epoch 193/200 ---> train_recall : 0.5176832393644285 , valid_recall : 0.5135135135135135
# epoch 193/200 ---> TN_valid: 391, FP_valid: 78, TP_valid: 171, FN_valid: 162
# epoch 193/200 ---> AUC_valid: 0.7345960032527197
# epoch 193/200 ---> Precision_valid: 0.6867469879518072
# epoch 194/200 ---> train_accuracy: 0.7193347215652466, valid_accuracy: 0.6995012760162354
# epoch 194/200 ---> train_recall : 0.5171706817016914 , valid_recall : 0.5105105105105106
# epoch 194/200 ---> TN_valid: 391, FP_valid: 78, TP_valid: 170, FN_valid: 163
# epoch 194/200 ---> AUC_valid: 0.7343783015424806
# epoch 194/200 ---> Precision_valid: 0.6854838709677419
# epoch 195/200 ---> train_accuracy: 0.7193347215652466, valid_accuracy: 0.7007481455802917
# epoch 195/200 ---> train_recall : 0.5233213736545361 , valid_recall : 0.5195195195195195
# epoch 195/200 ---> TN_valid: 389, FP_valid: 80, TP_valid: 173, FN_valid: 160
# epoch 195/200 ---> AUC_valid: 0.7337059874373306
# epoch 195/200 ---> Precision_valid: 0.6837944664031621
# epoch 196/200 ---> train_accuracy: 0.7178794145584106, valid_accuracy: 0.6995012760162354
# epoch 196/200 ---> train_recall : 0.5156330087134803 , valid_recall : 0.5105105105105106
# epoch 196/200 ---> TN_valid: 391, FP_valid: 78, TP_valid: 170, FN_valid: 163
# epoch 196/200 ---> AUC_valid: 0.7346664361589736
# epoch 196/200 ---> Precision_valid: 0.6854838709677419
# epoch 197/200 ---> train_accuracy: 0.7168399095535278, valid_accuracy: 0.6982543468475342
# epoch 197/200 ---> train_recall : 0.5079446437724244 , valid_recall : 0.5075075075075075
# epoch 197/200 ---> TN_valid: 391, FP_valid: 78, TP_valid: 169, FN_valid: 164
# epoch 197/200 ---> AUC_valid: 0.7352427053919591
# epoch 197/200 ---> Precision_valid: 0.6842105263157895
# epoch 198/200 ---> train_accuracy: 0.7170478105545044, valid_accuracy: 0.6995012760162354
# epoch 198/200 ---> train_recall : 0.5192209123526397 , valid_recall : 0.5135135135135135
# epoch 198/200 ---> TN_valid: 390, FP_valid: 79, TP_valid: 171, FN_valid: 162
# epoch 198/200 ---> AUC_valid: 0.734237435729973
# epoch 198/200 ---> Precision_valid: 0.684
# epoch 199/200 ---> train_accuracy: 0.7182952165603638, valid_accuracy: 0.6995012760162354
# epoch 199/200 ---> train_recall : 0.5146078933880062 , valid_recall : 0.5135135135135135
# epoch 199/200 ---> TN_valid: 390, FP_valid: 79, TP_valid: 171, FN_valid: 162
# epoch 199/200 ---> AUC_valid: 0.7344359284657792
# epoch 199/200 ---> Precision_valid: 0.684

# %%
# Plot training and validation accuracy over epochs
plt.plot([i for i in range(len(train_accuracy_list))], train_accuracy_list, label="train")
plt.plot([i for i in range(len(valid_accuracy_list))], valid_accuracy_list, label="validation")
plt.legend(loc="upper left")
plt.xlabel('Epochs')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
# Plot training and validation recall over epochs
plt.plot([i for i in range(len(train_accuracy_list))], train_recall_list, label="train")
plt.plot([i for i in range(len(valid_recall_list))], valid_recall_list, label="validation")
plt.legend(loc="upper left")
plt.xlabel('Epochs')
plt.ylabel('recall')
# Out:
# Text(0, 0.5, 'recall')

# %% [markdown]
# Neural Network with Early Stopping

# %%
# Importing necessary libraries
import torch as t
from torch.utils.data import TensorDataset, DataLoader
from torch.nn import Sequential, Linear, Tanh, Sigmoid
from torch.optim import Adam
from torch.nn import BCELoss
import matplotlib.pyplot as plt

# Defining the parameters
number_of_input_features = 11
number_of_hidden_units = 10
epochs = 200
learning_rate = 0.001
batch_size = 25

# Loading and preprocessing the data
X_train_tensor = t.Tensor(X_train).type(t.float32)
Y_train_tensor = t.Tensor(Y_train).type(t.float32)

X_valid_tensor = t.Tensor(X_valid).type(t.float32)
Y_valid_tensor = t.Tensor(Y_valid).type(t.float32)

train_dataset = TensorDataset(X_train_tensor, Y_train_tensor)
train_data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Creating a neural network model
model = Sequential(
    Linear(number_of_input_features, number_of_hidden_units),
    Tanh(),
    Linear(number_of_hidden_units, 1),
    Sigmoid()
)

# Setting up the optimizer and loss function
optimizer = Adam(model.parameters(), lr=learning_rate)
loss_fn = BCELoss()

# Lists to store accuracy values during training
train_accuracy_list = []
valid_accuracy_list = []
train_recall_list = []
valid_recall_list = []

# Main training loop
for epoch in range(epochs):
    # Learning rate scheduling (optional)
    if epoch % 500 == 0:
        learning_rate *= .9

    per_epoch_loss_list = []

    for batch_idx, (X, Y) in enumerate(train_data_loader):
        probs = model(X)

        # new loss is the old loss + regularization term
        loss = loss_fn(probs.view(-1), Y)

        per_epoch_loss_list.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    with t.no_grad():
        # Calculate accuracy on train data
        model.eval()
        probs = model(X_train_tensor)
        prediction = (probs >= .5).type(t.LongTensor).view(-1)

        train_accuracy = (prediction == Y_train_tensor).type(t.float32).mean().item()

        TP_train = t.sum((prediction == 1) & (Y_train_tensor == 1)).item()
        FN_train = t.sum((prediction == 0) & (Y_train_tensor == 1)).item()
        recall_train = TP_train / (TP_train + FN_train)

        # Calculate accuracy on validation data
        probs = model(X_valid_tensor)
        prediction = (probs > .5).type(t.LongTensor).view(-1)

        validation_accuracy = (prediction == Y_valid_tensor).type(t.float32).mean().item()

        print(f'epoch {epoch}/{epochs} ---> train_accuracy : {train_accuracy} , validation_accuracy : {validation_accuracy}')
        model.train()
        train_accuracy_list.append(train_accuracy)
        validation_accuracy_list.append(validation_accuracy)

        TP_valid = t.sum((prediction == 1) & (Y_valid_tensor == 1)).item()
        FN_valid = t.sum((prediction == 0) & (Y_valid_tensor == 1)).item()
        recall_valid = TP_valid / (TP_valid + FN_valid)

        print(f'epoch {epoch}/{epochs} ---> train_recall : {recall_train} , validation_recall : {recall_valid}')
        model.train()
        train_recall_list.append(recall_train)
        valid_recall_list.append(recall_valid)
# Out:
# epoch 0/200 ---> train_accuracy : 0.648856520652771 , validation_accuracy : 0.604738175868988
# epoch 0/200 ---> train_recall : 0.5781650435674013 , validation_recall : 0.5285285285285285
# epoch 1/200 ---> train_accuracy : 0.6908524036407471 , validation_accuracy : 0.6521196961402893
# epoch 1/200 ---> train_recall : 0.5258841619682214 , validation_recall : 0.4984984984984985
# epoch 2/200 ---> train_accuracy : 0.7022868990898132 , validation_accuracy : 0.6695760488510132
# epoch 2/200 ---> train_recall : 0.5192209123526397 , validation_recall : 0.5015015015015015
# epoch 3/200 ---> train_accuracy : 0.7041580080986023 , validation_accuracy : 0.6708229184150696
# epoch 3/200 ---> train_recall : 0.5274218349564326 , validation_recall : 0.5045045045045045
# epoch 4/200 ---> train_accuracy : 0.7037422060966492 , validation_accuracy : 0.6720698475837708
# epoch 4/200 ---> train_recall : 0.5320348539210661 , validation_recall : 0.5165165165165165
# epoch 5/200 ---> train_accuracy : 0.7068607211112976 , validation_accuracy : 0.6733167171478271
# epoch 5/200 ---> train_recall : 0.5207585853408508 , validation_recall : 0.5015015015015015
# epoch 6/200 ---> train_accuracy : 0.7043659090995789 , validation_accuracy : 0.6733167171478271
# epoch 6/200 ---> train_recall : 0.5233213736545361 , validation_recall : 0.5045045045045045
# epoch 7/200 ---> train_accuracy : 0.7039501070976257 , validation_accuracy : 0.6683291792869568
# epoch 7/200 ---> train_recall : 0.5361353152229625 , validation_recall : 0.5165165165165165
# epoch 8/200 ---> train_accuracy : 0.704781711101532 , validation_accuracy : 0.6745635867118835
# epoch 8/200 ---> train_recall : 0.5340850845720143 , validation_recall : 0.5195195195195195
# epoch 9/200 ---> train_accuracy : 0.7045738101005554 , validation_accuracy : 0.6708229184150696
# epoch 9/200 ---> train_recall : 0.5340850845720143 , validation_recall : 0.5105105105105106
# epoch 10/200 ---> train_accuracy : 0.7049896121025085 , validation_accuracy : 0.6720698475837708
# epoch 10/200 ---> train_recall : 0.5392106611993849 , validation_recall : 0.5225225225225225
# epoch 11/200 ---> train_accuracy : 0.7056133151054382 , validation_accuracy : 0.6708229184150696
# epoch 11/200 ---> train_recall : 0.531522296258329 , validation_recall : 0.5075075075075075
# epoch 12/200 ---> train_accuracy : 0.7074844241142273 , validation_accuracy : 0.6758104562759399
# epoch 12/200 ---> train_recall : 0.5212711430035879 , validation_recall : 0.5015015015015015
# epoch 13/200 ---> train_accuracy : 0.7064449191093445 , validation_accuracy : 0.6720698475837708
# epoch 13/200 ---> train_recall : 0.5330599692465402 , validation_recall : 0.5105105105105106
# epoch 14/200 ---> train_accuracy : 0.7122660875320435 , validation_accuracy : 0.6807979941368103
# epoch 14/200 ---> train_recall : 0.5258841619682214 , validation_recall : 0.5015015015015015
# epoch 15/200 ---> train_accuracy : 0.7091476321220398 , validation_accuracy : 0.6758104562759399
200 ---> train_accuracy : 0.7245322465896606 , validation_accuracy : 0.7144638299942017
# epoch 48/200 ---> train_recall : 0.5166581240389544 , validation_recall : 0.5195195195195195
# epoch 49/200 ---> train_accuracy : 0.7232848405838013 , validation_accuracy : 0.7144638299942017
# epoch 49/200 ---> train_recall : 0.521783700666325 , validation_recall : 0.5315315315315315
# epoch 50/200 ---> train_accuracy : 0.7249480485916138 , validation_accuracy : 0.7107232213020325
# epoch 50/200 ---> train_recall : 0.5299846232701179 , validation_recall : 0.5315315315315315
# epoch 51/200 ---> train_accuracy : 0.7245322465896606 , validation_accuracy : 0.7144638299942017
# epoch 51/200 ---> train_recall : 0.531522296258329 , validation_recall : 0.5345345345345346
# epoch 52/200 ---> train_accuracy : 0.7234927415847778 , validation_accuracy : 0.7119700908660889
# epoch 52/200 ---> train_recall : 0.5269092772936955 , validation_recall : 0.5285285285285285
# epoch 53/200 ---> train_accuracy : 0.7243243455886841 , validation_accuracy : 0.7157106995582581
# epoch 53/200 ---> train_recall : 0.5330599692465402 , validation_recall : 0.5405405405405406
# epoch 54/200 ---> train_accuracy : 0.7255717515945435 , validation_accuracy : 0.7182044982910156
# epoch 54/200 ---> train_recall : 0.5289595079446437 , validation_recall : 0.5345345345345346
# epoch 55/200 ---> train_accuracy : 0.7245322465896606 , validation_accuracy : 0.7132169604301453
# epoch 55/200 ---> train_recall : 0.5345976422347514 , validation_recall : 0.5345345345345346
# epoch 56/200 ---> train_accuracy : 0.7237006425857544 , validation_accuracy : 0.719451367855072
# epoch 56/200 ---> train_recall : 0.5176832393644285 , validation_recall : 0.5315315315315315
# epoch 57/200 ---> train_accuracy : 0.7237006425857544 , validation_accuracy : 0.7182044982910156
# epoch 57/200 ---> train_recall : 0.5258841619682214 , validation_recall : 0.5345345345345346
# epoch 58/200 ---> train_accuracy : 0.7228690385818481 , validation_accuracy : 0.7132169604301453
# epoch 58/200 ---> train_recall : 0.5253716043054844 , validation_recall : 0.5255255255255256
# epoch 59/200 ---> train_accuracy : 0.7245322465896606 , validation_accuracy : 0.7182044982910156
# epoch 59/200 ---> train_recall : 0.5161455663762173 , validation_recall : 0.5315315315315315
# epoch 60/200 ---> train_accuracy : 0.7234927415847778 , validation_accuracy : 0.719451367855072
# epoch 60/200 ---> train_recall : 0.5140953357252691 , validation_recall : 0.5285285285285285
# epoch 61/200 ---> train_accuracy : 0.7247401475906372 , validation_accuracy : 0.7132169604301453
# epoch 61/200 ---> train_recall : 0.5366478728856996 , validation_recall : 0.5375375375375375
# epoch 62/200 ---> train_accuracy : 0.7251559495925903 , validation_accuracy : 0.7157106995582581
# epoch 62/200 ---> train_recall : 0.5356227575602255 , validation_recall : 0.5405405405405406
# epoch 63/200 ---> train_accuracy : 0.7247401475906372 , validation_accuracy : 0.7157106995582581
# epoch 63/200 ---> train_recall : 0.5263967196309585 , validation_recall : 0.5315315315315315
# epoch 64/200 ---> train_accuracy : 0.7245322465896606 , validation_accuracy : 0.7157106995582581
# epoch 64/200 ---> train_recall : 0.5263967196309585 , validation_recall : 0.5315315315315315
# epoch 65/200 ---> train_accuracy : 0.7247401475906372 , validation_accuracy : 0.7157106995582581
# epoch 65/200 ---> train_recall : 0.5335725269092773 , validation_recall : 0.5375375375375375
# epoch 66/200 ---> train_accuracy : 0.723908543586731 , validation_accuracy : 0.7169576287269592
# epoch 66/200 ---> train_recall : 0.5289595079446437 , validation_recall : 0.5345345345345346
# epoch 67/200 ---> train_accuracy : 0.7249480485916138 , validation_accuracy : 0.7169576287269592
# epoch 67/200 ---> train_recall : 0.5289595079446437 , validation_recall : 0.5345345345345346
# epoch 68/200 ---> train_accuracy : 0.7249480485916138 , validation_accuracy : 0.7169576287269592
# epoch 68/200 ---> train_recall : 0.5351101998974884 , validation_recall : 0.5375375375375375
# epoch 69/200 ---> train_accuracy : 0.7251559495925903 , validation_accuracy : 0.7157106995582581
# epoch 69/200 ---> train_recall : 0.5463864684777038 , validation_recall : 0.5465465465465466
# epoch 70/200 ---> train_accuracy : 0.7251559495925903 , validation_accuracy : 0.7132169604301453
# epoch 70/200 ---> train_recall : 0.5289595079446437 , validation_recall : 0.5315315315315315
# epoch 71/200 ---> train_accuracy : 0.7245322465896606 , validation_accuracy : 0.7157106995582581
# epoch 71/200 ---> train_recall : 0.5402357765248591 , validation_recall : 0.5405405405405406
# epoch 72/200 ---> train_accuracy : 0.7266111969947815 , validation_accuracy : 0.7182044982910156
# epoch 72/200 ---> train_recall : 0.5320348539210661 , validation_recall : 0.5375375375375375
# epoch 73/200 ---> train_accuracy : 0.7249480485916138 , validation_accuracy : 0.7157106995582581
# epoch 73/200 ---> train_recall : 0.5381855458739108 , validation_recall : 0.5375375375375375
# epoch 74/200 ---> train_accuracy : 0.72577965259552 , validation_accuracy : 0.7182044982910156
# epoch 74/200 ---> train_recall : 0.5299846232701179 , validation_recall : 0.5345345345345346
# epoch 75/200 ---> train_accuracy : 0.7272348999977112 , validation_accuracy : 0.719451367855072
# epoch 75/200 ---> train_recall : 0.5243464889800102 , validation_recall : 0.5285285285285285
# epoch 76/200 ---> train_accuracy : 0.7247401475906372 , validation_accuracy : 0.7144638299942017
# epoch 76/200 ---> train_recall : 0.5366478728856996 , validation_recall : 0.5375375375375375
# epoch 77/200 ---> train_accuracy : 0.7272348999977112 , validation_accuracy : 0.7119700908660889
# epoch 77/200 ---> train_recall : 0.5356227575602255 , validation_recall : 0.5285285285285285
# epoch 78/200 ---> train_accuracy : 0.7284823060035706 , validation_accuracy : 0.7182044982910156
# epoch 78/200 ---> train_recall : 0.5274218349564326 , validation_recall : 0.5285285285285285
# epoch 79/200 ---> train_accuracy : 0.7274428009986877 , validation_accuracy : 0.7144638299942017
# epoch 79/200 ---> train_recall : 0.5335725269092773 , validation_recall : 0.5255255255255256
# epoch 80/200 ---> train_accuracy : 0.7274428009986877 , validation_accuracy : 0.7144638299942017
# epoch 80/200 ---> train_recall : 0.5443362378267556 , validation_recall : 0.5375375375375375
# epoch 81/200 ---> train_accuracy : 0.7272348999977112 , validation_accuracy : 0.7132169604301453
# epoch 81/200 ---> train_recall : 0.5397232188621219 , validation_recall : 0.5345345345345346
# epoch 82/200 ---> train_accuracy : 0.7261954545974731 , validation_accuracy : 0.7119700908660889
# epoch 82/200 ---> train_recall : 0.5556125064069708 , validation_recall : 0.5465465465465466
# epoch 83/200 ---> train_accuracy : 0.7259875535964966 , validation_accuracy : 0.7132169604301453
# epoch 83/200 ---> train_recall : 0.5417734495130703 , validation_recall : 0.5345345345345346
# epoch 84/200 ---> train_accuracy : 0.72577965259552 , validation_accuracy : 0.7157106995582581
# epoch 84/200 ---> train_recall : 0.5386981035366478 , validation_recall : 0.5345345345345346
# epoch 85/200 ---> train_accuracy : 0.7291060090065002 , validation_accuracy : 0.7169576287269592
# epoch 85/200 ---> train_recall : 0.5356227575602255 , validation_recall : 0.5255255255255256
# epoch 86/200 ---> train_accuracy : 0.7266111969947815 , validation_accuracy : 0.7157106995582581
# epoch 86/200 ---> train_recall : 0.5417734495130703 , validation_recall : 0.5345345345345346
# epoch 87/200 ---> train_accuracy : 0.7261954545974731 , validation_accuracy : 0.7144638299942017
# epoch 87/200 ---> train_recall : 0.5392106611993849 , validation_recall : 0.5345345345345346
# epoch 88/200 ---> train_accuracy : 0.7272348999977112 , validation_accuracy : 0.7157106995582581
# epoch 88/200 ---> train_recall : 0.5376729882111737 , validation_recall : 0.5315315315315315
# epoch 89/200 ---> train_accuracy : 0.7264033555984497 , validation_accuracy : 0.7094762921333313
# epoch 89/200 ---> train_recall : 0.5489492567913891 , validation_recall : 0.5345345345345346
# epoch 90/200 ---> train_accuracy : 0.728274405002594 , validation_accuracy : 0.719451367855072
# epoch 90/200 ---> train_recall : 0.5386981035366478 , validation_recall : 0.5285285285285285
# epoch 91/200 ---> train_accuracy : 0.7266111969947815 , validation_accuracy : 0.7169576287269592
# epoch 91/200 ---> train_recall : 0.5371604305484367 , validation_recall : 0.5285285285285285
# epoch 92/200 ---> train_accuracy : 0.7278586030006409 , validation_accuracy : 0.7132169604301453
# epoch 92/200 ---> train_recall : 0.5304971809328549 , validation_recall : 0.5255255255255256
# epoch 93/200 ---> train_accuracy : 0.7245322465896606 , validation_accuracy : 0.7144638299942017
# epoch 93/200 ---> train_recall : 0.5381855458739108 , validation_recall : 0.5315315315315315
# epoch 94/200 ---> train_accuracy : 0.7270269989967346 , validation_accuracy : 0.7157106995582581
# epoch 94/200 ---> train_recall : 0.5376729882111737 , validation_recall : 0.5285285285285285
# epoch 95/200 ---> train_accuracy : 0.7288981080055237 , validation_accuracy : 0.7144638299942017
# epoch 95/200 ---> train_recall : 0.5422860071758073 , validation_recall : 0.5315315315315315
# epoch 96/200 ---> train_accuracy : 0.728274405002594 , validation_accuracy : 0.7132169604301453
# epoch 96/200 ---> train_recall : 0.5397232188621219 , validation_recall : 0.5285285285285285
# epoch 97/200 ---> train_accuracy : 0.7284823060035706 , validation_accuracy : 0.7144638299942017
# epoch 97/200 ---> train_recall : 0.5412608918503332 , validation_recall : 0.5345345345345346
# epoch 98/200 ---> train_accuracy : 0.7297297120094299 , validation_accuracy : 0.7157106995582581
# epoch 98/200 ---> train_recall : 0.5443362378267556 , validation_recall : 0.5315315315315315
# epoch 99/200 ---> train_accuracy : 0.7255717515945435 , validation_accuracy : 0.7094762921333313
# epoch 99/200 ---> train_recall : 0.5504869297796002 , validation_recall : 0.5375375375375375
# epoch 100/200 ---> train_accuracy : 0.7286902070045471 , validation_accuracy : 0.7169576287269592
# epoch 100/200 ---> train_recall : 0.5417734495130703 , validation_recall : 0.5345345345345346
# epoch 101/200 ---> train_accuracy : 0.7272348999977112 , validation_accuracy : 0.7032418847084045
# epoch 101/200 ---> train_recall : 0.5520246027678114 , validation_recall : 0.5315315315315315
# epoch 102/200 ---> train_accuracy : 0.728274405002594 , validation_accuracy : 0.7107232213020325
# epoch 102/200 ---> train_recall : 0.5443362378267556 , validation_recall : 0.5315315315315315
# epoch 103/200 ---> train_accuracy : 0.7280665040016174 , validation_accuracy : 0.7119700908660889
# epoch 103/200 ---> train_recall : 0.5453613531522297 , validation_recall : 0.5345345345345346
# epoch 104/200 ---> train_accuracy : 0.7284823060035706 , validation_accuracy : 0.7107232213020325
# epoch 104/200 ---> train_recall : 0.5443362378267556 , validation_recall : 0.5315315315315315
# epoch 105/200 ---> train_accuracy : 0.7268190979957581 , validation_accuracy : 0.7119700908660889
# epoch 105/200 ---> train_recall : 0.5361353152229625 , validation_recall : 0.5315315315315315
# epoch 106/200 ---> train_accuracy : 0.7274428009986877 , validation_accuracy : 0.7107232213020325
# epoch 106/200 ---> train_recall : 0.5443362378267556 , validation_recall : 0.5375375375375375
# epoch 107/200 ---> train_accuracy : 0.7270269989967346 , validation_accuracy : 0.7119700908660889
# epoch 107/200 ---> train_recall : 0.5366478728856996 , validation_recall : 0.5255255255255256
# epoch 108/200 ---> train_accuracy : 0.7278586030006409 , validation_accuracy : 0.7144638299942017
# epoch 108/200 ---> train_recall : 0.5366478728856996 , validation_recall : 0.5255255255255256
# epoch 109/200 ---> train_accuracy : 0.7266111969947815 , validation_accuracy : 0.7107232213020325
# epoch 109/200 ---> train_recall : 0.5448487954894926 , validation_recall : 0.5375375375375375
# epoch 110/200 ---> train_accuracy : 0.7278586030006409 , validation_accuracy : 0.7132169604301453
# epoch 110/200 ---> train_recall : 0.5304971809328549 , validation_recall : 0.5255255255255256
# epoch 111/200 ---> train_accuracy : 0.7255717515945435 , validation_accuracy : 0.7119700908660889
# epoch 111/200 ---> train_recall : 0.5448487954894926 , validation_recall : 0.5375375375375375
# epoch 112/200 ---> train_accuracy : 0.7266111969947815 , validation_accuracy : 0.7107232213020325
# epoch 112/200 ---> train_recall : 0.5345976422347514 , validation_recall : 0.5285285285285285
# epoch 113/200 ---> train_accuracy : 0.7274428009986877 , validation_accuracy : 0.7132169604301453
# epoch 113/200 ---> train_recall : 0.5356227575602255 , validation_recall : 0.5285285285285285
# epoch 114/200 ---> train_accuracy : 0.72577965259552 , validation_accuracy : 0.7094762921333313
# epoch 114/200 ---> train_recall : 0.5458739108149667 , validation_recall : 0.5375375375375375
# epoch 115/200 ---> train_accuracy : 0.7276507019996643 , validation_accuracy : 0.7107232213020325
# epoch 115/200 ---> train_recall : 0.5402357765248591 , validation_recall : 0.5255255255255256
# epoch 116/200 ---> train_accuracy : 0.7264033555984497 , validation_accuracy : 0.7119700908660889
# epoch 116/200 ---> train_recall : 0.5427985648385444 , validation_recall : 0.5345345345345346
# epoch 117/200 ---> train_accuracy : 0.7251559495925903 , validation_accuracy : 0.7119700908660889
# epoch 117/200 ---> train_recall : 0.5407483341875962 , validation_recall : 0.5345345345345346
# epoch 118/200 ---> train_accuracy : 0.7245322465896606 , validation_accuracy : 0.7094762921333313
# epoch 118/200 ---> train_recall : 0.5453613531522297 , validation_recall : 0.5375375375375375
# epoch 119/200 ---> train_accuracy : 0.7264033555984497 , validation_accuracy : 0.7107232213020325
# epoch 119/200 ---> train_recall : 0.5474115838031779 , validation_recall : 0.5405405405405406
# epoch 120/200 ---> train_accuracy : 0.7253638505935669 , validation_accuracy : 0.7094762921333313
# epoch 120/200 ---> train_recall : 0.5474115838031779 , validation_recall : 0.5375375375375375
# epoch 121/200 ---> train_accuracy : 0.7247401475906372 , validation_accuracy : 0.7094762921333313
# epoch 121/200 ---> train_recall : 0.5474115838031779 , validation_recall : 0.5375375375375375
# epoch 122/200 ---> train_accuracy : 0.7272348999977112 , validation_accuracy : 0.
# epoch 140/200 ---> train_accuracy : 0.7276507019996643 , validation_accuracy : 0.7094762921333313
# epoch 140/200 ---> train_recall : 0.5433111225012814 , validation_recall : 0.5345345345345346
# epoch 141/200 ---> train_accuracy : 0.7266111969947815 , validation_accuracy : 0.7069825530052185
# epoch 141/200 ---> train_recall : 0.547924141465915 , validation_recall : 0.5345345345345346
# epoch 142/200 ---> train_accuracy : 0.7268190979957581 , validation_accuracy : 0.7069825530052185
# epoch 142/200 ---> train_recall : 0.5417734495130703 , validation_recall : 0.5315315315315315
# epoch 143/200 ---> train_accuracy : 0.7276507019996643 , validation_accuracy : 0.7069825530052185
# epoch 143/200 ---> train_recall : 0.5412608918503332 , validation_recall : 0.5285285285285285
# epoch 144/200 ---> train_accuracy : 0.72577965259552 , validation_accuracy : 0.7032418847084045
# epoch 144/200 ---> train_recall : 0.5386981035366478 , validation_recall : 0.5225225225225225
# epoch 145/200 ---> train_accuracy : 0.7268190979957581 , validation_accuracy : 0.7044887542724609
# epoch 145/200 ---> train_recall : 0.5361353152229625 , validation_recall : 0.5255255255255256
# epoch 146/200 ---> train_accuracy : 0.7276507019996643 , validation_accuracy : 0.7044887542724609
# epoch 146/200 ---> train_recall : 0.5417734495130703 , validation_recall : 0.5255255255255256
# epoch 147/200 ---> train_accuracy : 0.728274405002594 , validation_accuracy : 0.7069825530052185
# epoch 147/200 ---> train_recall : 0.5540748334187596 , validation_recall : 0.5405405405405406
# epoch 148/200 ---> train_accuracy : 0.7288981080055237 , validation_accuracy : 0.7057356834411621
# epoch 148/200 ---> train_recall : 0.5561250640697079 , validation_recall : 0.5375375375375375
# epoch 149/200 ---> train_accuracy : 0.7272348999977112 , validation_accuracy : 0.7082294225692749
# epoch 149/200 ---> train_recall : 0.5566376217324449 , validation_recall : 0.5405405405405406
# epoch 150/200 ---> train_accuracy : 0.7291060090065002 , validation_accuracy : 0.7032418847084045
# epoch 150/200 ---> train_recall : 0.547924141465915 , validation_recall : 0.5285285285285285
# epoch 151/200 ---> train_accuracy : 0.7295218110084534 , validation_accuracy : 0.7032418847084045
# epoch 151/200 ---> train_recall : 0.5520246027678114 , validation_recall : 0.5345345345345346
# epoch 152/200 ---> train_accuracy : 0.7288981080055237 , validation_accuracy : 0.7032418847084045
# epoch 152/200 ---> train_recall : 0.5530497180932855 , validation_recall : 0.5315315315315315
# epoch 153/200 ---> train_accuracy : 0.7299376130104065 , validation_accuracy : 0.7069825530052185
# epoch 153/200 ---> train_recall : 0.5499743721168632 , validation_recall : 0.5315315315315315
# epoch 154/200 ---> train_accuracy : 0.7305613160133362 , validation_accuracy : 0.7069825530052185
# epoch 154/200 ---> train_recall : 0.548436699128652 , validation_recall : 0.5285285285285285
# epoch 155/200 ---> train_accuracy : 0.7295218110084534 , validation_accuracy : 0.7032418847084045
# epoch 155/200 ---> train_recall : 0.5438236801640185 , validation_recall : 0.5225225225225225
# epoch 156/200 ---> train_accuracy : 0.7286902070045471 , validation_accuracy : 0.7044887542724609
# epoch 156/200 ---> train_recall : 0.547924141465915 , validation_recall : 0.5255255255255256
# epoch 157/200 ---> train_accuracy : 0.7305613160133362 , validation_accuracy : 0.7057356834411621
# epoch 174/200 ---> train_recall : 0.5530497180932855 , validation_recall : 0.5315315315315315
# epoch 175/200 ---> train_accuracy : 0.731600821018219 , validation_accuracy : 0.7032418847084045
# epoch 175/200 ---> train_recall : 0.5545873910814967 , validation_recall : 0.5315315315315315
# epoch 176/200 ---> train_accuracy : 0.7313929200172424 , validation_accuracy : 0.7007481455802917
# epoch 176/200 ---> train_recall : 0.5556125064069708 , validation_recall : 0.5345345345345346
# epoch 177/200 ---> train_accuracy : 0.7297297120094299 , validation_accuracy : 0.7007481455802917
# epoch 177/200 ---> train_recall : 0.5463864684777038 , validation_recall : 0.5315315315315315
# epoch 178/200 ---> train_accuracy : 0.7301455140113831 , validation_accuracy : 0.7019950151443481
# epoch 178/200 ---> train_recall : 0.5504869297796002 , validation_recall : 0.5315315315315315
# epoch 179/200 ---> train_accuracy : 0.7297297120094299 , validation_accuracy : 0.7007481455802917
# epoch 179/200 ---> train_recall : 0.5550999487442337 , validation_recall : 0.5345345345345346
# epoch 180/200 ---> train_accuracy : 0.7286902070045471 , validation_accuracy : 0.6995012760162354
# epoch 180/200 ---> train_recall : 0.557150179395182 , validation_recall : 0.5375375375375375
# epoch 181/200 ---> train_accuracy : 0.7295218110084534 , validation_accuracy : 0.7007481455802917
# epoch 181/200 ---> train_recall : 0.5566376217324449 , validation_recall : 0.5375375375375375
# epoch 182/200 ---> train_accuracy : 0.7288981080055237 , validation_accuracy : 0.7032418847084045
# epoch 182/200 ---> train_recall : 0.5525371604305485 , validation_recall : 0.5375375375375375
# epoch 183/200 ---> train_accuracy : 0.7311850190162659 , validation_accuracy : 0.6982543468475342
# epoch 183/200 ---> train_recall : 0.5581752947206561 , validation_recall : 0.5315315315315315
# epoch 184/200 ---> train_accuracy : 0.7299376130104065 , validation_accuracy : 0.7019950151443481
# epoch 184/200 ---> train_recall : 0.5494618144541261 , validation_recall : 0.5285285285285285
# epoch 185/200 ---> train_accuracy : 0.7307692170143127 , validation_accuracy : 0.7044887542724609
# epoch 185/200 ---> train_recall : 0.5509994874423373 , validation_recall : 0.5345345345345346
# epoch 186/200 ---> train_accuracy : 0.7307692170143127 , validation_accuracy : 0.7032418847084045
# epoch 186/200 ---> train_recall : 0.5494618144541261 , validation_recall : 0.5345345345345346
# epoch 187/200 ---> train_accuracy : 0.7313929200172424 , validation_accuracy : 0.6982543468475342
# epoch 187/200 ---> train_recall : 0.5566376217324449 , validation_recall : 0.5315315315315315
# epoch 188/200 ---> train_accuracy : 0.7286902070045471 , validation_accuracy : 0.6995012760162354
# epoch 188/200 ---> train_recall : 0.5494618144541261 , validation_recall : 0.5315315315315315
# epoch 189/200 ---> train_accuracy : 0.7295218110084534 , validation_accuracy : 0.6982543468475342
# epoch 189/200 ---> train_recall : 0.5545873910814967 , validation_recall : 0.5375375375375375
# epoch 190/200 ---> train_accuracy : 0.7305613160133362 , validation_accuracy : 0.7032418847084045
# epoch 190/200 ---> train_recall : 0.5515120451050743 , validation_recall : 0.5375375375375375
# epoch 191/200 ---> train_accuracy : 0.7303534150123596 , validation_accuracy : 0.6982543468475342
# epoch 191/200 ---> train_recall : 0.5592004100461302 , validation_recall : 0.5315315315315315
# epoch 192/200 ---> train_accuracy : 0.7295218110084534 , validation_accuracy : 0.7019950151443481
# epoch 192/200 ---> train_recall : 0.5489492567913891 , validation_recall : 0.5315315315315315
# epoch 193/200 ---> train_accuracy : 0.7322245240211487 , validation_accuracy : 0.7082294225692749
# epoch 193/200 ---> train_recall : 0.5499743721168632 , validation_recall : 0.5345345345345346
# epoch 194/200 ---> train_accuracy : 0.7299376130104065 , validation_accuracy : 0.7032418847084045
# epoch 194/200 ---> train_recall : 0.5509994874423373 , validation_recall : 0.5315315315315315
# epoch 195/200 ---> train_accuracy : 0.7305613160133362 , validation_accuracy : 0.6970074772834778
# epoch 195/200 ---> train_recall : 0.5525371604305485 , validation_recall : 0.5255255255255256
# epoch 196/200 ---> train_accuracy : 0.7322245240211487 , validation_accuracy : 0.7057356834411621
# epoch 196/200 ---> train_recall : 0.5468990261404408 , validation_recall : 0.5315315315315315
# epoch 197/200 ---> train_accuracy : 0.7295218110084534 , validation_accuracy : 0.7019950151443481
# epoch 197/200 ---> train_recall : 0.557150179395182 , validation_recall : 0.5375375375375375
# epoch 198/200 ---> train_accuracy : 0.7293139100074768 , validation_accuracy : 0.7019950151443481
# epoch 198/200 ---> train_recall : 0.557150179395182 , validation_recall : 0.5405405405405406
# epoch 199/200 ---> train_accuracy : 0.7305613160133362 , validation_accuracy : 0.7044887542724609
# epoch 199/200 ---> train_recall : 0.5494618144541261 , validation_recall : 0.5315315315315315

# %%
# Plotting the training and validation accuracy
plt.plot([i for i in range(len(train_accuracy_list))], train_accuracy_list, label="train")
plt.plot([i for i in range(len(validation_accuracy_list))], validation_accuracy_list, label='validation')
plt.legend(loc="upper left")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# Plotting the training and validation accuracy
plt.plot([i for i in range(len(train_recall_list))], train_recall_list, label="train")
plt.plot([i for i in range(len(valid_recall_list))], valid_recall_list, label='validation')
plt.legend(loc="upper left")
plt.xlabel('Epochs')
plt.ylabel('Recall')
# Out:
# Text(0, 0.5, 'Recall')

# %% [markdown]
# Final Neural Network Test Set Performance

# %%
from sklearn.metrics import roc_auc_score, confusion_matrix, precision_score
from torch.nn import BCELoss
import tensorflow as tf

tf.random.set_seed(42)

number_of_input_features = 11  # Number of input features in the dataset

#Hyperparameters: {'learning_rate': 0.001, 'batch_size': 25, 'number_of_hidden_units': 10, 'dropout_probability': 0.5}
#Validation Accuracy: 0.7331671118736267

# Reduced number of hidden units to 5 and just using 1 hidden layer
number_of_hidden_units = 10  # Number of hidden units in the neural network
epochs = 200  # Number of training epochs
learning_rate = 0.001  # Learning rate for the optimizer
batch_size = 25  # Number of samples in each training batch

# Convert training and testing data to PyTorch tensors
X_train_tensor = t.Tensor(X_train).type(t.float32)
Y_train_tensor = t.Tensor(Y_train).type(t.float32)
X_test_tensor = t.Tensor(X_test).type(t.float32)
Y_test_tensor = t.Tensor(Y_test).type(t.float32)

# Create a training dataset and data loader
train_dataset = TensorDataset(X_train_tensor, Y_train_tensor)
train_data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Define the neural network model
model = Sequential(
    Linear(number_of_input_features, number_of_hidden_units),  # Linear layer for matrix multiplication and bias addition
    Tanh(),  # Add Tanh activation function
    Linear(number_of_hidden_units, 1),  # Another linear layer
    Sigmoid()  # Sigmoid activation for probability output
)

# Define the optimizer
optimizer = Adam(model.parameters(), lr=learning_rate)

# Define the loss function as Binary Cross-Entropy Loss
loss_fn = BCELoss()

train_accuracy_list = []  # List to store training accuracy
test_accuracy_list = []  # List to store validation accuracy
train_recall_list = []
test_recall_list = []

#Main training loop
for epoch in range(epochs):
    if epoch % 500 == 0:
        learning_rate *= 0.9  # Learning rate scheduling

    per_epoch_loss_list = []  # List to store losses for each epoch

    for batch_idx, (X, Y) in enumerate(train_data_loader):
        # Forward pass: Compute predictions
        probs = model(X)

        # Calculate the loss
        loss = loss_fn(probs.view(-1), Y)
        per_epoch_loss_list.append(loss.item())

        # Backward pass: Compute gradients and update weights
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Evaluate the model on training and validation data
    with t.no_grad():
        # Set the model in eval mode; some layers use this for certain calculations during training
        model.eval()

        # Calculate accuracy on train data
        probs = model(X_train_tensor)
        prediction = (probs >= 0.5).type(t.LongTensor).view(-1)
        train_accuracy = (prediction == Y_train_tensor).type(t.float32).mean().item()

        TP_train = t.sum((prediction == 1) & (Y_train_tensor == 1)).item()
        FN_train = t.sum((prediction == 0) & (Y_train_tensor == 1)).item()
        recall_train = TP_train / (TP_train + FN_train)

        # Calculate accuracy on test data
        probs = model(X_test_tensor)
        prediction = (probs > 0.5).type(t.LongTensor).view(-1)
        test_accuracy = (prediction == Y_test_tensor).type(t.float32).mean().item()

        TP_test = t.sum((prediction == 1) & (Y_test_tensor == 1)).item()
        FN_test = t.sum((prediction == 0) & (Y_test_tensor == 1)).item()
        recall_test = TP_test / (TP_test + FN_test)

        conf_matrix_test = confusion_matrix(Y_test_tensor, prediction)
        TN_test = conf_matrix_test[0, 0]
        FP_test = conf_matrix_test[0, 1]
        TP_test = conf_matrix_test[1, 1]
        FN_test = conf_matrix_test[1, 0]

        # Calculate AUC
        auc_test = roc_auc_score(Y_test_tensor.numpy(), probs.numpy())

        # Calculate precision
        precision_test = precision_score(Y_test_tensor.numpy(), prediction.numpy())

        print(f'epoch {epoch}/{epochs} ---> train_accuracy: {train_accuracy}, test_accuracy: {test_accuracy}')
        print(f'epoch {epoch}/{epochs} ---> train_recall : {recall_train} , test_recall : {recall_test}')
        print(f'epoch {epoch}/{epochs} ---> TN_test: {TN_test}, FP_test: {FP_test}, TP_test: {TP_test}, FN_test: {FN_test}')
        print(f'epoch {epoch}/{epochs} ---> AUC_test: {auc_test}')
        print(f'epoch {epoch}/{epochs} ---> Precision_test: {precision_test}')

        model.train()
        train_recall_list.append(recall_train)
        test_recall_list.append(recall_test)

        # Set the model back to train mode
        model.train()

        # Append accuracy values to lists
        train_accuracy_list.append(train_accuracy)
        test_accuracy_list.append(test_accuracy)
# Out:
# epoch 0/200 ---> train_accuracy: 0.6800415515899658, test_accuracy: 0.6870324015617371
# epoch 0/200 ---> train_recall : 0.5735520246027678 , test_recall : 0.6144578313253012
# epoch 0/200 ---> TN_test: 347, FP_test: 123, TP_test: 204, FN_test: 128
# epoch 0/200 ---> AUC_test: 0.7353947705716481
# epoch 0/200 ---> Precision_test: 0.6238532110091743
# epoch 1/200 ---> train_accuracy: 0.7002078890800476, test_accuracy: 0.7007481455802917
# epoch 1/200 ---> train_recall : 0.5279343926191696 , test_recall : 0.5813253012048193
# epoch 1/200 ---> TN_test: 369, FP_test: 101, TP_test: 193, FN_test: 139
# epoch 1/200 ---> AUC_test: 0.7441745706229173
# epoch 1/200 ---> Precision_test: 0.6564625850340136
# epoch 2/200 ---> train_accuracy: 0.706652820110321, test_accuracy: 0.719451367855072
# epoch 2/200 ---> train_recall : 0.5140953357252691 , test_recall : 0.5903614457831325
# epoch 2/200 ---> TN_test: 381, FP_test: 89, TP_test: 196, FN_test: 136
# epoch 2/200 ---> AUC_test: 0.7458215842091771
# epoch 2/200 ---> Precision_test: 0.6877192982456141
# epoch 3/200 ---> train_accuracy: 0.7041580080986023, test_accuracy: 0.7119700908660889
# epoch 3/200 ---> train_recall : 0.5294720656073808 , test_recall : 0.5933734939759037
# epoch 3/200 ---> TN_test: 374, FP_test: 96, TP_test: 197, FN_test: 135
# epoch 3/200 ---> AUC_test: 0.7455396052294283
# epoch 3/200 ---> Precision_test: 0.6723549488054608
# epoch 4/200 ---> train_accuracy: 0.7051975131034851, test_accuracy: 0.7094762921333313
# epoch 4/200 ---> train_recall : 0.5274218349564326 , test_recall : 0.5933734939759037
# epoch 4/200 ---> TN_test: 372, FP_test: 98, TP_test: 197, FN_test: 135
# epoch 4/200 ---> AUC_test: 0.7456870033324788
# epoch 4/200 ---> Precision_test: 0.6677966101694915
# epoch 5/200 ---> train_accuracy: 0.7068607211112976, test_accuracy: 0.7182044982910156
# epoch 5/200 ---> train_recall : 0.5187083546899026 , test_recall : 0.5843373493975904
# epoch 5/200 ---> TN_test: 382, FP_test: 88, TP_test: 194, FN_test: 138
# epoch 5/200 ---> AUC_test: 0.7457318636247117
# epoch 5/200 ---> Precision_test: 0.6879432624113475
# epoch 6/200 ---> train_accuracy: 0.7031185030937195, test_accuracy: 0.7107232213020325
# epoch 6/200 ---> train_recall : 0.5371604305484367 , test_recall : 0.5963855421686747
# epoch 6/200 ---> TN_test: 372, FP_test: 98, TP_test: 198, FN_test: 134
# epoch 6/200 ---> AUC_test: 0.7456165085875417
# epoch 6/200 ---> Precision_test: 0.668918918918919
# epoch 7/200 ---> train_accuracy: 0.7058212161064148, test_accuracy: 0.7094762921333313
# epoch 7/200 ---> train_recall : 0.5299846232701179 , test_recall : 0.5933734939759037
# epoch 7/200 ---> TN_test: 372, FP_test: 98, TP_test: 197, FN_test: 135
# epoch 7/200 ---> AUC_test: 0.7456485516534221
# epoch 7/200 ---> Precision_test: 0.6677966101694915
# epoch 8/200 ---> train_accuracy: 0.7043659090995789, test_accuracy: 0.7107232213020325
# epoch 8/200 ---> train_recall : 0.5320348539210661 , test_recall : 0.5933734939759037
# epoch 8/200 ---> TN_test: 373, FP_test: 97, TP_test: 197, FN_test: 135
# epoch 8/200 ---> AUC_test: 0.7456613688797744
# epoch 8/200 ---> Precision_test: 0.6700680272108843
# epoch 9/200 ---> train_accuracy: 0.7060291171073914, test_accuracy: 0.7107232213020325
# epoch 9/200 ---> train_recall : 0.5263967196309585 , test_recall : 0.5903614457831325
# epoch 9/200 ---> TN_test: 374, FP_test: 96, TP_test: 196, FN_test: 136
# epoch 9/200 ---> AUC_test: 0.7462317354524481
# epoch 9/200 ---> Precision_test: 0.6712328767123288
# epoch 10/200 ---> train_accuracy: 0.706652820110321, test_accuracy: 0.7119700908660889
# epoch 10/200 ---> train_recall : 0.5299846232701179 , test_recall : 0.5933734939759037
# epoch 10/200 ---> TN_test: 374, FP_test: 96, TP_test: 197, FN_test: 135
# epoch 10/200 ---> AUC_test: 0.7457318636247117
# epoch 10/200 ---> Precision_test: 0.6723549488054608
# epoch 11/200 ---> train_accuracy: 0.7064449191093445, test_accuracy: 0.7132169604301453
# epoch 11/200 ---> train_recall : 0.5202460276781138 , test_recall : 0.5843373493975904
# epoch 11/200 ---> TN_test: 378, FP_test: 92, TP_test: 194, FN_test: 138
# epoch 11/200 ---> AUC_test: 0.7464944885926685
# epoch 11/200 ---> Precision_test: 0.6783216783216783
# epoch 12/200 ---> train_accuracy: 0.7072765231132507, test_accuracy: 0.7094762921333313
# epoch 12/200 ---> train_recall : 0.5304971809328549 , test_recall : 0.5903614457831325
# epoch 12/200 ---> TN_test: 373, FP_test: 97, TP_test: 196, FN_test: 136
# epoch 12/200 ---> AUC_test: 0.7468405537041785
# epoch 12/200 ---> Precision_test: 0.6689419795221843
# epoch 13/200 ---> train_accuracy: 0.7072765231132507, test_accuracy: 0.7119700908660889
# epoch 13/200 ---> train_recall : 0.5253716043054844 , test_recall : 0.5903614457831325
# epoch 13/200 ---> TN_test: 375, FP_test: 95, TP_test: 196, FN_test: 136
# epoch 13/200 ---> AUC_test: 0.7473596513714431
# epoch 13/200 ---> Precision_test: 0.6735395189003437
# epoch 14/200 ---> train_accuracy: 0.708108127117157, test_accuracy: 0.7132169604301453
# epoch 14/200 ---> train_recall : 0.5238339313172732 , test_recall : 0.5873493975903614
# epoch 14/200 ---> TN_test: 377, FP_test: 93, TP_test: 195, FN_test: 137
# epoch 14/200 ---> AUC_test: 0.7475647269930786
# epoch 14/200 ---> Precision_test: 0.6770833333333334
# epoch 15/200 ---> train_accuracy: 0.7072765231132507, test_accuracy: 0.7107232213020325
# epoch 15/200 ---> train_recall : 0.5279343926191696 , test_recall : 0.5903614457831325
# epoch 15/200 ---> TN_test: 374, FP_test: 96, TP_test: 196, FN_test: 136
# epoch 15/200 ---> AUC_test: 0.747583952832607
# epoch 15/200 ---> Precision_test: 0.6712328767123288
# epoch 16/200 ---> train_accuracy: 0.708108127117157, test_accuracy: 0.7132169604301453
# epoch 16/200 ---> train_recall : 0.5258841619682214 , test_recall : 0.5933734939759037
# epoch 16/200 ---> TN_test: 375, FP_test: 95, TP_test: 197, FN_test: 135
# epoch 16/200 ---> AUC_test: 0.7480710074339914
# epoch 16/200 ---> Precision_test: 0.6746575342465754
# epoch 17/200 ---> train_accuracy: 0.7085239291191101, test_accuracy: 0.7094762921333313
# epoch 17/200 ---> train_recall : 0.5330599692465402 , test_recall : 0.5903614457831325
# epoch 17/200 ---> TN_test: 373, FP_test: 97, TP_test: 196, FN_test: 136
# epoch 17/200 ---> AUC_test: 0.7476736734170726
# epoch 17/200 ---> Precision_test: 0.6689419795221843
# epoch 18/200 ---> train_accuracy: 0.7085239291191101, test_accuracy: 0.7119700908660889
# epoch 18/200 ---> train_recall : 0.5289595079446437 , test_recall : 0.5873493975903614
# epoch 18/200 ---> TN_test: 376, FP_test: 94, TP_test: 195, FN_test: 137
# epoch 18/200 ---> AUC_test: 0.7477890284542426
# epoch 18/200 ---> Precision_test: 0.6747404844290658
# epoch 19/200 ---> train_accuracy: 0.7091476321220398, test_accuracy: 0.7107232213020325
# epoch 19/200 ---> train_recall : 0.5274218349564326 , test_recall : 0.5873493975903614
# epoch 19/200 ---> TN_test: 375, FP_test: 95, TP_test: 195, FN_test: 137
# epoch 19/200 ---> AUC_test: 0.7483593950269162
# epoch 19/200 ---> Precision_test: 0.6724137931034483
# epoch 20/200 ---> train_accuracy: 0.7091476321220398, test_accuracy: 0.7132169604301453
# epoch 20/200 ---> train_recall : 0.5289595079446437 , test_recall : 0.5903614457831325
# epoch 20/200 ---> TN_test: 376, FP_test: 94, TP_test: 196, FN_test: 136
# epoch 20/200 ---> AUC_test: 0.7486670084593694
# epoch 20/200 ---> Precision_test: 0.6758620689655173
# epoch 21/200 ---> train_accuracy: 0.7114344835281372, test_accuracy: 0.7119700908660889
# epoch 21/200 ---> train_recall : 0.531009738595592 , test_recall : 0.5873493975903614
# epoch 21/200 ---> TN_test: 376, FP_test: 94, TP_test: 195, FN_test: 137
# epoch 21/200 ---> AUC_test: 0.7493335042296847
# epoch 21/200 ---> Precision_test: 0.6747404844290658
# epoch 22/200 ---> train_accuracy: 0.7110186815261841, test_accuracy: 0.7182044982910156
# epoch 22/200 ---> train_recall : 0.5274218349564326 , test_recall : 0.5903614457831325
# epoch 22/200 ---> TN_test: 380, FP_test: 90, TP_test: 196, FN_test: 136
# epoch 22/200 ---> AUC_test: 0.7504614201486799
# epoch 22/200 ---> Precision_test: 0.6853146853146853
# epoch 23/200 ---> train_accuracy: 0.7103950381278992, test_accuracy: 0.7169576287269592
# epoch 23/200 ---> train_recall : 0.5304971809328549 , test_recall : 0.5963855421686747
# epoch 23/200 ---> TN_test: 377, FP_test: 93, TP_test: 198, FN_test: 134
# epoch 23/200 ---> AUC_test: 0.7497756985388361
# epoch 23/200 ---> Precision_test: 0.6804123711340206
# epoch 24/200 ---> train_accuracy: 0.7108108401298523, test_accuracy: 0.7206982374191284
# epoch 24/200 ---> train_recall : 0.5263967196309585 , test_recall : 0.5963855421686747
# epoch 24/200 ---> TN_test: 380, FP_test: 90, TP_test: 198, FN_test: 134
# epoch 24/200 ---> AUC_test: 0.7506536785439631
# epoch 24/200 ---> Precision_test: 0.6875
# epoch 25/200 ---> train_accuracy: 0.7149688005447388, test_accuracy: 0.7244389057159424
# epoch 25/200 ---> train_recall : 0.5238339313172732 , test_recall : 0.5933734939759037
# epoch 25/200 ---> TN_test: 384, FP_test: 86, TP_test: 197, FN_test: 135
# epoch 25/200 ---> AUC_test: 0.7516341963599077
# epoch 25/200 ---> Precision_test: 0.696113074204947
# epoch 26/200 ---> train_accuracy: 0.7110186815261841, test_accuracy: 0.7206982374191284
# epoch 26/200 ---> train_recall : 0.5263967196309585 , test_recall : 0.5933734939759037
# epoch 26/200 ---> TN_test: 381, FP_test: 89, TP_test: 197, FN_test: 135
# epoch 26/200 ---> AUC_test: 0.7512048192771085
# epoch 26/200 ---> Precision_test: 0.6888111888111889
# epoch 27/200 ---> train_accuracy: 0.7120581865310669, test_accuracy: 0.7157106995582581
# epoch 27/200 ---> train_recall : 0.5361353152229625 , test_recall : 0.5963855421686747
# epoch 27/200 ---> TN_test: 376, FP_test: 94, TP_test: 198, FN_test: 134
# epoch 27/200 ---> AUC_test: 0.7510125608818251
# epoch 27/200 ---> Precision_test: 0.678082191780822
# epoch 28/200 ---> train_accuracy: 0.7135134935379028, test_accuracy: 0.7219451665878296
# epoch 28/200 ---> train_recall : 0.5258841619682214 , test_recall : 0.5933734939759037
# epoch 28/200 ---> TN_test: 382, FP_test: 88, TP_test: 197, FN_test: 135
# epoch 28/200 ---> AUC_test: 0.7518456805947193
# epoch 28/200 ---> Precision_test: 0.6912280701754386
# epoch 29/200 ---> train_accuracy: 0.715800404548645, test_accuracy: 0.7256857752799988
# epoch 29/200 ---> train_recall : 0.5299846232701179 , test_recall : 0.5963855421686747
# epoch 29/200 ---> TN_test: 384, FP_test: 86, TP_test: 198, FN_test: 134
# epoch 29/200 ---> AUC_test: 0.7525121763650346
# epoch 29/200 ---> Precision_test: 0.6971830985915493
# epoch 30/200 ---> train_accuracy: 0.7174636125564575, test_accuracy: 0.7256857752799988
# epoch 30/200 ---> train_recall : 0.5289595079446437 , test_recall : 0.6024096385542169
# epoch 30/200 ---> TN_test: 382, FP_test: 88, TP_test: 200, FN_test: 132
# epoch 30/200 ---> AUC_test: 0.7527813381184311
# epoch 30/200 ---> Precision_test: 0.6944444444444444
# epoch 31/200 ---> train_accuracy: 0.7164241075515747, test_accuracy: 0.7219451665878296
# epoch 31/200 ---> train_recall : 0.531522296258329 , test_recall : 0.5963855421686747
# epoch 31/200 ---> TN_test: 381, FP_test: 89, TP_test: 198, FN_test: 134
# epoch 31/200 ---> AUC_test: 0.7535183286336837
# epoch 31/200 ---> Precision_test: 0.6898954703832753
# epoch 32/200 ---> train_accuracy: 0.7162162065505981, test_accuracy: 0.7219451665878296
# epoch 32/200 ---> train_recall : 0.5345976422347514 , test_recall : 0.5963855421686747
# epoch 32/200 ---> TN_test: 381, FP_test: 89, TP_test: 198, FN_test: 134
# epoch 32/200 ---> AUC_test: 0.7532748013329915
# epoch 32/200 ---> Precision_test: 0.6898954703832753
# epoch 33/200 ---> train_accuracy: 0.7162162065505981, test_accuracy: 0.719451367855072
# epoch 33/200 ---> train_recall : 0.5351101998974884 , test_recall : 0.5963855421686747
# epoch 33/200 ---> TN_test: 379, FP_test: 91, TP_test: 198, FN_test: 134
# epoch 33/200 ---> AUC_test: 0.7535503716995643
# epoch 33/200 ---> Precision_test: 0.6851211072664359
# epoch 34/200 ---> train_accuracy: 0.7185031175613403, test_accuracy: 0.7206982374191284
# epoch 34/200 ---> train_recall : 0.5289595079446437 , test_recall : 0.5933734939759037
# epoch 34/200 ---> TN_test: 381, FP_test: 89, TP_test: 197, FN_test: 135
# epoch 34/200 ---> AUC_test: 0.7541335554985902
# epoch 34/200 ---> Precision_test: 0.6888111888111889
# epoch 35/200 ---> train_accuracy: 0.7214137315750122, test_accuracy: 0.7306733131408691
# epoch 35/200 ---> train_recall : 0.5243464889800102 , test_recall : 0.5963855421686747
# epoch 35/200 ---> TN_test: 388, FP_test: 82, TP_test: 198, FN_test: 134
# epoch 35/200 ---> AUC_test: 0.7547039220712637
# epoch 35/200 ---> Precision_test: 0.7071428571428572
# epoch 36/200 ---> train_accuracy: 0.720582127571106, test_accuracy: 0.7256857752799988
# epoch 36/200 ---> train_recall : 0.5253716043054844 , test_recall : 0.5933734939759037
# epoch 36/200 ---> TN_test: 385, FP_test: 85, TP_test: 197, FN_test: 135
# epoch 36/200 ---> AUC_test: 0.7549474493719559
# epoch 36/200 ---> Precision_test: 0.6985815602836879
# epoch 37/200 ---> train_accuracy: 0.7199584245681763, test_accuracy: 0.7294264435768127
# epoch 37/200 ---> train_recall : 0.522296258329062 , test_recall : 0.5933734939759037
# epoch 37/200 ---> TN_test: 388, FP_test: 82, TP_test: 197, FN_test: 135
# epoch 37/200 ---> AUC_test: 0.7558638810561396
# epoch 37/200 ---> Precision_test: 0.7060931899641577
# epoch 38/200 ---> train_accuracy: 0.7193347215652466, test_accuracy: 0.723192036151886
# epoch 38/200 ---> train_recall : 0.5248590466427473 , test_recall : 0.5903614457831325
# epoch 38/200 ---> TN_test: 384, FP_test: 86, TP_test: 196, FN_test: 136
# epoch 38/200 ---> AUC_test: 0.7557549346321455
# epoch 38/200 ---> Precision_test: 0.6950354609929078
# epoch 39/200 ---> train_accuracy: 0.7174636125564575, test_accuracy: 0.723192036151886
# epoch 39/200 ---> train_recall : 0.5386981035366478 , test_recall : 0.608433734939759
# epoch 39/200 ---> TN_test: 378, FP_test: 92, TP_test: 202, FN_test: 130
# epoch 39/200 ---> AUC_test: 0.755838246603435
# epoch 39/200 ---> Precision_test: 0.6870748299319728
# epoch 40/200 ---> train_accuracy: 0.7214137315750122, test_accuracy: 0.7281795740127563
# epoch 40/200 ---> train_recall : 0.5253716043054844 , test_recall : 0.5903614457831325
# epoch 40/200 ---> TN_test: 388, FP_test: 82, TP_test: 196, FN_test: 136
# epoch 40/200 ---> AUC_test: 0.7567034093822096
# epoch 40/200 ---> Precision_test: 0.7050359712230215
# epoch 41/200 ---> train_accuracy: 0.7218295335769653, test_accuracy: 0.7244389057159424
# epoch 41/200 ---> train_recall : 0.531009738595592 , test_recall : 0.5963855421686747
# epoch 41/200 ---> TN_test: 383, FP_test: 87, TP_test: 198, FN_test: 134
# epoch 41/200 ---> AUC_test: 0.7562868495257625
# epoch 41/200 ---> Precision_test: 0.6947368421052632
# epoch 42/200 ---> train_accuracy: 0.7203742265701294, test_accuracy: 0.7206982374191284
# epoch 42/200 ---> train_recall : 0.5397232188621219 , test_recall : 0.6024096385542169
# epoch 42/200 ---> TN_test: 378, FP_test: 92, TP_test: 200, FN_test: 132
# epoch 42/200 ---> AUC_test: 0.7566777749295053
# epoch 42/200 ---> Precision_test: 0.684931506849315
# epoch 43/200 ---> train_accuracy: 0.7255717515945435, test_accuracy: 0.7281795740127563
# epoch 43/200 ---> train_recall : 0.5299846232701179 , test_recall : 0.5933734939759037
# epoch 43/200 ---> TN_test: 387, FP_test: 83, TP_test: 197, FN_test: 135
# epoch 43/200 ---> AUC_test: 0.7581004870546013
# epoch 43/200 ---> Precision_test: 0.7035714285714286
# epoch 44/200 ---> train_accuracy: 0.7249480485916138, test_accuracy: 0.7256857752799988
# epoch 44/200 ---> train_recall : 0.531522296258329 , test_recall : 0.5993975903614458
# epoch 44/200 ---> TN_test: 383, FP_test: 87, TP_test: 199, FN_test: 133
# epoch 44/200 ---> AUC_test: 0.7580876698282493
# epoch 44/200 ---> Precision_test: 0.6958041958041958
# epoch 45/200 ---> train_accuracy: 0.7264033555984497, test_accuracy: 0.7206982374191284
# epoch 45/200 ---> train_recall : 0.5371604305484367 , test_recall : 0.5933734939759037
# epoch 45/200 ---> TN_test: 381, FP_test: 89, TP_test: 197, FN_test: 135
# epoch 45/200 ---> AUC_test: 0.7584721866188158
# epoch 45/200 ---> Precision_test: 0.6888111888111889
# epoch 46/200 ---> train_accuracy: 0.7261954545974731, test_accuracy: 0.7219451665878296
# epoch 46/200 ---> train_recall : 0.5284469502819067 , test_recall : 0.5903614457831325
# epoch 46/200 ---> TN_test: 383, FP_test: 87, TP_test: 196, FN_test: 136
# epoch 46/200 ---> AUC_test: 0.7591963599077161
# epoch 46/200 ---> Precision_test: 0.6925795053003534
# epoch 47/200 ---> train_accuracy: 0.7274428009986877, test_accuracy: 0.7206982374191284
# epoch 47/200 ---> train_recall : 0.5284469502819067 , test_recall : 0.5873493975903614
# epoch 47/200 ---> TN_test: 383, FP_test: 87, TP_test: 195, FN_test: 137
# epoch 47/200 ---> AUC_test: 0.7591322737759549
# epoch 47/200 ---> Precision_test: 0.6914893617021277
# epoch 48/200 ---> train_accuracy: 0.7259875535964966, test_accuracy: 0.7269326448440552
# epoch 48/200 ---> train_recall : 0.5345976422347514 , test_recall : 0.6054216867469879
# epoch 48/200 ---> TN_test: 382, FP_test: 88, TP_test: 201, FN_test: 131
# epoch 48/200 ---> AUC_test: 0.7598308126121507
# epoch 48/200 ---> Precision_test: 0.6955017301038062
# epoch 49/200 ---> train_accuracy: 0.7266111969947815, test_accuracy: 0.7269326448440552
# epoch 49/200 ---> train_recall : 0.5284469502819067 , test_recall : 0.5963855421686747
# epoch 49/200 ---> TN_test: 385, FP_test: 85, TP_test: 198, FN_test: 134
# epoch 49/200 ---> AUC_test: 0.7601896949500128
# epoch 49/200 ---> Precision_test: 0.6996466431095406
# epoch 50/200 ---> train_accuracy: 0.7266111969947815, test_accuracy: 0.7269326448440552
# epoch 50/200 ---> train_recall : 0.5325474115838031 , test_recall : 0.5963855421686747
# epoch 50/200 ---> TN_test: 385, FP_test: 85, TP_test: 198, FN_test: 134
# epoch 50/200 ---> AUC_test: 0.7599269418097924
# epoch 50/200 ---> Precision_test: 0.6996466431095406
# epoch 51/200 ---> train_accuracy: 0.72577965259552, test_accuracy: 0.7294264435768127
# epoch 51/200 ---> train_recall : 0.531522296258329 , test_recall : 0.6024096385542169
# epoch 51/200 ---> TN_test: 385, FP_test: 85, TP_test: 200, FN_test: 132
# epoch 51/200 ---> AUC_test: 0.760971545757498
# epoch 51/200 ---> Precision_test: 0.7017543859649122
# epoch 52/200 ---> train_accuracy: 0.7270269989967346, test_accuracy: 0.7281795740127563
# epoch 52/200 ---> train_recall : 0.5320348539210661 , test_recall : 0.5963855421686747
# epoch 52/200 ---> TN_test: 386, FP_test: 84, TP_test: 198, FN_test: 134
# epoch 52/200 ---> AUC_test: 0.7606062548064598
# epoch 52/200 ---> Precision_test: 0.7021276595744681
# epoch 53/200 ---> train_accuracy: 0.7255717515945435, test_accuracy: 0.7331671118736267
# epoch 53/200 ---> train_recall : 0.5274218349564326 , test_recall : 0.5993975903614458
# epoch 53/200 ---> TN_test: 389, FP_test: 81, TP_test: 199, FN_test: 133
# epoch 53/200 ---> AUC_test: 0.7613496539348885
# epoch 53/200 ---> Precision_test: 0.7107142857142857
# epoch 54/200 ---> train_accuracy: 0.7259875535964966, test_accuracy: 0.7281795740127563
# epoch 54/200 ---> train_recall : 0.5207585853408508 , test_recall : 0.5843373493975904
# epoch 54/200 ---> TN_test: 390, FP_test: 80, TP_test: 194, FN_test: 138
# epoch 54/200 ---> AUC_test: 0.7607792873622148
# epoch 54/200 ---> Precision_test: 0.708029197080292
# epoch 55/200 ---> train_accuracy: 0.7264033555984497, test_accuracy: 0.7319201827049255
# epoch 55/200 ---> train_recall : 0.5356227575602255 , test_recall : 0.6054216867469879
# epoch 55/200 ---> TN_test: 386, FP_test: 84, TP_test: 201, FN_test: 131
# epoch 55/200 ---> AUC_test: 0.7608433734939758
# epoch 55/200 ---> Precision_test: 0.7052631578947368
# epoch 56/200 ---> train_accuracy: 0.7259875535964966, test_accuracy: 0.7319201827049255
# epoch 56/200 ---> train_recall : 0.5279343926191696 , test_recall : 0.5963855421686747
# epoch 56/200 ---> TN_test: 389, FP_test: 81, TP_test: 198, FN_test: 134
# epoch 56/200 ---> AUC_test: 0.7615419123301719
# epoch 56/200 ---> Precision_test: 0.7096774193548387
# epoch 57/200 ---> train_accuracy: 0.72577965259552, test_accuracy: 0.7306733131408691
# epoch 57/200 ---> train_recall : 0.5299846232701179 , test_recall : 0.5933734939759037
# epoch 57/200 ---> TN_test: 389, FP_test: 81, TP_test: 197, FN_test: 135
# epoch 57/200 ---> AUC_test: 0.7613752883875929
# epoch 57/200 ---> Precision_test: 0.7086330935251799
# epoch 58/200 ---> train_accuracy: 0.72577965259552, test_accuracy: 0.7294264435768127
# epoch 58/200 ---> train_recall : 0.5248590466427473 , test_recall : 0.5873493975903614
# epoch 58/200 ---> TN_test: 390, FP_test: 80, TP_test: 195, FN_test: 137
# epoch 58/200 ---> AUC_test: 0.7617213534991027
# epoch 58/200 ---> Precision_test: 0.7090909090909091
# epoch 59/200 ---> train_accuracy: 0.7276507019996643, test_accuracy: 0.7356608510017395
# epoch 59/200 ---> train_recall : 0.5330599692465402 , test_recall : 0.6024096385542169
# epoch 59/200 ---> TN_test: 390, FP_test: 80, TP_test: 200, FN_test: 132
# epoch 59/200 ---> AUC_test: 0.7615483209433478
# epoch 59/200 ---> Precision_test: 0.7142857142857143
# epoch 60/200 ---> train_accuracy: 0.7266111969947815, test_accuracy: 0.7344139814376831
# epoch 60/200 ---> train_recall : 0.5330599692465402 , test_recall : 0.6024096385542169
# epoch 60/200 ---> TN_test: 389, FP_test: 81, TP_test: 200, FN_test: 132
# epoch 60/200 ---> AUC_test: 0.7615675467828762
# epoch 60/200 ---> Precision_test: 0.7117437722419929
# epoch 61/200 ---> train_accuracy: 0.7274428009986877, test_accuracy: 0.7344139814376831
# epoch 61/200 ---> train_recall : 0.5402357765248591 , test_recall : 0.6024096385542169
# epoch 61/200 ---> TN_test: 389, FP_test: 81, TP_test: 200, FN_test: 132
# epoch 61/200 ---> AUC_test: 0.7617533965649834
# epoch 61/200 ---> Precision_test: 0.7117437722419929
# epoch 62/200 ---> train_accuracy: 0.7268190979957581, test_accuracy: 0.7319201827049255
# epoch 62/200 ---> train_recall : 0.5284469502819067 , test_recall : 0.5933734939759037
# epoch 62/200 ---> TN_test: 390, FP_test: 80, TP_test: 197, FN_test: 135
# epoch 62/200 ---> AUC_test: 0.7626570110228148
# epoch 62/200 ---> Precision_test: 0.7111913357400722
# epoch 63/200 ---> train_accuracy: 0.7249480485916138, test_accuracy: 0.7306733131408691
# epoch 63/200 ---> train_recall : 0.5202460276781138 , test_recall : 0.5903614457831325
# epoch 63/200 ---> TN_test: 390, FP_test: 80, TP_test: 196, FN_test: 136
# epoch 63/200 ---> AUC_test: 0.7619264291207383
# epoch 63/200 ---> Precision_test: 0.7101449275362319
# epoch 64/200 ---> train_accuracy: 0.7274428009986877, test_accuracy: 0.7331671118736267
# epoch 64/200 ---> train_recall : 0.5284469502819067 , test_recall : 0.5963855421686747
# epoch 64/200 ---> TN_test: 390, FP_test: 80, TP_test: 198, FN_test: 134
# epoch 64/200 ---> AUC_test: 0.7622532683927199
# epoch 64/200 ---> Precision_test: 0.7122302158273381
# epoch 65/200 ---> train_accuracy: 0.7249480485916138, test_accuracy: 0.7319201827049255
# epoch 65/200 ---> train_recall : 0.5243464889800102 , test_recall : 0.5933734939759037
# epoch 65/200 ---> TN_test: 390, FP_test: 80, TP_test: 197, FN_test: 135
# epoch 65/200 ---> AUC_test: 0.7628428608049218
# epoch 65/200 ---> Precision_test: 0.7111913357400722
# epoch 66/200 ---> train_accuracy: 0.7280665040016174, test_accuracy: 0.7344139814376831
# epoch 66/200 ---> train_recall : 0.5361353152229625 , test_recall : 0.6024096385542169
# epoch 66/200 ---> TN_test: 389, FP_test: 81, TP_test: 200, FN_test: 132
# epoch 66/200 ---> AUC_test: 0.7627210971545757
# epoch 66/200 ---> Precision_test: 0.7117437722419929
# epoch 67/200 ---> train_accuracy: 0.7286902070045471, test_accuracy: 0.7331671118736267
# epoch 67/200 ---> train_recall : 0.5392106611993849 , test_recall : 0.6024096385542169
# epoch 67/200 ---> TN_test: 388, FP_test: 82, TP_test: 200, FN_test: 132
# epoch 67/200 ---> AUC_test: 0.7628749038708023
# epoch 67/200 ---> Precision_test: 0.7092198581560284
# epoch 68/200 ---> train_accuracy: 0.7245322465896606, test_accuracy: 0.7319201827049255
# epoch 68/200 ---> train_recall : 0.5161455663762173 , test_recall : 0.5873493975903614
# epoch 68/200 ---> TN_test: 392, FP_test: 78, TP_test: 195, FN_test: 137
# epoch 68/200 ---> AUC_test: 0.7630799794924379
# epoch 68/200 ---> Precision_test: 0.7142857142857143
# epoch 69/200 ---> train_accuracy: 0.72577965259552, test_accuracy: 0.7331671118736267
# epoch 69/200 ---> train_recall : 0.5202460276781138 , test_recall : 0.5933734939759037
# epoch 69/200 ---> TN_test: 391, FP_test: 79, TP_test: 197, FN_test: 135
# epoch 69/200 ---> AUC_test: 0.7627210971545758
# epoch 69/200 ---> Precision_test: 0.7137681159420289
# epoch 70/200 ---> train_accuracy: 0.7297297120094299, test_accuracy: 0.7306733131408691
# epoch 70/200 ---> train_recall : 0.5397232188621219 , test_recall : 0.5963855421686747
# epoch 70/200 ---> TN_test: 388, FP_test: 82, TP_test: 198, FN_test: 134
# epoch 70/200 ---> AUC_test: 0.7624006664957703
# epoch 70/200 ---> Precision_test: 0.7071428571428572
# epoch 71/200 ---> train_accuracy: 0.7303534150123596, test_accuracy: 0.7306733131408691
# epoch 71/200 ---> train_recall : 0.5376729882111737 , test_recall : 0.5963855421686747
# epoch 71/200 ---> TN_test: 388, FP_test: 82, TP_test: 198, FN_test: 134
# epoch 71/200 ---> AUC_test: 0.7624839784670598
# epoch 71/200 ---> Precision_test: 0.7071428571428572
# epoch 72/200 ---> train_accuracy: 0.7291060090065002, test_accuracy: 0.7294264435768127
# epoch 72/200 ---> train_recall : 0.5351101998974884 , test_recall : 0.5933734939759037
# epoch 72/200 ---> TN_test: 388, FP_test: 82, TP_test: 197, FN_test: 135
# epoch 72/200 ---> AUC_test: 0.7631056139451423
# epoch 72/200 ---> Precision_test: 0.7060931899641577
# epoch 73/200 ---> train_accuracy: 0.7286902070045471, test_accuracy: 0.7269326448440552
# epoch 73/200 ---> train_recall : 0.5340850845720143 , test_recall : 0.5933734939759037
# epoch 73/200 ---> TN_test: 386, FP_test: 84, TP_test: 197, FN_test: 135
# epoch 73/200 ---> AUC_test: 0.7627403229941041
# epoch 73/200 ---> Precision_test: 0.701067615658363
# epoch 74/200 ---> train_accuracy: 0.7270269989967346, test_accuracy: 0.7244389057159424
# epoch 74/200 ---> train_recall : 0.5407483341875962 , test_recall : 0.5963855421686747
# epoch 74/200 ---> TN_test: 383, FP_test: 87, TP_test: 198, FN_test: 134
# epoch 74/200 ---> AUC_test: 0.7620097410920277
# epoch 74/200 ---> Precision_test: 0.6947368421052632
# epoch 75/200 ---> train_accuracy: 0.7272348999977112, test_accuracy: 0.7281795740127563
# epoch 75/200 ---> train_recall : 0.5320348539210661 , test_recall : 0.5963855421686747
# epoch 75/200 ---> TN_test: 386, FP_test: 84, TP_test: 198, FN_test: 134
# epoch 75/200 ---> AUC_test: 0.7628172263522173
# epoch 75/200 ---> Precision_test: 0.7021276595744681
# epoch 76/200 ---> train_accuracy: 0.7284823060035706, test_accuracy: 0.7281795740127563
# epoch 76/200 ---> train_recall : 0.5340850845720143 , test_recall : 0.5903614457831325
# epoch 76/200 ---> TN_test: 388, FP_test: 82, TP_test: 196, FN_test: 136
# epoch 76/200 ---> AUC_test: 0.7637721097154575
# epoch 76/200 ---> Precision_test: 0.7050359712230215
# epoch 77/200 ---> train_accuracy: 0.7301455140113831, test_accuracy: 0.7294264435768127
# epoch 77/200 ---> train_recall : 0.5433111225012814 , test_recall : 0.6024096385542169
# epoch 77/200 ---> TN_test: 385, FP_test: 85, TP_test: 200, FN_test: 132
# epoch 77/200 ---> AUC_test: 0.7637400666495772
# epoch 77/200 ---> Precision_test: 0.7017543859649122
# epoch 78/200 ---> train_accuracy: 0.7291060090065002, test_accuracy: 0.7256857752799988
# epoch 78/200 ---> train_recall : 0.5443362378267556 , test_recall : 0.5993975903614458
# epoch 78/200 ---> TN_test: 383, FP_test: 87, TP_test: 199, FN_test: 133
# epoch 78/200 ---> AUC_test: 0.7623622148167137
# epoch 78/200 ---> Precision_test: 0.6958041958041958
# epoch 79/200 ---> train_accuracy: 0.7291060090065002, test_accuracy: 0.7294264435768127
# epoch 79/200 ---> train_recall : 0.547924141465915 , test_recall : 0.6024096385542169
# epoch 79/200 ---> TN_test: 385, FP_test: 85, TP_test: 200, FN_test: 132
# epoch 79/200 ---> AUC_test: 0.7634388618303
# epoch 79/200 ---> Precision_test: 0.7017543859649122
# epoch 80/200 ---> train_accuracy: 0.7303534150123596, test_accuracy: 0.7294264435768127
# epoch 80/200 ---> train_recall : 0.5443362378267556 , test_recall : 0.5993975903614458
# epoch 80/200 ---> TN_test: 386, FP_test: 84, TP_test: 199, FN_test: 133
# epoch 80/200 ---> AUC_test: 0.7636343245321713
# epoch 80/200 ---> Precision_test: 0.7031802120141343
# epoch 81/200 ---> train_accuracy: 0.7291060090065002, test_accuracy: 0.7269326448440552
# epoch 81/200 ---> train_recall : 0.5468990261404408 , test_recall : 0.5993975903614458
# epoch 81/200 ---> TN_test: 384, FP_test: 86, TP_test: 199, FN_test: 133
# epoch 81/200 ---> AUC_test: 0.7627275057677518
# epoch 81/200 ---> Precision_test: 0.6982456140350877
# epoch 82/200 ---> train_accuracy: 0.7318087220191956, test_accuracy: 0.7306733131408691
# epoch 82/200 ---> train_recall : 0.5361353152229625 , test_recall : 0.5933734939759037
# epoch 82/200 ---> TN_test: 389, FP_test: 81, TP_test: 197, FN_test: 135
# epoch 82/200 ---> AUC_test: 0.7627210971545757
# epoch 82/200 ---> Precision_test: 0.7086330935251799
# epoch 83/200 ---> train_accuracy: 0.7295218110084534, test_accuracy: 0.7269326448440552
# epoch 83/200 ---> train_recall : 0.5489492567913891 , test_recall : 0.5993975903614458
# epoch 83/200 ---> TN_test: 384, FP_test: 86, TP_test: 199, FN_test: 133
# epoch 83/200 ---> AUC_test: 0.7628044091258651
# epoch 83/200 ---> Precision_test: 0.6982456140350877
# epoch 84/200 ---> train_accuracy: 0.7295218110084534, test_accuracy: 0.7256857752799988
# epoch 84/200 ---> train_recall : 0.5453613531522297 , test_recall : 0.5963855421686747
# epoch 84/200 ---> TN_test: 384, FP_test: 86, TP_test: 198, FN_test: 134
# epoch 84/200 ---> AUC_test: 0.7628941297103307
# epoch 84/200 ---> Precision_test: 0.6971830985915493
# epoch 85/200 ---> train_accuracy: 0.7301455140113831, test_accuracy: 0.7294264435768127
# epoch 85/200 ---> train_recall : 0.5392106611993849 , test_recall : 0.5933734939759037
# epoch 85/200 ---> TN_test: 388, FP_test: 82, TP_test: 197, FN_test: 135
# epoch 85/200 ---> AUC_test: 0.7630030761343245
# epoch 85/200 ---> Precision_test: 0.7060931899641577
# epoch 86/200 ---> train_accuracy: 0.7297297120094299, test_accuracy: 0.7256857752799988
# epoch 86/200 ---> train_recall : 0.5356227575602255 , test_recall : 0.5933734939759037
# epoch 86/200 ---> TN_test: 385, FP_test: 85, TP_test: 197, FN_test: 135
# epoch 86/200 ---> AUC_test: 0.7628941297103307
# epoch 86/200 ---> Precision_test: 0.6985815602836879
# epoch 87/200 ---> train_accuracy: 0.7303534150123596, test_accuracy: 0.7281795740127563
# epoch 87/200 ---> train_recall : 0.5376729882111737 , test_recall : 0.5933734939759037
# epoch 87/200 ---> TN_test: 387, FP_test: 83, TP_test: 197, FN_test: 135
# epoch 87/200 ---> AUC_test: 0.763496539348885
# epoch 87/200 ---> Precision_test: 0.7035714285714286
# epoch 88/200 ---> train_accuracy: 0.7307692170143127, test_accuracy: 0.7281795740127563
# epoch 88/200 ---> train_recall : 0.5376729882111737 , test_recall : 0.5873493975903614
# epoch 88/200 ---> TN_test: 389, FP_test: 81, TP_test: 195, FN_test: 137
# epoch 88/200 ---> AUC_test: 0.7636118943860548
# epoch 88/200 ---> Precision_test: 0.7065217391304348
# epoch 89/200 ---> train_accuracy: 0.7301455140113831, test_accuracy: 0.723192036151886
# epoch 89/200 ---> train_recall : 0.5515120451050743 , test_recall : 0.5993975903614458
# epoch 89/200 ---> TN_test: 381, FP_test: 89, TP_test: 199, FN_test: 133
# epoch 89/200 ---> AUC_test: 0.7625160215329402
# epoch 89/200 ---> Precision_test: 0.6909722222222222
# epoch 90/200 ---> train_accuracy: 0.7305613160133362, test_accuracy: 0.7269326448440552
# epoch 90/200 ---> train_recall : 0.5325474115838031 , test_recall : 0.5873493975903614
# epoch 90/200 ---> TN_test: 388, FP_test: 82, TP_test: 195, FN_test: 137
# epoch 90/200 ---> AUC_test: 0.7629005383235068
# epoch 90/200 ---> Precision_test: 0.703971119133574
# epoch 91/200 ---> train_accuracy: 0.7301455140113831, test_accuracy: 0.7294264435768127
# epoch 91/200 ---> train_recall : 0.5417734495130703 , test_recall : 0.5963855421686747
# epoch 91/200 ---> TN_test: 387, FP_test: 83, TP_test: 198, FN_test: 134
# epoch 91/200 ---> AUC_test: 0.7632530120481927
# epoch 91/200 ---> Precision_test: 0.7046263345195729
# epoch 92/200 ---> train_accuracy: 0.7305613160133362, test_accuracy: 0.7256857752799988
# epoch 92/200 ---> train_recall : 0.5417734495130703 , test_recall : 0.5933734939759037
# epoch 92/200 ---> TN_test: 385, FP_test: 85, TP_test: 197, FN_test: 135
# epoch 92/200 ---> AUC_test: 0.7630030761343246
# epoch 92/200 ---> Precision_test: 0.6985815602836879
# epoch 93/200 ---> train_accuracy: 0.7309771180152893, test_accuracy: 0.7244389057159424
# epoch 93/200 ---> train_recall : 0.5509994874423373 , test_recall : 0.5993975903614458
# epoch 93/200 ---> TN_test: 382, FP_test: 88, TP_test: 199, FN_test: 133
# epoch 93/200 ---> AUC_test: 0.7623301717508332
# epoch 93/200 ---> Precision_test: 0.6933797909407665
# epoch 94/200 ---> train_accuracy: 0.7305613160133362, test_accuracy: 0.7294264435768127
# epoch 94/200 ---> train_recall : 0.5397232188621219 , test_recall : 0.5963855421686747
# epoch 94/200 ---> TN_test: 387, FP_test: 83, TP_test: 198, FN_test: 134
# epoch 94/200 ---> AUC_test: 0.763150474237375
# epoch 94/200 ---> Precision_test: 0.7046263345195729
# epoch 95/200 ---> train_accuracy: 0.7313929200172424, test_accuracy: 0.7256857752799988
# epoch 95/200 ---> train_recall : 0.5412608918503332 , test_recall : 0.5903614457831325
# epoch 95/200 ---> TN_test: 386, FP_test: 84, TP_test: 196, FN_test: 136
# epoch 95/200 ---> AUC_test: 0.7628813124839784
# epoch 95/200 ---> Precision_test: 0.7
# epoch 96/200 ---> train_accuracy: 0.7288981080055237, test_accuracy: 0.7281795740127563
# epoch 96/200 ---> train_recall : 0.5361353152229625 , test_recall : 0.5933734939759037
# epoch 96/200 ---> TN_test: 387, FP_test: 83, TP_test: 197, FN_test: 135
# epoch 96/200 ---> AUC_test: 0.7624583440143553
# epoch 96/200 ---> Precision_test: 0.7035714285714286
# epoch 97/200 ---> train_accuracy: 0.7309771180152893, test_accuracy: 0.7269326448440552
# epoch 97/200 ---> train_recall : 0.5448487954894926 , test_recall : 0.5993975903614458
# epoch 97/200 ---> TN_test: 384, FP_test: 86, TP_test: 199, FN_test: 133
# epoch 97/200 ---> AUC_test: 0.7625288387592926
# epoch 97/200 ---> Precision_test: 0.6982456140350877
# epoch 98/200 ---> train_accuracy: 0.7311850190162659, test_accuracy: 0.7219451665878296
# epoch 98/200 ---> train_recall : 0.5550999487442337 , test_recall : 0.6054216867469879
# epoch 98/200 ---> TN_test: 378, FP_test: 92, TP_test: 201, FN_test: 131
# epoch 98/200 ---> AUC_test: 0.7622212253268392
# epoch 98/200 ---> Precision_test: 0.6860068259385665
# epoch 99/200 ---> train_accuracy: 0.7295218110084534, test_accuracy: 0.7244389057159424
# epoch 99/200 ---> train_recall : 0.5402357765248591 , test_recall : 0.5933734939759037
# epoch 99/200 ---> TN_test: 384, FP_test: 86, TP_test: 197, FN_test: 135
# epoch 99/200 ---> AUC_test: 0.7623750320430659
# epoch 99/200 ---> Precision_test: 0.696113074204947
# epoch 100/200 ---> train_accuracy: 0.7295218110084534, test_accuracy: 0.7269326448440552
# epoch 100/200 ---> train_recall : 0.5417734495130703 , test_recall : 0.5963855421686747
# epoch 100/200 ---> TN_test: 385, FP_test: 85, TP_test: 198, FN_test: 134
# epoch 100/200 ---> AUC_test: 0.7627146885413997
# epoch 100/200 ---> Precision_test: 0.6996466431095406
# epoch 101/200 ---> train_accuracy: 0.7311850190162659, test_accuracy: 0.7281795740127563
# epoch 101/200 ---> train_recall : 0.5366478728856996 , test_recall : 0.5903614457831325
# epoch 101/200 ---> TN_test: 388, FP_test: 82, TP_test: 196, FN_test: 136
# epoch 101/200 ---> AUC_test: 0.7627403229941039
# epoch 101/200 ---> Precision_test: 0.7050359712230215
# epoch 102/200 ---> train_accuracy: 0.7301455140113831, test_accuracy: 0.7256857752799988
# epoch 102/200 ---> train_recall : 0.5509994874423373 , test_recall : 0.6024096385542169
# epoch 102/200 ---> TN_test: 382, FP_test: 88, TP_test: 200, FN_test: 132
# epoch 102/200 ---> AUC_test: 0.7625993335042297
# epoch 102/200 ---> Precision_test: 0.6944444444444444
# epoch 103/200 ---> train_accuracy: 0.7293139100074768, test_accuracy: 0.7244389057159424
# epoch 103/200 ---> train_recall : 0.5433111225012814 , test_recall : 0.5963855421686747
# epoch 103/200 ---> TN_test: 383, FP_test: 87, TP_test: 198, FN_test: 134
# epoch 103/200 ---> AUC_test: 0.7624134837221225
# epoch 103/200 ---> Precision_test: 0.6947368421052632
# epoch 104/200 ---> train_accuracy: 0.7295218110084534, test_accuracy: 0.723192036151886
# epoch 104/200 ---> train_recall : 0.5376729882111737 , test_recall : 0.5903614457831325
# epoch 104/200 ---> TN_test: 384, FP_test: 86, TP_test: 196, FN_test: 136
# epoch 104/200 ---> AUC_test: 0.7626634196359907
# epoch 104/200 ---> Precision_test: 0.6950354609929078
# epoch 105/200 ---> train_accuracy: 0.7286902070045471, test_accuracy: 0.7256857752799988
# epoch 105/200 ---> train_recall : 0.5448487954894926 , test_recall : 0.5993975903614458
# epoch 105/200 ---> TN_test: 383, FP_test: 87, TP_test: 199, FN_test: 133
# epoch 105/200 ---> AUC_test: 0.7622532683927199
# epoch 105/200 ---> Precision_test: 0.6958041958041958
# epoch 106/200 ---> train_accuracy: 0.7291060090065002, test_accuracy: 0.723192036151886
# epoch 106/200 ---> train_recall : 0.5356227575602255 , test_recall : 0.5843373493975904
# epoch 106/200 ---> TN_test: 386, FP_test: 84, TP_test: 194, FN_test: 138
# epoch 106/200 ---> AUC_test: 0.7621186875160215
# epoch 106/200 ---> Precision_test: 0.697841726618705
# epoch 107/200 ---> train_accuracy: 0.7293139100074768, test_accuracy: 0.7269326448440552
# epoch 107/200 ---> train_recall : 0.547924141465915 , test_recall : 0.6054216867469879
# epoch 107/200 ---> TN_test: 382, FP_test: 88, TP_test: 201, FN_test: 131
# epoch 107/200 ---> AUC_test: 0.7619776980261472
# epoch 107/200 ---> Precision_test: 0.6955017301038062
# epoch 108/200 ---> train_accuracy: 0.7288981080055237, test_accuracy: 0.7244389057159424
# epoch 108/200 ---> train_recall : 0.5361353152229625 , test_recall : 0.5933734939759037
# epoch 108/200 ---> TN_test: 384, FP_test: 86, TP_test: 197, FN_test: 135
# epoch 108/200 ---> AUC_test: 0.7616508587541656
# epoch 108/200 ---> Precision_test: 0.696113074204947
# epoch 109/200 ---> train_accuracy: 0.7291060090065002, test_accuracy: 0.7256857752799988
# epoch 109/200 ---> train_recall : 0.5448487954894926 , test_recall : 0.6024096385542169
# epoch 109/200 ---> TN_test: 382, FP_test: 88, TP_test: 200, FN_test: 132
# epoch 109/200 ---> AUC_test: 0.7620417841579081
# epoch 109/200 ---> Precision_test: 0.6944444444444444
# epoch 110/200 ---> train_accuracy: 0.7288981080055237, test_accuracy: 0.7244389057159424
# epoch 110/200 ---> train_recall : 0.5392106611993849 , test_recall : 0.5963855421686747
# epoch 110/200 ---> TN_test: 383, FP_test: 87, TP_test: 198, FN_test: 134
# epoch 110/200 ---> AUC_test: 0.7615419123301717
# epoch 110/200 ---> Precision_test: 0.6947368421052632
# epoch 111/200 ---> train_accuracy: 0.7288981080055237, test_accuracy: 0.7294264435768127
# epoch 111/200 ---> train_recall : 0.5438236801640185 , test_recall : 0.608433734939759
# epoch 111/200 ---> TN_test: 383, FP_test: 87, TP_test: 202, FN_test: 130
# epoch 111/200 ---> AUC_test: 0.7613945142271212
# epoch 111/200 ---> Precision_test: 0.698961937716263
# epoch 112/200 ---> train_accuracy: 0.7295218110084534, test_accuracy: 0.7269326448440552
# epoch 112/200 ---> train_recall : 0.5433111225012814 , test_recall : 0.6024096385542169
# epoch 112/200 ---> TN_test: 383, FP_test: 87, TP_test: 200, FN_test: 132
# epoch 112/200 ---> AUC_test: 0.7622724942322482
# epoch 112/200 ---> Precision_test: 0.6968641114982579
# epoch 113/200 ---> train_accuracy: 0.7293139100074768, test_accuracy: 0.7281795740127563
# epoch 113/200 ---> train_recall : 0.5525371604305485 , test_recall : 0.608433734939759
# epoch 113/200 ---> TN_test: 382, FP_test: 88, TP_test: 202, FN_test: 130
# epoch 113/200 ---> AUC_test: 0.7612855678031274
# epoch 113/200 ---> Precision_test: 0.696551724137931
# epoch 114/200 ---> train_accuracy: 0.7286902070045471, test_accuracy: 0.7256857752799988
# epoch 114/200 ---> train_recall : 0.5489492567913891 , test_recall : 0.6054216867469879
# epoch 114/200 ---> TN_test: 381, FP_test: 89, TP_test: 201, FN_test: 131
# epoch 114/200 ---> AUC_test: 0.7611125352473725
# epoch 114/200 ---> Precision_test: 0.6931034482758621
# epoch 115/200 ---> train_accuracy: 0.7299376130104065, test_accuracy: 0.7306733131408691
# epoch 115/200 ---> train_recall : 0.5494618144541261 , test_recall : 0.608433734939759
# epoch 115/200 ---> TN_test: 384, FP_test: 86, TP_test: 202, FN_test: 130
# epoch 115/200 ---> AUC_test: 0.7617790310176877
# epoch 115/200 ---> Precision_test: 0.7013888888888888
# epoch 116/200 ---> train_accuracy: 0.7297297120094299, test_accuracy: 0.7281795740127563
# epoch 116/200 ---> train_recall : 0.5412608918503332 , test_recall : 0.6024096385542169
# epoch 116/200 ---> TN_test: 384, FP_test: 86, TP_test: 200, FN_test: 132
# epoch 116/200 ---> AUC_test: 0.7609779543706742
# epoch 116/200 ---> Precision_test: 0.6993006993006993
# epoch 117/200 ---> train_accuracy: 0.7303534150123596, test_accuracy: 0.7281795740127563
# epoch 117/200 ---> train_recall : 0.5525371604305485 , test_recall : 0.6144578313253012
# epoch 117/200 ---> TN_test: 380, FP_test: 90, TP_test: 204, FN_test: 128
# epoch 117/200 ---> AUC_test: 0.7608241476544476
# epoch 117/200 ---> Precision_test: 0.6938775510204082
# epoch 118/200 ---> train_accuracy: 0.731600821018219, test_accuracy: 0.7281795740127563
# epoch 118/200 ---> train_recall : 0.5474115838031779 , test_recall : 0.6054216867469879
# epoch 118/200 ---> TN_test: 383, FP_test: 87, TP_test: 201, FN_test: 131
# epoch 118/200 ---> AUC_test: 0.7615355037169956
# epoch 118/200 ---> Precision_test: 0.6979166666666666
# epoch 119/200 ---> train_accuracy: 0.7311850190162659, test_accuracy: 0.723192036151886
# epoch 119/200 ---> train_recall : 0.5468990261404408 , test_recall : 0.5993975903614458
# epoch 119/200 ---> TN_test: 381, FP_test: 89, TP_test: 199, FN_test: 133
# epoch 119/200 ---> AUC_test: 0.761727762112279
# epoch 119/200 ---> Precision_test: 0.6909722222222222
# epoch 120/200 ---> train_accuracy: 0.7301455140113831, test_accuracy: 0.7219451665878296
# epoch 120/200 ---> train_recall : 0.5520246027678114 , test_recall : 0.5993975903614458
# epoch 120/200 ---> TN_test: 380, FP_test: 90, TP_test: 199, FN_test: 133
# epoch 120/200 ---> AUC_test: 0.7617085362727506
# epoch 120/200 ---> Precision_test: 0.6885813148788927
# epoch 121/200 ---> train_accuracy: 0.728274405002594, test_accuracy: 0.7269326448440552
# epoch 121/200 ---> train_recall : 0.5443362378267556 , test_recall : 0.6054216867469879
# epoch 121/200 ---> TN_test: 382, FP_test: 88, TP_test: 201, FN_test: 131
# epoch 121/200 ---> AUC_test: 0.7610484491156114
# epoch 121/200 ---> Precision_test: 0.6955017301038062
# epoch 122/200 ---> train_accuracy: 0.7313929200172424, test_accuracy: 0.7256857752799988
# epoch 122/200 ---> train_recall : 0.547924141465915 , test_recall : 0.6054216867469879
# epoch 122/200 ---> TN_test: 381, FP_test: 89, TP_test: 201, FN_test: 131
# epoch 122/200 ---> AUC_test: 0.7610612663419637
# epoch 122/200 ---> Precision_test: 0.6931034482758621
# epoch 123/200 ---> train_accuracy: 0.7297297120094299, test_accuracy: 0.7256857752799988
# epoch 123/200 ---> train_recall : 0.5453613531522297 , test_recall : 0.6024096385542169
# epoch 123/200 ---> TN_test: 382, FP_test: 88, TP_test: 200, FN_test: 132
# epoch 123/200 ---> AUC_test: 0.7617021276595746
# epoch 123/200 ---> Precision_test: 0.6944444444444444
# epoch 124/200 ---> train_accuracy: 0.7318087220191956, test_accuracy: 0.7281795740127563
# epoch 124/200 ---> train_recall : 0.5453613531522297 , test_recall : 0.6024096385542169
# epoch 124/200 ---> TN_test: 384, FP_test: 86, TP_test: 200, FN_test: 132
# epoch 124/200 ---> AUC_test: 0.7610869007946679
# epoch 124/200 ---> Precision_test: 0.6993006993006993
# epoch 125/200 ---> train_accuracy: 0.7295218110084534, test_accuracy: 0.7281795740127563
# epoch 125/200 ---> train_recall : 0.5386981035366478 , test_recall : 0.5963855421686747
# epoch 125/200 ---> TN_test: 386, FP_test: 84, TP_test: 198, FN_test: 134
# epoch 125/200 ---> AUC_test: 0.7608113304280955
# epoch 125/200 ---> Precision_test: 0.7021276595744681
# epoch 126/200 ---> train_accuracy: 0.7303534150123596, test_accuracy: 0.7219451665878296
# epoch 126/200 ---> train_recall : 0.5530497180932855 , test_recall : 0.6054216867469879
# epoch 126/200 ---> TN_test: 378, FP_test: 92, TP_test: 201, FN_test: 131
# epoch 126/200 ---> AUC_test: 0.7609843629838503
# epoch 126/200 ---> Precision_test: 0.6860068259385665
# epoch 127/200 ---> train_accuracy: 0.7299376130104065, test_accuracy: 0.723192036151886
# epoch 127/200 ---> train_recall : 0.548436699128652 , test_recall : 0.6024096385542169
# epoch 127/200 ---> TN_test: 380, FP_test: 90, TP_test: 200, FN_test: 132
# epoch 127/200 ---> AUC_test: 0.760971545757498
# epoch 127/200 ---> Precision_test: 0.6896551724137931
# epoch 128/200 ---> train_accuracy: 0.7313929200172424, test_accuracy: 0.723192036151886
# epoch 128/200 ---> train_recall : 0.5458739108149667 , test_recall : 0.5963855421686747
# epoch 128/200 ---> TN_test: 382, FP_test: 88, TP_test: 198, FN_test: 134
# epoch 128/200 ---> AUC_test: 0.7610356318892593
# epoch 128/200 ---> Precision_test: 0.6923076923076923
# epoch 129/200 ---> train_accuracy: 0.7311850190162659, test_accuracy: 0.7269326448440552
# epoch 129/200 ---> train_recall : 0.5356227575602255 , test_recall : 0.5933734939759037
# epoch 129/200 ---> TN_test: 386, FP_test: 84, TP_test: 197, FN_test: 135
# epoch 129/200 ---> AUC_test: 0.7605934375801077
# epoch 129/200 ---> Precision_test: 0.701067615658363
# epoch 130/200 ---> train_accuracy: 0.7309771180152893, test_accuracy: 0.7281795740127563
# epoch 130/200 ---> train_recall : 0.5520246027678114 , test_recall : 0.608433734939759
# epoch 130/200 ---> TN_test: 382, FP_test: 88, TP_test: 202, FN_test: 130
# epoch 130/200 ---> AUC_test: 0.7604524480902335
# epoch 130/200 ---> Precision_test: 0.696551724137931
# epoch 131/200 ---> train_accuracy: 0.7305613160133362, test_accuracy: 0.7306733131408691
# epoch 131/200 ---> train_recall : 0.5407483341875962 , test_recall : 0.6024096385542169
# epoch 131/200 ---> TN_test: 386, FP_test: 84, TP_test: 200, FN_test: 132
# epoch 131/200 ---> AUC_test: 0.7603947705716483
# epoch 131/200 ---> Precision_test: 0.704225352112676
# epoch 132/200 ---> train_accuracy: 0.7313929200172424, test_accuracy: 0.7306733131408691
# epoch 132/200 ---> train_recall : 0.5386981035366478 , test_recall : 0.6024096385542169
# epoch 132/200 ---> TN_test: 386, FP_test: 84, TP_test: 200, FN_test: 132
# epoch 132/200 ---> AUC_test: 0.7602794155344783
# epoch 132/200 ---> Precision_test: 0.704225352112676
# epoch 133/200 ---> train_accuracy: 0.7320166230201721, test_accuracy: 0.7256857752799988
# epoch 133/200 ---> train_recall : 0.5458739108149667 , test_recall : 0.6024096385542169
# epoch 133/200 ---> TN_test: 382, FP_test: 88, TP_test: 200, FN_test: 132
# epoch 133/200 ---> AUC_test: 0.7605101256088183
# epoch 133/200 ---> Precision_test: 0.6944444444444444
# epoch 134/200 ---> train_accuracy: 0.731600821018219, test_accuracy: 0.7256857752799988
# epoch 134/200 ---> train_recall : 0.5443362378267556 , test_recall : 0.6024096385542169
# epoch 134/200 ---> TN_test: 382, FP_test: 88, TP_test: 200, FN_test: 132
# epoch 134/200 ---> AUC_test: 0.7606447064855166
# epoch 134/200 ---> Precision_test: 0.6944444444444444
# epoch 135/200 ---> train_accuracy: 0.7328482270240784, test_accuracy: 0.7269326448440552
# epoch 135/200 ---> train_recall : 0.5463864684777038 , test_recall : 0.6024096385542169
# epoch 135/200 ---> TN_test: 383, FP_test: 87, TP_test: 200, FN_test: 132
# epoch 135/200 ---> AUC_test: 0.7605421686746988
# epoch 135/200 ---> Precision_test: 0.6968641114982579
# epoch 136/200 ---> train_accuracy: 0.7293139100074768, test_accuracy: 0.7256857752799988
# epoch 136/200 ---> train_recall : 0.5427985648385444 , test_recall : 0.6024096385542169
# epoch 136/200 ---> TN_test: 382, FP_test: 88, TP_test: 200, FN_test: 132
# epoch 136/200 ---> AUC_test: 0.7601576518841323
# epoch 136/200 ---> Precision_test: 0.6944444444444444
# epoch 137/200 ---> train_accuracy: 0.7295218110084534, test_accuracy: 0.7206982374191284
# epoch 137/200 ---> train_recall : 0.548436699128652 , test_recall : 0.6024096385542169
# epoch 137/200 ---> TN_test: 378, FP_test: 92, TP_test: 200, FN_test: 132
# epoch 137/200 ---> AUC_test: 0.7605229428351704
# epoch 137/200 ---> Precision_test: 0.684931506849315
# ...
# epoch 154/200 ---> TN_test: 379, FP_test: 91, TP_test: 200, FN_test: 132
# epoch 154/200 ---> AUC_test: 0.7600102537810818
# epoch 154/200 ---> Precision_test: 0.6872852233676976
# epoch 155/200 ---> train_accuracy: 0.7328482270240784, test_accuracy: 0.7206982374191284
# epoch 155/200 ---> train_recall : 0.5509994874423373 , test_recall : 0.5993975903614458
# epoch 155/200 ---> TN_test: 379, FP_test: 91, TP_test: 199, FN_test: 133
# epoch 155/200 ---> AUC_test: 0.7599333504229685
# epoch 155/200 ---> Precision_test: 0.6862068965517242
# epoch 156/200 ---> train_accuracy: 0.7326403260231018, test_accuracy: 0.7219451665878296
# epoch 156/200 ---> train_recall : 0.5545873910814967 , test_recall : 0.6024096385542169
# epoch 156/200 ---> TN_test: 379, FP_test: 91, TP_test: 200, FN_test: 132
# epoch 156/200 ---> AUC_test: 0.7597410920276851
# epoch 156/200 ---> Precision_test: 0.6872852233676976
# epoch 157/200 ---> train_accuracy: 0.7322245240211487, test_accuracy: 0.7219451665878296
# epoch 157/200 ---> train_recall : 0.5515120451050743 , test_recall : 0.5993975903614458
# epoch 157/200 ---> TN_test: 380, FP_test: 90, TP_test: 199, FN_test: 133
# epoch 157/200 ---> AUC_test: 0.7599589848756729
# epoch 157/200 ---> Precision_test: 0.6885813148788927
# epoch 158/200 ---> train_accuracy: 0.731600821018219, test_accuracy: 0.7244389057159424
# epoch 158/200 ---> train_recall : 0.5463864684777038 , test_recall : 0.5993975903614458
# epoch 158/200 ---> TN_test: 382, FP_test: 88, TP_test: 199, FN_test: 133
# epoch 158/200 ---> AUC_test: 0.7597410920276851
# epoch 158/200 ---> Precision_test: 0.6933797909407665
# epoch 159/200 ---> train_accuracy: 0.7324324250221252, test_accuracy: 0.7206982374191284
# epoch 159/200 ---> train_recall : 0.5520246027678114 , test_recall : 0.6024096385542169
# epoch 159/200 ---> TN_test: 378, FP_test: 92, TP_test: 200, FN_test: 132
# epoch 159/200 ---> AUC_test: 0.7598244039989746
# epoch 159/200 ---> Precision_test: 0.684931506849315
# epoch 160/200 ---> train_accuracy: 0.7332640290260315, test_accuracy: 0.7269326448440552
# epoch 160/200 ---> train_recall : 0.5438236801640185 , test_recall : 0.5993975903614458
# epoch 160/200 ---> TN_test: 384, FP_test: 86, TP_test: 199, FN_test: 133
# epoch 160/200 ---> AUC_test: 0.7595424250192258
# epoch 160/200 ---> Precision_test: 0.6982456140350877
# epoch 161/200 ---> train_accuracy: 0.7343035340309143, test_accuracy: 0.7244389057159424
# epoch 161/200 ---> train_recall : 0.5463864684777038 , test_recall : 0.5993975903614458
# epoch 161/200 ---> TN_test: 382, FP_test: 88, TP_test: 199, FN_test: 133
# epoch 161/200 ---> AUC_test: 0.7589143809279671
# epoch 161/200 ---> Precision_test: 0.6933797909407665
# epoch 162/200 ---> train_accuracy: 0.7330561280250549, test_accuracy: 0.7306733131408691
# epoch 162/200 ---> train_recall : 0.5376729882111737 , test_recall : 0.5963855421686747
# epoch 162/200 ---> TN_test: 388, FP_test: 82, TP_test: 198, FN_test: 134
# epoch 162/200 ---> AUC_test: 0.7592860804921815
# epoch 162/200 ---> Precision_test: 0.7071428571428572
# epoch 163/200 ---> train_accuracy: 0.7340956330299377, test_accuracy: 0.7244389057159424
# epoch 163/200 ---> train_recall : 0.5489492567913891 , test_recall : 0.5993975903614458
# epoch 163/200 ---> TN_test: 382, FP_test: 88, TP_test: 199, FN_test: 133
# epoch 163/200 ---> AUC_test: 0.759311714944886
# epoch 163/200 ---> Precision_test: 0.6933797909407665
# epoch 164/200 ---> train_accuracy: 0.731600821018219, test_accuracy: 0.7182044982910156
# epoch 164/200 ---> train_recall : 0.5515120451050743 , test_recall : 0.6024096385542169
# epoch 164/200 ---> TN_test: 376, FP_test: 94, TP_test: 200, FN_test: 132
# epoch 164/200 ---> AUC_test: 0.7590233273519611
# epoch 164/200 ---> Precision_test: 0.6802721088435374
# epoch 165/200 ---> train_accuracy: 0.7338877320289612, test_accuracy: 0.7244389057159424
# epoch 165/200 ---> train_recall : 0.548436699128652 , test_recall : 0.5993975903614458
# epoch 165/200 ---> TN_test: 382, FP_test: 88, TP_test: 199, FN_test: 133
# epoch 165/200 ---> AUC_test: 0.7586259933350423
# epoch 165/200 ---> Precision_test: 0.6933797909407665
# epoch 166/200 ---> train_accuracy: 0.7336798310279846, test_accuracy: 0.7219451665878296
# epoch 166/200 ---> train_recall : 0.5540748334187596 , test_recall : 0.6024096385542169
# epoch 166/200 ---> TN_test: 379, FP_test: 91, TP_test: 200, FN_test: 132
# epoch 166/200 ---> AUC_test: 0.7588246603435016
# epoch 166/200 ---> Precision_test: 0.6872852233676976
# epoch 167/200 ---> train_accuracy: 0.7340956330299377, test_accuracy: 0.7206982374191284
# epoch 167/200 ---> train_recall : 0.5550999487442337 , test_recall : 0.6024096385542169
# epoch 167/200 ---> TN_test: 378, FP_test: 92, TP_test: 200, FN_test: 132
# epoch 167/200 ---> AUC_test: 0.7591771340681877
# epoch 167/200 ---> Precision_test: 0.684931506849315
# epoch 168/200 ---> train_accuracy: 0.7330561280250549, test_accuracy: 0.7269326448440552
# epoch 168/200 ---> train_recall : 0.5509994874423373 , test_recall : 0.608433734939759
# epoch 168/200 ---> TN_test: 381, FP_test: 89, TP_test: 202, FN_test: 130
# epoch 168/200 ---> AUC_test: 0.7585939502691618
# epoch 168/200 ---> Precision_test: 0.6941580756013745
# epoch 169/200 ---> train_accuracy: 0.7334719300270081, test_accuracy: 0.723192036151886
# epoch 169/200 ---> train_recall : 0.5535622757560226 , test_recall : 0.5993975903614458
# epoch 169/200 ---> TN_test: 381, FP_test: 89, TP_test: 199, FN_test: 133
# epoch 169/200 ---> AUC_test: 0.7591002307100745
# epoch 169/200 ---> Precision_test: 0.6909722222222222
# epoch 170/200 ---> train_accuracy: 0.7328482270240784, test_accuracy: 0.7244389057159424
# epoch 170/200 ---> train_recall : 0.5489492567913891 , test_recall : 0.6024096385542169
# epoch 170/200 ---> TN_test: 381, FP_test: 89, TP_test: 200, FN_test: 132
# epoch 170/200 ---> AUC_test: 0.7591771340681877
# epoch 170/200 ---> Precision_test: 0.6920415224913494
# epoch 171/200 ---> train_accuracy: 0.7336798310279846, test_accuracy: 0.7256857752799988
# epoch 171/200 ---> train_recall : 0.5474115838031779 , test_recall : 0.5993975903614458
# epoch 171/200 ---> TN_test: 383, FP_test: 87, TP_test: 199, FN_test: 133
# epoch 171/200 ---> AUC_test: 0.7586964880799794
# epoch 171/200 ---> Precision_test: 0.6958041958041958
# epoch 172/200 ---> train_accuracy: 0.7338877320289612, test_accuracy: 0.7182044982910156
# epoch 172/200 ---> train_recall : 0.5545873910814967 , test_recall : 0.6024096385542169
# epoch 172/200 ---> TN_test: 376, FP_test: 94, TP_test: 200, FN_test: 132
# epoch 172/200 ---> AUC_test: 0.758670853627275
# epoch 172/200 ---> Precision_test: 0.6802721088435374
# epoch 173/200 ---> train_accuracy: 0.7334719300270081, test_accuracy: 0.723192036151886
# epoch 173/200 ---> train_recall : 0.5499743721168632 , test_recall : 0.5993975903614458
# epoch 173/200 ---> TN_test: 381, FP_test: 89, TP_test: 199, FN_test: 133
# epoch 173/200 ---> AUC_test: 0.7587669828249167
# epoch 173/200 ---> Precision_test: 0.6909722222222222
# epoch 174/200 ---> train_accuracy: 0.7343035340309143, test_accuracy: 0.723192036151886
# epoch 174/200 ---> train_recall : 0.5535622757560226 , test_recall : 0.5993975903614458
# epoch 174/200 ---> TN_test: 381, FP_test: 89, TP_test: 199, FN_test: 133
# epoch 174/200 ---> AUC_test: 0.7582735196103564
# epoch 174/200 ---> Precision_test: 0.6909722222222222
# epoch 175/200 ---> train_accuracy: 0.7322245240211487, test_accuracy: 0.7219451665878296
# epoch 175/200 ---> train_recall : 0.5556125064069708 , test_recall : 0.6024096385542169
# epoch 175/200 ---> TN_test: 379, FP_test: 91, TP_test: 200, FN_test: 132
# epoch 175/200 ---> AUC_test: 0.7585554985901051
# epoch 175/200 ---> Precision_test: 0.6872852233676976
# epoch 176/200 ---> train_accuracy: 0.7328482270240784, test_accuracy: 0.7219451665878296
# epoch 176/200 ---> train_recall : 0.5561250640697079 , test_recall : 0.6024096385542169
# epoch 176/200 ---> TN_test: 379, FP_test: 91, TP_test: 200, FN_test: 132
# epoch 176/200 ---> AUC_test: 0.7582158420917714
# epoch 176/200 ---> Precision_test: 0.6872852233676976
# epoch 177/200 ---> train_accuracy: 0.7347193360328674, test_accuracy: 0.7182044982910156
# epoch 177/200 ---> train_recall : 0.5607380830343414 , test_recall : 0.6024096385542169
# epoch 177/200 ---> TN_test: 376, FP_test: 94, TP_test: 200, FN_test: 132
# epoch 177/200 ---> AUC_test: 0.7583247885157652
# epoch 177/200 ---> Precision_test: 0.6802721088435374
# epoch 178/200 ---> train_accuracy: 0.7343035340309143, test_accuracy: 0.7256857752799988
# epoch 178/200 ---> train_recall : 0.547924141465915 , test_recall : 0.6024096385542169
# epoch 178/200 ---> TN_test: 382, FP_test: 88, TP_test: 200, FN_test: 132
# epoch 178/200 ---> AUC_test: 0.7591002307100744
# epoch 178/200 ---> Precision_test: 0.6944444444444444
# epoch 179/200 ---> train_accuracy: 0.7328482270240784, test_accuracy: 0.7182044982910156
# epoch 179/200 ---> train_recall : 0.5597129677088672 , test_recall : 0.6024096385542169
# epoch 179/200 ---> TN_test: 376, FP_test: 94, TP_test: 200, FN_test: 132
# epoch 179/200 ---> AUC_test: 0.7584273263265829
# epoch 179/200 ---> Precision_test: 0.6802721088435374
# epoch 180/200 ---> train_accuracy: 0.7332640290260315, test_accuracy: 0.723192036151886
# epoch 180/200 ---> train_recall : 0.5550999487442337 , test_recall : 0.6054216867469879
# epoch 180/200 ---> TN_test: 379, FP_test: 91, TP_test: 201, FN_test: 131
# epoch 180/200 ---> AUC_test: 0.7582030248654192
# epoch 180/200 ---> Precision_test: 0.6883561643835616
# epoch 181/200 ---> train_accuracy: 0.7340956330299377, test_accuracy: 0.7256857752799988
# epoch 181/200 ---> train_recall : 0.5474115838031779 , test_recall : 0.5993975903614458
# epoch 181/200 ---> TN_test: 383, FP_test: 87, TP_test: 199, FN_test: 133
# epoch 181/200 ---> AUC_test: 0.7584209177134069
# epoch 181/200 ---> Precision_test: 0.6958041958041958
# epoch 182/200 ---> train_accuracy: 0.7334719300270081, test_accuracy: 0.723192036151886
# epoch 182/200 ---> train_recall : 0.547924141465915 , test_recall : 0.6024096385542169
# epoch 182/200 ---> TN_test: 380, FP_test: 90, TP_test: 200, FN_test: 132
# epoch 182/200 ---> AUC_test: 0.7588310689566777
# epoch 182/200 ---> Precision_test: 0.6896551724137931
# epoch 183/200 ---> train_accuracy: 0.7326403260231018, test_accuracy: 0.7281795740127563
# epoch 183/200 ---> train_recall : 0.5381855458739108 , test_recall : 0.5933734939759037
# epoch 183/200 ---> TN_test: 387, FP_test: 83, TP_test: 197, FN_test: 135
# epoch 183/200 ---> AUC_test: 0.7585074339912843
# epoch 183/200 ---> Precision_test: 0.7035714285714286
# epoch 184/200 ---> train_accuracy: 0.7338877320289612, test_accuracy: 0.7219451665878296
# epoch 184/200 ---> train_recall : 0.5530497180932855 , test_recall : 0.5993975903614458
# epoch 184/200 ---> TN_test: 380, FP_test: 90, TP_test: 199, FN_test: 133
# epoch 184/200 ---> AUC_test: 0.7586259933350423
# epoch 184/200 ---> Precision_test: 0.6885813148788927
# epoch 185/200 ---> train_accuracy: 0.7324324250221252, test_accuracy: 0.7281795740127563
# epoch 185/200 ---> train_recall : 0.5458739108149667 , test_recall : 0.5993975903614458
# epoch 185/200 ---> TN_test: 385, FP_test: 85, TP_test: 199, FN_test: 133
# epoch 185/200 ---> AUC_test: 0.7588759292489105
# epoch 185/200 ---> Precision_test: 0.7007042253521126
# epoch 186/200 ---> train_accuracy: 0.7334719300270081, test_accuracy: 0.7294264435768127
# epoch 186/200 ---> train_recall : 0.5433111225012814 , test_recall : 0.6024096385542169
# epoch 186/200 ---> TN_test: 385, FP_test: 85, TP_test: 200, FN_test: 132
# epoch 186/200 ---> AUC_test: 0.7583824660343502
# epoch 186/200 ---> Precision_test: 0.7017543859649122
# epoch 187/200 ---> train_accuracy: 0.7340956330299377, test_accuracy: 0.7244389057159424
# epoch 187/200 ---> train_recall : 0.5504869297796002 , test_recall : 0.5993975903614458
# epoch 187/200 ---> TN_test: 382, FP_test: 88, TP_test: 199, FN_test: 133
# epoch 187/200 ---> AUC_test: 0.7589143809279673
# epoch 187/200 ---> Precision_test: 0.6933797909407665
# epoch 188/200 ---> train_accuracy: 0.7345114350318909, test_accuracy: 0.7244389057159424
# epoch 188/200 ---> train_recall : 0.5489492567913891 , test_recall : 0.5993975903614458
# epoch 188/200 ---> TN_test: 382, FP_test: 88, TP_test: 199, FN_test: 133
# epoch 188/200 ---> AUC_test: 0.7578697769802614
# epoch 188/200 ---> Precision_test: 0.6933797909407665
# epoch 189/200 ---> train_accuracy: 0.7332640290260315, test_accuracy: 0.7269326448440552
# epoch 189/200 ---> train_recall : 0.5433111225012814 , test_recall : 0.6024096385542169
# epoch 189/200 ---> TN_test: 383, FP_test: 87, TP_test: 200, FN_test: 132
# epoch 189/200 ---> AUC_test: 0.7581517559600104
# epoch 189/200 ---> Precision_test: 0.6968641114982579
# epoch 190/200 ---> train_accuracy: 0.7322245240211487, test_accuracy: 0.723192036151886
# epoch 190/200 ---> train_recall : 0.5494618144541261 , test_recall : 0.5993975903614458
# epoch 190/200 ---> TN_test: 381, FP_test: 89, TP_test: 199, FN_test: 133
# epoch 190/200 ---> AUC_test: 0.7576967444245065
# epoch 190/200 ---> Precision_test: 0.6909722222222222
# epoch 191/200 ---> train_accuracy: 0.7343035340309143, test_accuracy: 0.7219451665878296
# epoch 191/200 ---> train_recall : 0.5592004100461302 , test_recall : 0.6054216867469879
# epoch 191/200 ---> TN_test: 378, FP_test: 92, TP_test: 201, FN_test: 131
# epoch 191/200 ---> AUC_test: 0.7580364009228403
# epoch 191/200 ---> Precision_test: 0.6860068259385665
# epoch 192/200 ---> train_accuracy: 0.7343035340309143, test_accuracy: 0.7281795740127563
# epoch 192/200 ---> train_recall : 0.548436699128652 , test_recall : 0.6024096385542169
# epoch 192/200 ---> TN_test: 384, FP_test: 86, TP_test: 200, FN_test: 132
# epoch 192/200 ---> AUC_test: 0.7580428095360163
# epoch 192/200 ---> Precision_test: 0.6993006993006993
# epoch 193/200 ---> train_accuracy: 0.7330561280250549, test_accuracy: 0.7256857752799988
# epoch 193/200 ---> train_recall : 0.548436699128652 , test_recall : 0.6024096385542169
# epoch 193/200 ---> TN_test: 382, FP_test: 88, TP_test: 200, FN_test: 132
# epoch 193/200 ---> AUC_test: 0.7584850038451679
# epoch 193/200 ---> Precision_test: 0.6944444444444444
# epoch 194/200 ---> train_accuracy: 0.7351351380348206, test_accuracy: 0.7219451665878296
# epoch 194/200 ---> train_recall : 0.5561250640697079 , test_recall : 0.6024096385542169
# epoch 194/200 ---> TN_test: 379, FP_test: 91, TP_test: 200, FN_test: 132
# epoch 194/200 ---> AUC_test: 0.7582735196103564
# epoch 194/200 ---> Precision_test: 0.6872852233676976
# epoch 195/200 ---> train_accuracy: 0.7340956330299377, test_accuracy: 0.7269326448440552
# epoch 195/200 ---> train_recall : 0.5448487954894926 , test_recall : 0.5993975903614458
# epoch 195/200 ---> TN_test: 384, FP_test: 86, TP_test: 199, FN_test: 133
# epoch 195/200 ---> AUC_test: 0.7583311971289413
# epoch 195/200 ---> Precision_test: 0.6982456140350877
# epoch 196/200 ---> train_accuracy: 0.7345114350318909, test_accuracy: 0.7281795740127563
# epoch 196/200 ---> train_recall : 0.548436699128652 , test_recall : 0.5993975903614458
# epoch 196/200 ---> TN_test: 385, FP_test: 85, TP_test: 199, FN_test: 133
# epoch 196/200 ---> AUC_test: 0.7577031530376825
# epoch 196/200 ---> Precision_test: 0.7007042253521126
# epoch 197/200 ---> train_accuracy: 0.7334719300270081, test_accuracy: 0.7244389057159424
# epoch 197/200 ---> train_recall : 0.5540748334187596 , test_recall : 0.6024096385542169
# epoch 197/200 ---> TN_test: 381, FP_test: 89, TP_test: 200, FN_test: 132
# epoch 197/200 ---> AUC_test: 0.7575877980005128
# epoch 197/200 ---> Precision_test: 0.6920415224913494
# epoch 198/200 ---> train_accuracy: 0.7338877320289612, test_accuracy: 0.7256857752799988
# epoch 198/200 ---> train_recall : 0.5520246027678114 , test_recall : 0.5993975903614458
# epoch 198/200 ---> TN_test: 383, FP_test: 87, TP_test: 199, FN_test: 133
# epoch 198/200 ---> AUC_test: 0.7581261215073059
# epoch 198/200 ---> Precision_test: 0.6958041958041958
# epoch 199/200 ---> train_accuracy: 0.7343035340309143, test_accuracy: 0.7244389057159424
# epoch 199/200 ---> train_recall : 0.5520246027678114 , test_recall : 0.5963855421686747
# epoch 199/200 ---> TN_test: 383, FP_test: 87, TP_test: 198, FN_test: 134
# epoch 199/200 ---> AUC_test: 0.7579274544988465
# epoch 199/200 ---> Precision_test: 0.6947368421052632

# %%
# Plotting the training and validation recall
plt.plot([i for i in range(len(train_recall_list))], train_recall_list, label="train")
plt.plot([i for i in range(len(test_recall_list))], test_recall_list, label='test')
plt.legend(loc="upper left")
plt.xlabel('Epochs')
plt.ylabel('Recall')
# Out:
# Text(0, 0.5, 'Recall')

# %%
# Plotting the training and validation accuracy
plt.plot([i for i in range(len(train_accuracy_list))], train_accuracy_list, label="train")
plt.plot([i for i in range(len(test_accuracy_list))], test_accuracy_list, label='validation')
plt.legend(loc="upper left")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# SHAP Analysis

# %%
# !pip install shap
import shap
import numpy as np

explainer = shap.DeepExplainer(model, X_train_tensor)
shap_values = explainer.shap_values(X_train_tensor)
feature_names = X_train_tensor.columns.tolist()

#Summary dot plots
shap.summary_plot(shap_values, X_train_tensor, plot_type = "dot", feature_names=)
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.44.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.2)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.58.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
